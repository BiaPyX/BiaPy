# %% [markdown]
# # **3D Instance Segmentation pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **3D instance segmentation** of microscopy data.
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume.gif' width='300px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume_mask.gif' width='300px'/>
# <figcaption><b>Figure 1</b>: Example of a 3D instance segmentation problem. From left to right: 3D electron microscopy image and its corresponding nuclei instance labels (source: NucMM, <a href="https://link.springer.com/chapter/10.1007/978-3-030-87193-2_16">Lin et al, 2021</a>).</figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their corresponding instance label images,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the segmentation results** to your local machine.
#
# **Disclaimer:** the structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 3D images to train the model.
# * **Training label images**: with the instance-label 3D images to train the model. Their number and sizes must match those of the training raw images.
# * **Test raw images**: with the raw 3D images to test the model.
# * **Test label images**: with the instance-label 3D images to test the model. Their number and sizes must match those of the validation raw images.
# * **Output folder**: a path to store the segmentation results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing one result **TIFF image** for each test image. The result images contain the instances of the "objects" of interest as predicted by our pipeline.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3'**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`.

# %%
#@markdown ##Play the cell to upload local files (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/x
# %cd /content/input/train/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (train label images)

from google.colab import files
# !mkdir -p /content/input/train/y 
# %cd /content/input/train/y
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test raw images)

from google.colab import files
# !mkdir -p /content/input/val/x
# %cd /content/input/val/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test label images)

from google.colab import files
# !mkdir -p /content/input/val/y
# %cd /content/input/val/y
uploaded = files.upload()
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use the [3D demo dataset from the StarDist 0.3.0 release](https://github.com/mpicbg-csbd/stardist/releases/download/0.3.0/demo3D.zip), publicly available online.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')

# !curl -L -s -o demo3D.zip 'https://drive.google.com/uc?id=1fdL35ZTNw5hhiKau1gadaGu-rc5ZU_C7&confirm=t'

# !unzip -q demo3D.zip
# !rm demo3D.zip

print( 'Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train/x', train_data_mask_path as '/content/data/train/y', test_data_path as '/content/data/test/x', test_data_mask_path as '/content/data/test/y', and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train/x' #@param {type:"string"}
#@markdown #####Path to train instances
train_data_mask_path = '/content/data/train/y' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test/x' #@param {type:"string"}
#@markdown #####Path to test instances
test_data_mask_path = '/content/data/test/y' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone https://github.com/danifranco/BiaPy.git
    # !git checkout 81072f1c0734412be3daf1312bf1c6bb139b6b66 &> /dev/null
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Cloning into 'BiaPy'...
# remote: Enumerating objects: 15349, done.
# remote: Counting objects: 100% (1418/1418), done.
# remote: Compressing objects: 100% (476/476), done.
# remote: Total 15349 (delta 1002), reused 1338 (delta 928), pack-reused 13931
# Receiving objects: 100% (15349/15349), 817.63 MiB | 34.14 MiB/s, done.
# Resolving deltas: 100% (8271/8271), done.

# %% [markdown]
# ## **Configure and train the DNN model**
# [BiaPy](https://biapy.readthedocs.io/en/latest/) uses a bottom-up approach to instance segmentation in 2D and 3D by learning the binary masks, contours, and
# (optionally) the distance map of the objects of interest, to be later post-processed using marker-controlled watershed (see [Wei et al. 2020](https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7)).
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/cysto_instance_bcd_scheme.svg' width='300px'/>
# <figcaption><b>Figure 2</b>: Example of multi-channel representation for instance segmentation. Label instances can be learnt by predicting their contours, binary masks and distance maps (<a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>).</figcaption></center>
# </figure>
#
# The use of these representations and other pipeline hyperparameters can be configured by editing the YAML configuration file or (easier) by running the next cell.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
# #### **Basic training parameters**
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, preliminary results can already be observed after 50 epochs, but better results are obtained when running the model longer. **Default value: 100**
#
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. **Default value: 10**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: U-Net, Residual U-Net (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1))  **Default value: Residual U-Net**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 8**
#
# * **`patch_size_xy`:** Input the XY size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 64**
#
# * **`patch_size_z`:** Input the Z size of the patches use to train your model (length in pixels in Z). The value should be smaller or equal to the dimensions of the image. **Default value: 32**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 1**
#
# * **`anisotropic_data`:** Select if your image data is anisotropic (lower resolution in Z with respect to XY). The model downsampling step size will be set accordingly. **Default value: True**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: ADAM**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.0001**
#
# * **`problem_representation`:** Select the type of representation that the model must learn to identify the instances. Options: "Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask" (see <a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>). **Default value: "Binary mask + Contours"**

# %%
#@markdown ###Name of the model:
model_name = "my_3d_instance_segmentation" #@param {type:"string"}

#@markdown ### Basic training parameters:
number_of_epochs =  200#@param {type:"number"}
percentage_validation =  10 #@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "Residual U-Net" #@param ["U-Net", "Residual U-Net"]

batch_size =  2#@param {type:"number"}
patch_size_xy = 64 #@param {type:"number"}
patch_size_z = 32 #@param {type:"number"}

input_channels = 1 #@param {type:"number"}
anisotropic_data = True #@param {type:"boolean"}

optimizer = "ADAM" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.0001 #@param {type:"number"}

problem_representation = "Binary mask + Contours" #@param ["Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask"]

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# remove template file it is exists
template_file = 'resunet_3d_instances.yaml'
if os.path.exists( template_file ):
    os.remove( template_file )

# Download template file 
# !wget https://raw.githubusercontent.com/danifranco/BiaPy/master/templates/instance_segmentation/resunet_3d_instances.yaml &> /dev/null

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_path))
if not os.path.exists(train_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_mask_path)
ids = sorted(next(os.walk(train_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_mask_path))

# Check folders before modifying the .yaml file
if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_path))
if not os.path.exists(test_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_mask_path)
ids = sorted(next(os.walk(test_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_mask_path))


# open template configuration file
import yaml
with open( template_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['TRAIN']['MASK_PATH'] = train_data_mask_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path
biapy_config['DATA']['TEST']['MASK_PATH'] = test_data_mask_path

# make sure ground truth labels are loaded
biapy_config['DATA']['TEST']['LOAD_GT'] = True

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size_z)+', '+ str(patch_size_xy)+', '+ str(patch_size_xy)+ ', ' + str(input_channels)+')'
# adjust test padding accordingly
padding_xy = patch_size_xy // 8
padding_z = patch_size_z // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+str(padding_z)+', '+ str(padding_xy)+', '+ str(padding_xy)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = True
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe problem representation
#   BC = "Binary mask + Contours"
#   BCM = "Binary mask + Contours + Foreground mask"
#   BCD = "Binary mask + Contours + Distance map"
#   BCDv2 = "Binary mask + Contours + Distance map with background"
#   Dv2 = "Distance map with background"
#   BDv2 = "Binary mask + Distance map with background"
problem_channels = 'BC'
if problem_representation == "Binary mask + Contours":
    problem_channels = 'BC'
elif problem_representation == "Binary mask + Contours + Foreground mask":
    problem_channels = 'BCM'
elif problem_representation == "Binary mask + Contours + Distance map":
    problem_channels = 'BCD'
elif problem_representation == "Binary mask + Contours + Distance map with background":
    problem_channels = 'BCDv2'
elif problem_representation == "Distance map with background":
    problem_channels = 'Dv2'
else:
    problem_channels = 'BDv2'

biapy_config['PROBLEM']['INSTANCE_SEG']['DATA_CHANNELS'] = problem_channels

# Transcribe model architecture
architecture = 'unet'
if model_architecture == "U-Net":
    architecture = 'unet'
else:
    architecture = 'resunet'
biapy_config['MODEL']['ARCHITECTURE'] = architecture
if anisotropic_data == True:
    biapy_config['MODEL']['Z_DOWN'] = 1
else:
    biapy_config['MODEL']['Z_DOWN'] = 2

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2022-12-12 14:38:31
# Arguments: Namespace(config='/content/my_3d_instance_segmentation.yaml', gpu='0', name='my_3d_instance_segmentation', result_dir='/content/output', run_id=1)
# Job: my_3d_instance_segmentation_1
# Python       : 3.8.16 (default, Dec  7 2022, 01:12:13)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [2048, 1024]
#   UNETR_NUM_HEADS: 6
#   UNETR_OUT_DIM: 1
#   UNETR_TOKEN_SIZE: 16
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MAP_CODE_DIR:
#   MAP_H5_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/mAP_checkpoints
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     FULL_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_post_processing
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_INST_VORONOI: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances_voronoi
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH1: 0.2
#     DATA_MW_TH2: 0.1
#     DATA_MW_TH3: 0.3
#     DATA_MW_TH4: 1.2
#     DATA_MW_TH5: 1.5
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ: 30
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MAP: False
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     BLENDING: False
#     DET_WATERSHED: False
#     DET_WATERSHED_CIRCULARITY: 0.5
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [10.0]
#     VORONOI_ON_MASK: False
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: True
#   EPOCHS: 200
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# You select to create BC channels from given instance labels and no file is detected in /content/data/train/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TRAIN.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/train/y
# 100% 27/27 [00:00<00:00, 347.31it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating Y_train channels . . .
# 100% 27/27 [00:03<00:00,  7.48it/s]
# Loading data from /content/data/train/x
# 100% 27/27 [00:00<00:00, 328.73it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating X_train channels . . .
# You select to create BC channels from given instance labels and no file is detected in /content/data/test/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TEST.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/test/y
# 100% 3/3 [00:00<00:00, 484.11it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Creating Y_test channels . . .
# 100% 3/3 [00:00<00:00, 12.10it/s]
# Creating X_test channels . . .
# Loading data from /content/data/test/x
# 100% 3/3 [00:00<00:00, 504.75it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BC_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BC_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BC_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BC_thick
# #################
# #   LOAD DATA   #
# #################
#
# ### LOAD ###
# 0) Loading train images . . .
# Loading data from /content/data/train/x_BC_thick
# 100% 27/27 [00:00<00:00, 408.88it/s]
# *** Loaded data shape is (216, 32, 64, 64, 1)
# 1) Loading train masks . . .
# Loading data from /content/data/train/y_BC_thick
# 100% 27/27 [00:00<00:00, 85.30it/s]
# *** Loaded data shape is (216, 32, 64, 64, 2)
# *** Loaded train data shape is: (194, 32, 64, 64, 1)
# *** Loaded train mask shape is: (194, 32, 64, 64, 2)
# *** Loaded validation data shape is: (22, 32, 64, 64, 1)
# *** Loaded validation mask shape is: (22, 32, 64, 64, 2)
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# Initializing train data generator . . .
# Training data normalization - min: 0.0009765774011611938 , max: 0.006027313880622387 , mean: 0.002458977047353983
# Initializing val data generator . . .
# Validation data normalization - min: 0.001144426641985774 , max: 0.005951018538326025 , mean: 0.002492719329893589
# Creating generator samples . . .
# 0) Creating samples of data augmentation . . .
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/imgaug/augmenters/base.py:49: SuspiciousSingleImageShapeWarning: You provided a numpy array of shape (64, 64, 32) as a single-image augmentation input, which was interpreted as (H, W, C). The last dimension however has a size of >=32, which indicates that you provided a multi-image array with shape (N, H, W) instead. If that is the case, you should use e.g. augmenter(imageS=<your input>) or augment_imageS(<your input>). Otherwise your multi-image input will be interpreted as a single image during augmentation.
#   ia.warn(
# 100% 10/10 [00:00<00:00, 66.54it/s]
# #################
# #  BUILD MODEL  #
# #################
#
# 2022-12-12 14:38:43.472113: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 32, 64, 64, 1)]          0                 []
#
#  conv3d_1 (Conv3D)                               (None, 32, 64, 64, 36)           1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, 32, 64, 64, 36)           0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, 32, 64, 64, 36)           72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, 32, 64, 64, 36)           35028             ['elu[0][0]']
#
#  add (Add)                                       (None, 32, 64, 64, 36)           0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, 32, 32, 32, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, 32, 32, 32, 36)           0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, 32, 32, 32, 48)           46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, 32, 32, 32, 48)           1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, 32, 32, 32, 48)           62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, 32, 16, 16, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, 32, 16, 16, 48)           0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, 32, 16, 16, 64)           83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, 32, 16, 16, 64)           3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, 32, 16, 16, 64)           110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, 32, 32, 32, 48)           24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, 32, 32, 32, 96)           0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, 32, 32, 32, 96)           0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, 32, 32, 32, 48)           124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, 32, 32, 32, 48)           4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, 32, 32, 32, 48)           62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, 32, 64, 64, 36)           13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, 32, 64, 64, 72)           0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, 32, 64, 64, 72)           0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, 32, 64, 64, 36)           70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, 32, 64, 64, 36)           2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, 32, 64, 64, 36)           35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, 32, 64, 64, 2)            578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# #####################
# #  TRAIN THE MODEL  #
# #####################
#
# Epoch 1/200
# 97/97 [==============================] - ETA: 0s - loss: 0.7501 - jaccard_index_instances: 0.0125
#
# Epoch 00001: val_loss improved from inf to 0.67277, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 39s 276ms/step - loss: 0.7501 - jaccard_index_instances: 0.0125 - val_loss: 0.6728 - val_jaccard_index_instances: 1.7321e-05
# Epoch 2/200
# 97/97 [==============================] - ETA: 0s - loss: 0.6299 - jaccard_index_instances: 0.0134
#
# Epoch 00002: val_loss did not improve from 0.67277
#
#
# 97/97 [==============================] - 27s 275ms/step - loss: 0.6299 - jaccard_index_instances: 0.0134 - val_loss: 0.6758 - val_jaccard_index_instances: 0.0000e+00
# Epoch 3/200
# 97/97 [==============================] - ETA: 0s - loss: 0.5806 - jaccard_index_instances: 0.0243
#
# Epoch 00003: val_loss improved from 0.67277 to 0.63696, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.5806 - jaccard_index_instances: 0.0243 - val_loss: 0.6370 - val_jaccard_index_instances: 2.8560e-06
# Epoch 4/200
# 97/97 [==============================] - ETA: 0s - loss: 0.5688 - jaccard_index_instances: 0.0465
#
# Epoch 00004: val_loss improved from 0.63696 to 0.52497, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.5688 - jaccard_index_instances: 0.0465 - val_loss: 0.5250 - val_jaccard_index_instances: 0.1222
# Epoch 5/200
# 97/97 [==============================] - ETA: 0s - loss: 0.4947 - jaccard_index_instances: 0.1175
#
# Epoch 00005: val_loss improved from 0.52497 to 0.50419, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.4947 - jaccard_index_instances: 0.1175 - val_loss: 0.5042 - val_jaccard_index_instances: 0.1109
# Epoch 6/200
# 97/97 [==============================] - ETA: 0s - loss: 0.4606 - jaccard_index_instances: 0.1458
#
# Epoch 00006: val_loss improved from 0.50419 to 0.49023, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.4606 - jaccard_index_instances: 0.1458 - val_loss: 0.4902 - val_jaccard_index_instances: 0.2068
# Epoch 7/200
# 97/97 [==============================] - ETA: 0s - loss: 0.4526 - jaccard_index_instances: 0.1491
#
# Epoch 00007: val_loss improved from 0.49023 to 0.48299, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.4526 - jaccard_index_instances: 0.1491 - val_loss: 0.4830 - val_jaccard_index_instances: 0.1987
# Epoch 8/200
# 97/97 [==============================] - ETA: 0s - loss: 0.4250 - jaccard_index_instances: 0.1873
#
# Epoch 00008: val_loss improved from 0.48299 to 0.45107, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.4250 - jaccard_index_instances: 0.1873 - val_loss: 0.4511 - val_jaccard_index_instances: 0.1564
# Epoch 9/200
# 97/97 [==============================] - ETA: 0s - loss: 0.4043 - jaccard_index_instances: 0.1989
#
# Epoch 00009: val_loss improved from 0.45107 to 0.42478, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.4043 - jaccard_index_instances: 0.1989 - val_loss: 0.4248 - val_jaccard_index_instances: 0.1871
# Epoch 10/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3988 - jaccard_index_instances: 0.2181
#
# Epoch 00010: val_loss improved from 0.42478 to 0.42272, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.3988 - jaccard_index_instances: 0.2181 - val_loss: 0.4227 - val_jaccard_index_instances: 0.2775
# Epoch 11/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3796 - jaccard_index_instances: 0.2382
#
# Epoch 00011: val_loss improved from 0.42272 to 0.40746, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.3796 - jaccard_index_instances: 0.2382 - val_loss: 0.4075 - val_jaccard_index_instances: 0.2494
# Epoch 12/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3633 - jaccard_index_instances: 0.2690
#
# Epoch 00012: val_loss improved from 0.40746 to 0.37727, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3633 - jaccard_index_instances: 0.2690 - val_loss: 0.3773 - val_jaccard_index_instances: 0.2455
# Epoch 13/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3522 - jaccard_index_instances: 0.2931
#
# Epoch 00013: val_loss improved from 0.37727 to 0.36087, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3522 - jaccard_index_instances: 0.2931 - val_loss: 0.3609 - val_jaccard_index_instances: 0.2874
# Epoch 14/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3419 - jaccard_index_instances: 0.3119
#
# Epoch 00014: val_loss improved from 0.36087 to 0.35154, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3419 - jaccard_index_instances: 0.3119 - val_loss: 0.3515 - val_jaccard_index_instances: 0.3586
# Epoch 15/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3301 - jaccard_index_instances: 0.3436
#
# Epoch 00015: val_loss improved from 0.35154 to 0.34244, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3301 - jaccard_index_instances: 0.3436 - val_loss: 0.3424 - val_jaccard_index_instances: 0.3352
# Epoch 16/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3240 - jaccard_index_instances: 0.3654
#
# Epoch 00016: val_loss improved from 0.34244 to 0.33046, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3240 - jaccard_index_instances: 0.3654 - val_loss: 0.3305 - val_jaccard_index_instances: 0.3983
# Epoch 17/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3121 - jaccard_index_instances: 0.3886
#
# Epoch 00017: val_loss improved from 0.33046 to 0.32859, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3121 - jaccard_index_instances: 0.3886 - val_loss: 0.3286 - val_jaccard_index_instances: 0.3981
# Epoch 18/200
# 97/97 [==============================] - ETA: 0s - loss: 0.3085 - jaccard_index_instances: 0.4110
#
# Epoch 00018: val_loss improved from 0.32859 to 0.32191, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.3085 - jaccard_index_instances: 0.4110 - val_loss: 0.3219 - val_jaccard_index_instances: 0.4022
# Epoch 19/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2946 - jaccard_index_instances: 0.4331
#
# Epoch 00019: val_loss improved from 0.32191 to 0.31940, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2946 - jaccard_index_instances: 0.4331 - val_loss: 0.3194 - val_jaccard_index_instances: 0.4127
# Epoch 20/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2893 - jaccard_index_instances: 0.4514
#
# Epoch 00020: val_loss improved from 0.31940 to 0.29417, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.2893 - jaccard_index_instances: 0.4514 - val_loss: 0.2942 - val_jaccard_index_instances: 0.4858
# Epoch 21/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2829 - jaccard_index_instances: 0.4609
#
# Epoch 00021: val_loss did not improve from 0.29417
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.2829 - jaccard_index_instances: 0.4609 - val_loss: 0.3468 - val_jaccard_index_instances: 0.3969
# Epoch 22/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2822 - jaccard_index_instances: 0.4669
#
# Epoch 00022: val_loss improved from 0.29417 to 0.28946, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2822 - jaccard_index_instances: 0.4669 - val_loss: 0.2895 - val_jaccard_index_instances: 0.4929
# Epoch 23/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2719 - jaccard_index_instances: 0.4849
#
# Epoch 00023: val_loss improved from 0.28946 to 0.27587, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2719 - jaccard_index_instances: 0.4849 - val_loss: 0.2759 - val_jaccard_index_instances: 0.5295
# Epoch 24/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2649 - jaccard_index_instances: 0.4911
#
# Epoch 00024: val_loss improved from 0.27587 to 0.26736, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2649 - jaccard_index_instances: 0.4911 - val_loss: 0.2674 - val_jaccard_index_instances: 0.5355
# Epoch 25/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2594 - jaccard_index_instances: 0.5078
#
# Epoch 00025: val_loss improved from 0.26736 to 0.26325, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.2594 - jaccard_index_instances: 0.5078 - val_loss: 0.2633 - val_jaccard_index_instances: 0.5294
# Epoch 26/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2526 - jaccard_index_instances: 0.5181
#
# Epoch 00026: val_loss did not improve from 0.26325
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.2526 - jaccard_index_instances: 0.5181 - val_loss: 0.2640 - val_jaccard_index_instances: 0.5334
# Epoch 27/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2464 - jaccard_index_instances: 0.5274
#
# Epoch 00027: val_loss improved from 0.26325 to 0.24906, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2464 - jaccard_index_instances: 0.5274 - val_loss: 0.2491 - val_jaccard_index_instances: 0.5488
# Epoch 28/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2407 - jaccard_index_instances: 0.5428
#
# Epoch 00028: val_loss improved from 0.24906 to 0.24021, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2407 - jaccard_index_instances: 0.5428 - val_loss: 0.2402 - val_jaccard_index_instances: 0.5825
# Epoch 29/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2348 - jaccard_index_instances: 0.5553
#
# Epoch 00029: val_loss improved from 0.24021 to 0.23413, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2348 - jaccard_index_instances: 0.5553 - val_loss: 0.2341 - val_jaccard_index_instances: 0.5890
# Epoch 30/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2314 - jaccard_index_instances: 0.5559
#
# Epoch 00030: val_loss did not improve from 0.23413
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.2314 - jaccard_index_instances: 0.5559 - val_loss: 0.2370 - val_jaccard_index_instances: 0.5724
# Epoch 31/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2238 - jaccard_index_instances: 0.5707
#
# Epoch 00031: val_loss improved from 0.23413 to 0.22161, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2238 - jaccard_index_instances: 0.5707 - val_loss: 0.2216 - val_jaccard_index_instances: 0.5993
# Epoch 32/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2231 - jaccard_index_instances: 0.5752
#
# Epoch 00032: val_loss did not improve from 0.22161
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.2231 - jaccard_index_instances: 0.5752 - val_loss: 0.2235 - val_jaccard_index_instances: 0.6144
# Epoch 33/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2222 - jaccard_index_instances: 0.5778
#
# Epoch 00033: val_loss did not improve from 0.22161
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.2222 - jaccard_index_instances: 0.5778 - val_loss: 0.2322 - val_jaccard_index_instances: 0.5914
# Epoch 34/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2161 - jaccard_index_instances: 0.5856
#
# Epoch 00034: val_loss improved from 0.22161 to 0.21548, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2161 - jaccard_index_instances: 0.5856 - val_loss: 0.2155 - val_jaccard_index_instances: 0.6223
# Epoch 35/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2112 - jaccard_index_instances: 0.6002
#
# Epoch 00035: val_loss improved from 0.21548 to 0.21128, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2112 - jaccard_index_instances: 0.6002 - val_loss: 0.2113 - val_jaccard_index_instances: 0.6250
# Epoch 36/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2122 - jaccard_index_instances: 0.5992
#
# Epoch 00036: val_loss improved from 0.21128 to 0.20573, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2122 - jaccard_index_instances: 0.5992 - val_loss: 0.2057 - val_jaccard_index_instances: 0.6319
# Epoch 37/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2037 - jaccard_index_instances: 0.6088
#
# Epoch 00037: val_loss improved from 0.20573 to 0.20196, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.2037 - jaccard_index_instances: 0.6088 - val_loss: 0.2020 - val_jaccard_index_instances: 0.6439
# Epoch 38/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2014 - jaccard_index_instances: 0.6186
#
# Epoch 00038: val_loss improved from 0.20196 to 0.20039, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2014 - jaccard_index_instances: 0.6186 - val_loss: 0.2004 - val_jaccard_index_instances: 0.6345
# Epoch 39/200
# 97/97 [==============================] - ETA: 0s - loss: 0.2016 - jaccard_index_instances: 0.6160
#
# Epoch 00039: val_loss improved from 0.20039 to 0.19818, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.2016 - jaccard_index_instances: 0.6160 - val_loss: 0.1982 - val_jaccard_index_instances: 0.6538
# Epoch 40/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1984 - jaccard_index_instances: 0.6253
#
# Epoch 00040: val_loss did not improve from 0.19818
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1984 - jaccard_index_instances: 0.6253 - val_loss: 0.2090 - val_jaccard_index_instances: 0.6385
# Epoch 41/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1976 - jaccard_index_instances: 0.6208
#
# Epoch 00041: val_loss did not improve from 0.19818
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1976 - jaccard_index_instances: 0.6208 - val_loss: 0.2004 - val_jaccard_index_instances: 0.6466
# Epoch 42/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1937 - jaccard_index_instances: 0.6292
#
# Epoch 00042: val_loss improved from 0.19818 to 0.19481, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1937 - jaccard_index_instances: 0.6292 - val_loss: 0.1948 - val_jaccard_index_instances: 0.6546
# Epoch 43/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1916 - jaccard_index_instances: 0.6345
#
# Epoch 00043: val_loss improved from 0.19481 to 0.18671, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 275ms/step - loss: 0.1916 - jaccard_index_instances: 0.6345 - val_loss: 0.1867 - val_jaccard_index_instances: 0.6693
# Epoch 44/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1860 - jaccard_index_instances: 0.6430
#
# Epoch 00044: val_loss improved from 0.18671 to 0.18510, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1860 - jaccard_index_instances: 0.6430 - val_loss: 0.1851 - val_jaccard_index_instances: 0.6638
# Epoch 45/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1866 - jaccard_index_instances: 0.6434
#
# Epoch 00045: val_loss improved from 0.18510 to 0.18049, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.1866 - jaccard_index_instances: 0.6434 - val_loss: 0.1805 - val_jaccard_index_instances: 0.6784
# Epoch 46/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1891 - jaccard_index_instances: 0.6367
#
# Epoch 00046: val_loss did not improve from 0.18049
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1891 - jaccard_index_instances: 0.6367 - val_loss: 0.1821 - val_jaccard_index_instances: 0.6723
# Epoch 47/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1839 - jaccard_index_instances: 0.6480
#
# Epoch 00047: val_loss did not improve from 0.18049
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1839 - jaccard_index_instances: 0.6480 - val_loss: 0.1811 - val_jaccard_index_instances: 0.6720
# Epoch 48/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1824 - jaccard_index_instances: 0.6473
#
# Epoch 00048: val_loss did not improve from 0.18049
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1824 - jaccard_index_instances: 0.6473 - val_loss: 0.1825 - val_jaccard_index_instances: 0.6713
# Epoch 49/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1811 - jaccard_index_instances: 0.6514
#
# Epoch 00049: val_loss improved from 0.18049 to 0.17609, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1811 - jaccard_index_instances: 0.6514 - val_loss: 0.1761 - val_jaccard_index_instances: 0.6854
# Epoch 50/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1801 - jaccard_index_instances: 0.6526
#
# Epoch 00050: val_loss improved from 0.17609 to 0.17260, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1801 - jaccard_index_instances: 0.6526 - val_loss: 0.1726 - val_jaccard_index_instances: 0.6914
# Epoch 51/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1771 - jaccard_index_instances: 0.6599
#
# Epoch 00051: val_loss did not improve from 0.17260
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1771 - jaccard_index_instances: 0.6599 - val_loss: 0.1790 - val_jaccard_index_instances: 0.6808
# Epoch 52/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1762 - jaccard_index_instances: 0.6632
#
# Epoch 00052: val_loss improved from 0.17260 to 0.17212, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1762 - jaccard_index_instances: 0.6632 - val_loss: 0.1721 - val_jaccard_index_instances: 0.6889
# Epoch 53/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1764 - jaccard_index_instances: 0.6578
#
# ...
#
# Epoch 00180: val_loss improved from 0.12763 to 0.12702, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 277ms/step - loss: 0.1257 - jaccard_index_instances: 0.7488 - val_loss: 0.1270 - val_jaccard_index_instances: 0.7666
# Epoch 181/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1274 - jaccard_index_instances: 0.7440
#
# Epoch 00181: val_loss did not improve from 0.12702
#
#
# 97/97 [==============================] - 26s 271ms/step - loss: 0.1274 - jaccard_index_instances: 0.7440 - val_loss: 0.1294 - val_jaccard_index_instances: 0.7622
# Epoch 182/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1242 - jaccard_index_instances: 0.7514
#
# Epoch 00182: val_loss improved from 0.12702 to 0.12612, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.1242 - jaccard_index_instances: 0.7514 - val_loss: 0.1261 - val_jaccard_index_instances: 0.7684
# Epoch 183/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1251 - jaccard_index_instances: 0.7490
#
# Epoch 00183: val_loss did not improve from 0.12612
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1251 - jaccard_index_instances: 0.7490 - val_loss: 0.1278 - val_jaccard_index_instances: 0.7682
# Epoch 184/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1255 - jaccard_index_instances: 0.7471
#
# Epoch 00184: val_loss did not improve from 0.12612
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1255 - jaccard_index_instances: 0.7471 - val_loss: 0.1274 - val_jaccard_index_instances: 0.7676
# Epoch 185/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1255 - jaccard_index_instances: 0.7474
#
# Epoch 00185: val_loss did not improve from 0.12612
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1255 - jaccard_index_instances: 0.7474 - val_loss: 0.1276 - val_jaccard_index_instances: 0.7655
# Epoch 186/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1250 - jaccard_index_instances: 0.7473
#
# Epoch 00186: val_loss did not improve from 0.12612
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1250 - jaccard_index_instances: 0.7473 - val_loss: 0.1270 - val_jaccard_index_instances: 0.7665
# Epoch 187/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1255 - jaccard_index_instances: 0.7471
#
# Epoch 00187: val_loss did not improve from 0.12612
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1255 - jaccard_index_instances: 0.7471 - val_loss: 0.1284 - val_jaccard_index_instances: 0.7623
# Epoch 188/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1254 - jaccard_index_instances: 0.7490
#
# Epoch 00188: val_loss improved from 0.12612 to 0.12610, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.1254 - jaccard_index_instances: 0.7490 - val_loss: 0.1261 - val_jaccard_index_instances: 0.7676
# Epoch 189/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1252 - jaccard_index_instances: 0.7487
#
# Epoch 00189: val_loss did not improve from 0.12610
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1252 - jaccard_index_instances: 0.7487 - val_loss: 0.1302 - val_jaccard_index_instances: 0.7575
# Epoch 190/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1253 - jaccard_index_instances: 0.7462
#
# Epoch 00190: val_loss improved from 0.12610 to 0.12594, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.1253 - jaccard_index_instances: 0.7462 - val_loss: 0.1259 - val_jaccard_index_instances: 0.7689
# Epoch 191/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1242 - jaccard_index_instances: 0.7496
#
# Epoch 00191: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1242 - jaccard_index_instances: 0.7496 - val_loss: 0.1274 - val_jaccard_index_instances: 0.7652
# Epoch 192/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1261 - jaccard_index_instances: 0.7471
#
# Epoch 00192: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1261 - jaccard_index_instances: 0.7471 - val_loss: 0.1292 - val_jaccard_index_instances: 0.7649
# Epoch 193/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1255 - jaccard_index_instances: 0.7473
#
# Epoch 00193: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1255 - jaccard_index_instances: 0.7473 - val_loss: 0.1264 - val_jaccard_index_instances: 0.7664
# Epoch 194/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1238 - jaccard_index_instances: 0.7503
#
# Epoch 00194: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 27s 273ms/step - loss: 0.1238 - jaccard_index_instances: 0.7503 - val_loss: 0.1300 - val_jaccard_index_instances: 0.7587
# Epoch 195/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1255 - jaccard_index_instances: 0.7485
#
# Epoch 00195: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 27s 276ms/step - loss: 0.1255 - jaccard_index_instances: 0.7485 - val_loss: 0.1274 - val_jaccard_index_instances: 0.7663
# Epoch 196/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1236 - jaccard_index_instances: 0.7512
#
# Epoch 00196: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 271ms/step - loss: 0.1236 - jaccard_index_instances: 0.7512 - val_loss: 0.1269 - val_jaccard_index_instances: 0.7664
# Epoch 197/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1233 - jaccard_index_instances: 0.7515
#
# Epoch 00197: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1233 - jaccard_index_instances: 0.7515 - val_loss: 0.1263 - val_jaccard_index_instances: 0.7666
# Epoch 198/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1239 - jaccard_index_instances: 0.7492
#
# Epoch 00198: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 273ms/step - loss: 0.1239 - jaccard_index_instances: 0.7492 - val_loss: 0.1267 - val_jaccard_index_instances: 0.7683
# Epoch 199/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1250 - jaccard_index_instances: 0.7487
#
# Epoch 00199: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1250 - jaccard_index_instances: 0.7487 - val_loss: 0.1265 - val_jaccard_index_instances: 0.7696
# Epoch 200/200
# 97/97 [==============================] - ETA: 0s - loss: 0.1234 - jaccard_index_instances: 0.7515
#
# Epoch 00200: val_loss did not improve from 0.12594
#
#
# 97/97 [==============================] - 26s 272ms/step - loss: 0.1234 - jaccard_index_instances: 0.7515 - val_loss: 0.1263 - val_jaccard_index_instances: 0.7683
# Creating training plots . . .
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:05,  2.20it/s]
#
#  14% 2/14 [00:00<00:03,  3.93it/s]
#
#  21% 3/14 [00:00<00:02,  5.32it/s]
#
#  29% 4/14 [00:00<00:01,  6.18it/s]
#
#  36% 5/14 [00:00<00:01,  6.98it/s]
#
#  43% 6/14 [00:01<00:01,  7.59it/s]
#
#  50% 7/14 [00:01<00:00,  8.01it/s]
#
#  57% 8/14 [00:01<00:00,  8.41it/s]
#
#  64% 9/14 [00:01<00:00,  8.72it/s]
#
#  71% 10/14 [00:01<00:00,  8.86it/s]
#
#  79% 11/14 [00:01<00:00,  8.82it/s]
#
#  86% 12/14 [00:01<00:00,  9.02it/s]
#
#  93% 13/14 [00:01<00:00,  9.04it/s]
#
# 100% 14/14 [00:02<00:00,  4.62it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:03,  3.38it/s]
#
#  21% 3/14 [00:00<00:01,  5.62it/s]
#
#  29% 4/14 [00:00<00:01,  6.58it/s]
#
#  36% 5/14 [00:00<00:01,  7.34it/s]
#
#  43% 6/14 [00:00<00:01,  6.65it/s]
#
#  50% 7/14 [00:01<00:00,  7.43it/s]
#
#  57% 8/14 [00:01<00:00,  6.61it/s]
#
#  64% 9/14 [00:01<00:00,  7.15it/s]
#
#  71% 10/14 [00:01<00:00,  6.56it/s]
#
#  79% 11/14 [00:01<00:00,  7.23it/s]
#
#  86% 12/14 [00:01<00:00,  7.81it/s]
#
#  93% 13/14 [00:01<00:00,  6.85it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=5, tp=51, fn=0, precision=0.9107142857142857, recall=1.0, accuracy=0.9107142857142857, f1=0.9532710280373832, n_true=51, n_pred=56, mean_true_score=0.6715283861347273, mean_matched_score=0.6715283861347273, panoptic_quality=0.6401485550069363), Matching(criterion='iou', thresh=0.5, fp=5, tp=51, fn=0, precision=0.9107142857142857, recall=1.0, accuracy=0.9107142857142857, f1=0.9532710280373832, n_true=51, n_pred=56, mean_true_score=0.6715283861347273, mean_matched_score=0.6715283861347273, panoptic_quality=0.6401485550069363), Matching(criterion='iou', thresh=0.75, fp=47, tp=9, fn=42, precision=0.16071428571428573, recall=0.17647058823529413, accuracy=0.09183673469387756, f1=0.16822429906542055, n_true=51, n_pred=56, mean_true_score=0.13676886465035232, mean_matched_score=0.7750235663519965, panoptic_quality=0.1303777962087471))
#
# 100% 1/1 [00:06<00:00,  6.03s/it]
#  33% 1/3 [00:06<00:12,  6.05s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  6.25it/s]
#
#  14% 2/14 [00:00<00:01,  6.48it/s]
#
#  21% 3/14 [00:00<00:01,  7.11it/s]
#
#  29% 4/14 [00:00<00:01,  7.47it/s]
#
#  36% 5/14 [00:00<00:01,  6.59it/s]
#
#  43% 6/14 [00:00<00:01,  7.29it/s]
#
#  50% 7/14 [00:00<00:00,  7.64it/s]
#
#  57% 8/14 [00:01<00:00,  7.79it/s]
#
#  64% 9/14 [00:01<00:00,  7.83it/s]
#
#  71% 10/14 [00:01<00:00,  7.98it/s]
#
#  79% 11/14 [00:01<00:00,  8.08it/s]
#
#  86% 12/14 [00:01<00:00,  8.22it/s]
#
#  93% 13/14 [00:01<00:00,  7.08it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.05it/s]
#
#  14% 2/14 [00:00<00:01,  6.40it/s]
#
#  21% 3/14 [00:00<00:01,  7.48it/s]
#
#  29% 4/14 [00:00<00:01,  6.53it/s]
#
#  36% 5/14 [00:00<00:01,  7.39it/s]
#
#  43% 6/14 [00:00<00:01,  7.81it/s]
#
#  50% 7/14 [00:00<00:00,  8.24it/s]
#
#  57% 8/14 [00:01<00:00,  8.58it/s]
#
#  64% 9/14 [00:01<00:00,  7.27it/s]
#
#  71% 10/14 [00:01<00:00,  7.88it/s]
#
#  79% 11/14 [00:01<00:00,  8.26it/s]
#
#  86% 12/14 [00:01<00:00,  7.00it/s]
#
#  93% 13/14 [00:01<00:00,  7.60it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=2, tp=20, fn=0, precision=0.9090909090909091, recall=1.0, accuracy=0.9090909090909091, f1=0.9523809523809523, n_true=20, n_pred=22, mean_true_score=0.7511362075805664, mean_matched_score=0.7511362075805664, panoptic_quality=0.7153678167433966), Matching(criterion='iou', thresh=0.5, fp=2, tp=20, fn=0, precision=0.9090909090909091, recall=1.0, accuracy=0.9090909090909091, f1=0.9523809523809523, n_true=20, n_pred=22, mean_true_score=0.7511362075805664, mean_matched_score=0.7511362075805664, panoptic_quality=0.7153678167433966), Matching(criterion='iou', thresh=0.75, fp=12, tp=10, fn=10, precision=0.45454545454545453, recall=0.5, accuracy=0.3125, f1=0.47619047619047616, n_true=20, n_pred=22, mean_true_score=0.3938544273376465, mean_matched_score=0.787708854675293, panoptic_quality=0.3750994546072824))
#
# 100% 1/1 [00:03<00:00,  3.87s/it]
#  67% 2/3 [00:09<00:04,  4.78s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  8.84it/s]
#
#  14% 2/14 [00:00<00:01,  7.94it/s]
#
#  21% 3/14 [00:00<00:01,  6.35it/s]
#
#  29% 4/14 [00:00<00:01,  7.12it/s]
#
#  36% 5/14 [00:00<00:01,  7.60it/s]
#
#  43% 6/14 [00:00<00:01,  7.80it/s]
#
#  50% 7/14 [00:00<00:00,  7.92it/s]
#
#  57% 8/14 [00:01<00:00,  8.17it/s]
#
#  64% 9/14 [00:01<00:00,  8.12it/s]
#
#  71% 10/14 [00:01<00:00,  8.15it/s]
#
#  79% 11/14 [00:01<00:00,  8.24it/s]
#
#  86% 12/14 [00:01<00:00,  8.32it/s]
#
#  93% 13/14 [00:01<00:00,  8.21it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  5.14it/s]
#
#  14% 2/14 [00:00<00:01,  6.16it/s]
#
#  21% 3/14 [00:00<00:01,  7.15it/s]
#
#  29% 4/14 [00:00<00:01,  7.86it/s]
#
#  36% 5/14 [00:00<00:01,  8.30it/s]
#
#  43% 6/14 [00:00<00:01,  6.78it/s]
#
#  50% 7/14 [00:01<00:01,  6.20it/s]
#
#  57% 8/14 [00:01<00:01,  5.95it/s]
#
#  64% 9/14 [00:01<00:00,  5.78it/s]
#
#  71% 10/14 [00:01<00:00,  6.57it/s]
#
#  79% 11/14 [00:01<00:00,  6.19it/s]
#
#  86% 12/14 [00:01<00:00,  6.88it/s]
#
#  93% 13/14 [00:01<00:00,  6.39it/s]
#
# 100% 14/14 [00:02<00:00,  7.05it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6283222291527725, mean_matched_score=0.6283222291527725, panoptic_quality=0.6283222291527725), Matching(criterion='iou', thresh=0.5, fp=9, tp=155, fn=9, precision=0.9451219512195121, recall=0.9451219512195121, accuracy=0.8959537572254336, f1=0.9451219512195121, n_true=164, n_pred=164, mean_true_score=0.6023164144376429, mean_matched_score=0.6372896255985383, panoptic_quality=0.6023164144376429), Matching(criterion='iou', thresh=0.75, fp=160, tp=4, fn=160, precision=0.024390243902439025, recall=0.024390243902439025, accuracy=0.012345679012345678, f1=0.024390243902439025, n_true=164, n_pred=164, mean_true_score=0.01882181225753412, mean_matched_score=0.7716943025588989, panoptic_quality=0.01882181225753412))
#
# 100% 1/1 [00:04<00:00,  4.13s/it]
# 100% 3/3 [00:14<00:00,  4.70s/it]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 26.51195627450943
# Epoch number: 200
# Train time (s): 5302.391254901886
# Train loss: 0.12329106777906418
# Train Foreground jaccard_index_instances: 0.7515373826026917
# Validation loss: 0.12593775987625122
# Validation Foreground jaccard_index_instances: 0.769597589969635
# Loss (per patch): 0.06414338849760869
# Test Foreground IoU (per patch): 0.38810266535959126
#
# Test Foreground IoU (merge patches): 0.7865143937640818
# Test Overall IoU (merge patches): 0.8813059415638484
#
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=7, tp=235, fn=0, precision=0.9710743801652892, recall=1.0, accuracy=0.9710743801652892, f1=0.9853249475890985, n_true=235, n_pred=242, mean_true_score=0.648151137981009, mean_matched_score=0.648151137981009, panoptic_quality=0.6386394860609522, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=16, tp=226, fn=9, precision=0.9338842975206612, recall=0.9617021276595744, accuracy=0.900398406374502, f1=0.9475890985324947, n_true=235, n_pred=242, mean_true_score=0.6300023992010888, mean_matched_score=0.6550909903197162, panoptic_quality=0.6207570809738191, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=219, tp=23, fn=212, precision=0.09504132231404959, recall=0.09787234042553192, accuracy=0.05066079295154185, f1=0.09643605870020965, n_true=235, n_pred=242, mean_true_score=0.07633650150704892, mean_matched_score=0.7799599067024563, panoptic_quality=0.07521625934656812, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **Jaccard index or Intersection over Union** (IoU) metric is a method that can be used to quantify the overlap between the target mask and your prediction output. **Therefore, the closer to 1, the better the performance.** This metric can be used to assess the quality of your model to accurately predict cells.

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and IoU vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_jaccard_index_instances.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Intersection over Union (IoU) vs epoch number', fontdict = {'fontsize':22})

# %% [markdown]
# ## **Visualize instance segmentation results**

# %%
final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

instance_results = os.path.join(final_results, "per_image_instances")


#@markdown ##Play to visualize some results
from IPython.display import Markdown as md
md("After this last step, the resulting images should be placed in {}".format(final_results))
# Show a few examples to check that they have been stored correctly 
# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt

ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    sl = int(len(aux)/2)
    test_samples.append(aux[sl])
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]]))[sl].astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]]))[sl].astype(np.uint16)
    test_sample_gt.append(aux)

# Show predicted images
plt.figure(figsize=(20,15))
index = 1
for j in range(samples_to_show):
    plt.subplot(samples_to_show, 3, index)
    plt.title("Input image")
    plt.imshow(test_samples[j], cmap='gray')
    
    index = index + 1
    plt.subplot(samples_to_show, 3, index)
    plt.title("Instance segmentation")
    plt.imshow(test_sample_preds[j], cmap=cmap)
    
    index = index + 1
    plt.subplot(samples_to_show, 3, index)
    plt.title("Ground truth")
    plt.imshow(test_sample_gt[j],  cmap=cmap)
    index = index + 1
plt.show()

# %%
#@markdown ###Play to display the path to the output files (one 3D TIFF label image for each input image).

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

instance_results = os.path.join(final_results, "per_image_instances")

print("Output paths:")
print("    Instance segmentation files are in {}".format(instance_results))
# Out:
# Output paths:
#     Instance segmentation files are in /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances

# %% [markdown]
# ## **Download instance segmentation results**

# %%
#@markdown ###Play to download a zip file with all instance segmentation results in test.

from google.colab import files

# !zip -q -j /content/instance_segmentation_results.zip $instance_results/*.tif

files.download("/content/instance_segmentation_results.zip")

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))
