# %% [markdown]
# # **3D Instance Segmentation pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **3D instance segmentation** of microscopy data.
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume.gif' width='300px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume_mask.gif' width='300px'/>
# <figcaption><b>Figure 1</b>: Example of a 3D instance segmentation problem. From left to right: 3D electron microscopy image and its corresponding nuclei instance labels (source: NucMM, <a href="https://link.springer.com/chapter/10.1007/978-3-030-87193-2_16">Lin et al, 2021</a>).</figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their corresponding instance label images,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the segmentation results** to your local machine.
#
# **Disclaimer:** the structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 3D images to train the model.
# * **Training label images**: with the instance-label 3D images to train the model. Their number and sizes must match those of the training raw images.
# * **Test raw images**: with the raw 3D images to test the model.
# * **Test label images**: with the instance-label 3D images to test the model. Their number and sizes must match those of the validation raw images.
# * **Output folder**: a path to store the segmentation results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing one result **TIFF image** for each test image. The result images contain the instances of the "objects" of interest as predicted by our pipeline.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3'**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`.

# %%
#@markdown ##Play the cell to upload local files (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/x
# %cd /content/input/train/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (train label images)

from google.colab import files
# !mkdir -p /content/input/train/y 
# %cd /content/input/train/y
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test raw images)

from google.colab import files
# !mkdir -p /content/input/val/x
# %cd /content/input/val/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test label images)

from google.colab import files
# !mkdir -p /content/input/val/y
# %cd /content/input/val/y
uploaded = files.upload()
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use the [3D demo dataset from the StarDist 0.3.0 release](https://github.com/mpicbg-csbd/stardist/releases/download/0.3.0/demo3D.zip), publicly available online.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')

# !curl -L -s -o demo3D.zip 'https://drive.google.com/uc?id=1fdL35ZTNw5hhiKau1gadaGu-rc5ZU_C7&confirm=t'

# !unzip -q demo3D.zip
# !rm demo3D.zip

print( 'Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train/x', train_data_mask_path as '/content/data/train/y', test_data_path as '/content/data/test/x', test_data_mask_path as '/content/data/test/y', and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train/x' #@param {type:"string"}
#@markdown #####Path to train instances
train_data_mask_path = '/content/data/train/y' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test/x' #@param {type:"string"}
#@markdown #####Path to test instances
test_data_mask_path = '/content/data/test/y' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone --depth 1 https://github.com/danifranco/BiaPy.git
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs fill_voids edt &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Using existing installed version of BiaPy

# %% [markdown]
# ## **Configure and train the DNN model**
# [BiaPy](https://biapy.readthedocs.io/en/latest/) uses a bottom-up approach to instance segmentation in 2D and 3D by learning the binary masks, contours, and
# (optionally) the distance map of the objects of interest, to be later post-processed using marker-controlled watershed (see [Wei et al. 2020](https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7)).
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/cysto_instance_bcd_scheme.svg' width='300px'/>
# <figcaption><b>Figure 2</b>: Example of multi-channel representation for instance segmentation. Label instances can be learnt by predicting their contours, binary masks and distance maps (<a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>).</figcaption></center>
# </figure>
#
# The use of these representations and other pipeline hyperparameters can be configured by editing the YAML configuration file or (easier) by running the next cell.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
# #### **Data management**
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. **Default value: 10**
#
# * **`test_ground_truth`:** Select to use test data ground truth to measure the performance of the model's result. If selected, **test_data_mask_path** variable path set above will be used. **Default value: True**
#
# #### **Basic training parameters**
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, preliminary results can already be observed after 50 epochs, but better results are obtained when running the model longer. **Default value: 100**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: U-Net, Residual U-Net (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1))  **Default value: Residual U-Net**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 8**
#
# * **`patch_size_xy`:** Input the XY size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 64**
#
# * **`patch_size_z`:** Input the Z size of the patches use to train your model (length in pixels in Z). The value should be smaller or equal to the dimensions of the image. **Default value: 32**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 1**
#
# * **`anisotropic_data`:** Select if your image data is anisotropic (lower resolution in Z with respect to XY). The model downsampling step size will be set accordingly. **Default value: True**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: ADAM**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.0001**
#
# * **`problem_representation`:** Select the type of representation that the model must learn to identify the instances. Options: "Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask" (see <a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>). **Default value: "Binary mask + Contours"**
#
# * **`test_time_augmentation`:** Select to apply augmentation (flips and rotations) at test time. It usually provides more robust results but uses more time to produce each result. **Default value: False**

# %%
#@markdown ###Name of the model:
model_name = "my_3d_instance_segmentation" #@param {type:"string"}

#@markdown ### Data management:
test_ground_truth = True #@param {type:"boolean"}
percentage_validation =  10 #@param {type:"number"}

#@markdown ### Basic training parameters:
number_of_epochs =  100#@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "Residual U-Net" #@param ["U-Net", "Residual U-Net"]

batch_size =  2#@param {type:"number"}
patch_size_xy = 64 #@param {type:"number"}
patch_size_z = 32 #@param {type:"number"}

input_channels = 1 #@param {type:"number"}
anisotropic_data = True #@param {type:"boolean"}

optimizer = "ADAM" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.0001 #@param {type:"number"}

problem_representation = "Binary mask + Central points" #@param ["Binary mask + Contours", "Binary mask + Central points", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask"]

test_time_augmentation = False #@param {type:"boolean"}

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# remove template file it is exists
template_file = '3d_instances.yaml'
if os.path.exists( template_file ):
    os.remove( template_file )

# Download template file 
# !wget https://raw.githubusercontent.com/danifranco/BiaPy/master/templates/instance_segmentation/3d_instances.yaml &> /dev/null

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_path))
if not os.path.exists(train_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_mask_path)
ids = sorted(next(os.walk(train_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_mask_path))

# Check folders before modifying the .yaml file
if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_path))
if not os.path.exists(test_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_mask_path)
ids = sorted(next(os.walk(test_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_mask_path))


# open template configuration file
import yaml
with open( template_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['TRAIN']['GT_PATH'] = train_data_mask_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path
biapy_config['DATA']['TEST']['GT_PATH'] = test_data_mask_path
biapy_config['DATA']['TEST']['LOAD_GT'] = test_ground_truth

# make sure ground truth labels are loaded
biapy_config['DATA']['TEST']['LOAD_GT'] = True

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size_z)+', '+ str(patch_size_xy)+', '+ str(patch_size_xy)+ ', ' + str(input_channels)+')'
# adjust test padding accordingly
padding_xy = patch_size_xy // 8
padding_z = patch_size_z // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+str(padding_z)+', '+ str(padding_xy)+', '+ str(padding_xy)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = True
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe problem representation
#   BC = "Binary mask + Contours"
#   BCM = "Binary mask + Contours + Foreground mask"
#   BCD = "Binary mask + Contours + Distance map"
#   BCDv2 = "Binary mask + Contours + Distance map with background"
#   Dv2 = "Distance map with background"
#   BDv2 = "Binary mask + Distance map with background"
problem_channels = 'BC'
if problem_representation == "Binary mask + Contours":
    problem_channels = 'BC'
elif problem_representation == "Binary mask + Central points":
    problem_channels = 'BP'
elif problem_representation == "Binary mask + Contours + Foreground mask":
    problem_channels = 'BCM'
elif problem_representation == "Binary mask + Contours + Distance map":
    problem_channels = 'BCD'
elif problem_representation == "Binary mask + Contours + Distance map with background":
    problem_channels = 'BCDv2'
elif problem_representation == "Distance map with background":
    problem_channels = 'Dv2'
else:
    problem_channels = 'BDv2'

biapy_config['PROBLEM']['INSTANCE_SEG']['DATA_CHANNELS'] = problem_channels

# Transcribe model architecture
architecture = 'unet'
if model_architecture == "U-Net":
    architecture = 'unet'
else:
    architecture = 'resunet'
biapy_config['MODEL']['ARCHITECTURE'] = architecture
if anisotropic_data == True:
    biapy_config['MODEL']['Z_DOWN'] = [1 for i in range(len(biapy_config['MODEL']['FEATURE_MAPS'])-1)]
else:
    biapy_config['MODEL']['Z_DOWN'] = [2 for i in range(len(biapy_config['MODEL']['FEATURE_MAPS'])-1)]

# update test parameters
biapy_config['TEST']['AUGMENTATION'] = test_time_augmentation

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2023-05-07 20:08:11
# Arguments: Namespace(config='/content/my_3d_instance_segmentation.yaml', result_dir='/content/output', name='my_3d_instance_segmentation', run_id=1, gpu='0')
# Job: my_3d_instance_segmentation_1
# Python       : 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
# Keras        : 2.12.0
# Tensorflow   : 2.12.0
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GAUSSIAN_NOISE: False
#   GAUSSIAN_NOISE_MEAN: 0.0
#   GAUSSIAN_NOISE_USE_INPUT_IMG_MEAN_AND_VAR: False
#   GAUSSIAN_NOISE_VAR: 0.05
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   PEPPER: False
#   PEPPER_AMOUNT: 0.05
#   POISSON_NOISE: False
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SALT: False
#   SALT_AMOUNT: 0.05
#   SALT_AND_PEPPER: False
#   SALT_AND_PEPPER_AMOUNT: 0.05
#   SALT_AND_PEPPER_PROP: 0.5
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BP_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BP_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BP_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BP_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     MINIMUM_FOREGROUND_PER: -1.0
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BP_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BP_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [3072, 768]
#   UNETR_NUM_HEADS: 4
#   UNETR_TOKEN_SIZE: 16
#   UNETR_VIT_HIDD_MULT: 3
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: [1, 1]
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   PROFILER: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/profiler
#   RESULT_DIR:
#     AS_3D_STACK_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/as_3d_stack_post_processing
#     DET_ASSOC_POINTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/point_associations
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     INST_ASSOC_POINTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/instance_associations
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BP_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BP_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BP_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CENTRAL_POINT_DILATION: 3
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BP
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH_BINARY_MASK: 0.2
#     DATA_MW_TH_CONTOUR: 0.1
#     DATA_MW_TH_DISTANCE: 1.5
#     DATA_MW_TH_DIST_FOREGROUND: 1.2
#     DATA_MW_TH_FOREGROUND: 0.3
#     DATA_MW_TH_POINTS: 0.5
#     DATA_REMOVE_AFTER_MW: False
#     DATA_REMOVE_BEFORE_MW: False
#     DATA_REMOVE_SMALL_OBJ_AFTER: 100
#     DATA_REMOVE_SMALL_OBJ_BEFORE: 10
#     ERODE_AND_DILATE_FOREGROUND: False
#     FORE_DILATION_RADIUS: 5
#     FORE_EROSION_RADIUS: 5
#     SEED_MORPH_RADIUS: []
#     SEED_MORPH_SEQUENCE: []
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   ANALIZE_2D_IMGS_AS_3D_STACK: False
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   MATCHING_STATS_THS_COLORED_IMG: [0.3]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     DET_WATERSHED: False
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [-1.0]
#     REPARE_LARGE_BLOBS_SIZE: -1
#     VORONOI_ON_MASK: False
#     WATERSHED_CIRCULARITY: -1.0
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: True
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     MIN_LR: -1.0
#     NAME:
#     REDUCEONPLATEAU_FACTOR: 0.5
#     REDUCEONPLATEAU_PATIENCE: -1
#     WARMUP_COSINE_DECAY_EPOCHS: -1
#     WARMUP_COSINE_DECAY_HOLD_EPOCHS: -1
#     WARMUP_COSINE_DECAY_LR: -1.0
#   OPTIMIZER: ADAM
#   PATIENCE: 20
#   PROFILER: False
#   PROFILER_BATCH_RANGE: 10, 100
# ####################
# #  PRE-PROCESSING  #
# ####################
#
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# You select to create BP channels from given instance labels and no file is detected in /content/data/train/x_BP_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TRAIN.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/train/y
# 100% 27/27 [00:00<00:00, 485.84it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating Y_train channels . . .
# 100% 27/27 [00:04<00:00,  6.61it/s]
# Loading data from /content/data/train/x
# 100% 27/27 [00:00<00:00, 564.58it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating X_train channels . . .
# You select to create BP channels from given instance labels and no file is detected in /content/data/test/x_BP_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TEST.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/test/y
# 100% 3/3 [00:00<00:00, 703.51it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Creating Y_test channels . . .
# 100% 3/3 [00:00<00:00,  9.34it/s]
# Creating X_test channels . . .
# Loading data from /content/data/test/x
# 100% 3/3 [00:00<00:00, 795.68it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BP_instance_channels
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BP_instance_channels
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BP_instance_channels
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BP_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BP_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BP_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BP_thick
# #################
# #   LOAD DATA   #
# #################
#
# ### LOAD ###
# 0) Loading train images . . .
# Loading data from /content/data/train/x_BP_thick
# 100% 27/27 [00:00<00:00, 53.62it/s]
# *** Loaded data shape is (216, 32, 64, 64, 1)
# 1) Loading train masks . . .
# Loading data from /content/data/train/y_BP_thick
# 100% 27/27 [00:00<00:00, 58.49it/s]
# *** Loaded data shape is (216, 32, 64, 64, 2)
# Creating validation data
# *** Loaded train data shape is: (194, 32, 64, 64, 1)
# *** Loaded train mask shape is: (194, 32, 64, 64, 2)
# *** Loaded validation data shape is: (22, 32, 64, 64, 1)
# *** Loaded validation mask shape is: (22, 32, 64, 64, 2)
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# Initializing train data generator . . .
# Training data X normalization - min: 0.0009765774011611938 , max: 0.006027313880622387 , mean: 0.002458977047353983 , dtype: float32
# Training data Y normalization - min: 0 , max: 1 , mean: 0.0712254514399263 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Initializing val data generator . . .
# Validation data X normalization - min: 0.001144426641985774 , max: 0.005951018538326025 , mean: 0.002492719329893589 , dtype: float32
# Validation data Y normalization - min: 0 , max: 1 , mean: 0.07776849920099432 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Creating generator samples . . .
# 0) Creating samples of data augmentation . . .
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/imgaug/augmenters/base.py:49: SuspiciousSingleImageShapeWarning: You provided a numpy array of shape (64, 64, 32) as a single-image augmentation input, which was interpreted as (H, W, C). The last dimension however has a size of >=32, which indicates that you provided a multi-image array with shape (N, H, W) instead. If that is the case, you should use e.g. augmenter(imageS=<your input>) or augment_imageS(<your input>). Otherwise your multi-image input will be interpreted as a single image during augmentation.
#   ia.warn(
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  30% 3/10 [00:00<00:00, 22.92it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  60% 6/10 [00:00<00:00, 24.38it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  90% 9/10 [00:00<00:00, 24.02it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 10/10 [00:00<00:00, 24.48it/s]
# #################
# #  BUILD MODEL  #
# #################
#
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, None, None, None, 1)]    0                 []
#
#  conv3d_1 (Conv3D)                               (None, None, None, None, 36)     1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, None, None, None, 36)     0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, None, None, None, 36)     72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, None, None, None, 36)     35028             ['elu[0][0]']
#
#  add (Add)                                       (None, None, None, None, 36)     0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, None, None, None, 36)     0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, None, None, None, 36)     0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, None, None, None, 48)     46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, None, None, None, 48)     0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, None, None, None, 48)     1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, None, None, None, 48)     62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, None, None, None, 48)     0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, None, None, None, 48)     0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, None, None, None, 48)     0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, None, None, None, 64)     83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, None, None, None, 64)     0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, None, None, None, 64)     3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, None, None, None, 64)     110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, None, None, None, 64)     0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, None, None, None, 48)     24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, None, None, None, 96)     0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, None, None, None, 96)     0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, None, None, None, 48)     124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, None, None, None, 48)     0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, None, None, None, 48)     4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, None, None, None, 48)     62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, None, None, None, 48)     0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, None, None, None, 36)     13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, None, None, None, 72)     0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, None, None, None, 72)     0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, None, None, None, 36)     70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, None, None, None, 36)     0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, None, None, None, 36)     2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, None, None, None, 36)     35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, None, None, None, 36)     0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, None, None, None, 2)      578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# #####################
# #  TRAIN THE MODEL  #
# #####################
#
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/imgaug/augmenters/base.py:49: SuspiciousSingleImageShapeWarning: You provided a numpy array of shape (64, 64, 32) as a single-image augmentation input, which was interpreted as (H, W, C). The last dimension however has a size of >=32, which indicates that you provided a multi-image array with shape (N, H, W) instead. If that is the case, you should use e.g. augmenter(imageS=<your input>) or augment_imageS(<your input>). Otherwise your multi-image input will be interpreted as a single image during augmentation.
#   ia.warn(
# 97/97 [==============================] - ETA: 0s - loss: 0.5251 - jaccard_index_instances: 0.0162
#
# Epoch 00001: val_loss improved from inf to 0.40370, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 38s 239ms/step - loss: 0.5251 - jaccard_index_instances: 0.0162 - val_loss: 0.4037 - val_jaccard_index_instances: 0.2398
# Epoch 2/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3352 - jaccard_index_instances: 0.2306
#
# Epoch 00002: val_loss improved from 0.40370 to 0.28859, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 234ms/step - loss: 0.3352 - jaccard_index_instances: 0.2306 - val_loss: 0.2886 - val_jaccard_index_instances: 0.3136
# Epoch 3/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2750 - jaccard_index_instances: 0.3596
#
# Epoch 00003: val_loss improved from 0.28859 to 0.27014, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 246ms/step - loss: 0.2750 - jaccard_index_instances: 0.3596 - val_loss: 0.2701 - val_jaccard_index_instances: 0.4855
# Epoch 4/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2544 - jaccard_index_instances: 0.4144
#
# Epoch 00004: val_loss improved from 0.27014 to 0.23783, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 245ms/step - loss: 0.2544 - jaccard_index_instances: 0.4144 - val_loss: 0.2378 - val_jaccard_index_instances: 0.4555
# Epoch 5/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2305 - jaccard_index_instances: 0.4637
#
# Epoch 00005: val_loss improved from 0.23783 to 0.21801, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.2305 - jaccard_index_instances: 0.4637 - val_loss: 0.2180 - val_jaccard_index_instances: 0.5423
# Epoch 6/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2065 - jaccard_index_instances: 0.5258
#
# Epoch 00006: val_loss improved from 0.21801 to 0.19389, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 240ms/step - loss: 0.2065 - jaccard_index_instances: 0.5258 - val_loss: 0.1939 - val_jaccard_index_instances: 0.5339
# Epoch 7/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1841 - jaccard_index_instances: 0.5919
#
# Epoch 00007: val_loss improved from 0.19389 to 0.17663, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.1841 - jaccard_index_instances: 0.5919 - val_loss: 0.1766 - val_jaccard_index_instances: 0.5984
# Epoch 8/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1682 - jaccard_index_instances: 0.6226
#
# Epoch 00008: val_loss improved from 0.17663 to 0.15830, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 248ms/step - loss: 0.1682 - jaccard_index_instances: 0.6226 - val_loss: 0.1583 - val_jaccard_index_instances: 0.6535
# Epoch 9/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1604 - jaccard_index_instances: 0.6444
#
# Epoch 00009: val_loss improved from 0.15830 to 0.15162, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.1604 - jaccard_index_instances: 0.6444 - val_loss: 0.1516 - val_jaccard_index_instances: 0.6629
# Epoch 10/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1525 - jaccard_index_instances: 0.6567
#
# Epoch 00010: val_loss did not improve from 0.15162
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.1525 - jaccard_index_instances: 0.6567 - val_loss: 0.1671 - val_jaccard_index_instances: 0.6146
# Epoch 11/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1497 - jaccard_index_instances: 0.6623
#
# Epoch 00011: val_loss improved from 0.15162 to 0.13851, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 245ms/step - loss: 0.1497 - jaccard_index_instances: 0.6623 - val_loss: 0.1385 - val_jaccard_index_instances: 0.6958
# Epoch 12/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1414 - jaccard_index_instances: 0.6733
#
# Epoch 00012: val_loss improved from 0.13851 to 0.13493, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.1414 - jaccard_index_instances: 0.6733 - val_loss: 0.1349 - val_jaccard_index_instances: 0.7142
# Epoch 13/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1379 - jaccard_index_instances: 0.6833
#
# Epoch 00013: val_loss did not improve from 0.13493
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.1379 - jaccard_index_instances: 0.6833 - val_loss: 0.1388 - val_jaccard_index_instances: 0.7166
# Epoch 14/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1367 - jaccard_index_instances: 0.6846
#
# Epoch 00014: val_loss improved from 0.13493 to 0.12817, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.1367 - jaccard_index_instances: 0.6846 - val_loss: 0.1282 - val_jaccard_index_instances: 0.7199
# Epoch 15/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1333 - jaccard_index_instances: 0.6899
#
# Epoch 00015: val_loss did not improve from 0.12817
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.1333 - jaccard_index_instances: 0.6899 - val_loss: 0.1345 - val_jaccard_index_instances: 0.7102
# Epoch 16/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1290 - jaccard_index_instances: 0.6991
#
# Epoch 00016: val_loss did not improve from 0.12817
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1290 - jaccard_index_instances: 0.6991 - val_loss: 0.1283 - val_jaccard_index_instances: 0.7082
# Epoch 17/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1305 - jaccard_index_instances: 0.6959
#
# Epoch 00017: val_loss did not improve from 0.12817
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.1305 - jaccard_index_instances: 0.6959 - val_loss: 0.1310 - val_jaccard_index_instances: 0.7179
# Epoch 18/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1274 - jaccard_index_instances: 0.7011
#
# Epoch 00018: val_loss improved from 0.12817 to 0.12376, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 245ms/step - loss: 0.1274 - jaccard_index_instances: 0.7011 - val_loss: 0.1238 - val_jaccard_index_instances: 0.7350
# Epoch 19/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1246 - jaccard_index_instances: 0.7067
#
# Epoch 00019: val_loss did not improve from 0.12376
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1246 - jaccard_index_instances: 0.7067 - val_loss: 0.1327 - val_jaccard_index_instances: 0.7321
# Epoch 20/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1208 - jaccard_index_instances: 0.7144
#
# Epoch 00020: val_loss improved from 0.12376 to 0.11468, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.1208 - jaccard_index_instances: 0.7144 - val_loss: 0.1147 - val_jaccard_index_instances: 0.7421
# Epoch 21/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1183 - jaccard_index_instances: 0.7220
#
# Epoch 00021: val_loss did not improve from 0.11468
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.1183 - jaccard_index_instances: 0.7220 - val_loss: 0.1223 - val_jaccard_index_instances: 0.7318
# Epoch 22/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1179 - jaccard_index_instances: 0.7203
#
# Epoch 00022: val_loss did not improve from 0.11468
#
#
# 97/97 [==============================] - 26s 246ms/step - loss: 0.1179 - jaccard_index_instances: 0.7203 - val_loss: 0.1203 - val_jaccard_index_instances: 0.7215
# Epoch 23/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1120 - jaccard_index_instances: 0.7322
#
# Epoch 00023: val_loss improved from 0.11468 to 0.10920, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1120 - jaccard_index_instances: 0.7322 - val_loss: 0.1092 - val_jaccard_index_instances: 0.7530
# Epoch 24/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1121 - jaccard_index_instances: 0.7317
#
# Epoch 00024: val_loss did not improve from 0.10920
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.1121 - jaccard_index_instances: 0.7317 - val_loss: 0.1228 - val_jaccard_index_instances: 0.7502
# Epoch 25/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1100 - jaccard_index_instances: 0.7350
#
# Epoch 00025: val_loss improved from 0.10920 to 0.10499, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 240ms/step - loss: 0.1100 - jaccard_index_instances: 0.7350 - val_loss: 0.1050 - val_jaccard_index_instances: 0.7631
# Epoch 26/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1073 - jaccard_index_instances: 0.7425
#
# Epoch 00026: val_loss did not improve from 0.10499
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.1073 - jaccard_index_instances: 0.7425 - val_loss: 0.1050 - val_jaccard_index_instances: 0.7675
# Epoch 27/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1056 - jaccard_index_instances: 0.7441
#
# Epoch 00027: val_loss did not improve from 0.10499
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1056 - jaccard_index_instances: 0.7441 - val_loss: 0.1164 - val_jaccard_index_instances: 0.7467
# Epoch 28/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1037 - jaccard_index_instances: 0.7483
#
# Epoch 00028: val_loss did not improve from 0.10499
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1037 - jaccard_index_instances: 0.7483 - val_loss: 0.1077 - val_jaccard_index_instances: 0.7521
# Epoch 29/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1037 - jaccard_index_instances: 0.7502
#
# Epoch 00029: val_loss did not improve from 0.10499
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.1037 - jaccard_index_instances: 0.7502 - val_loss: 0.1102 - val_jaccard_index_instances: 0.7447
# Epoch 30/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1018 - jaccard_index_instances: 0.7533
#
# Epoch 00030: val_loss improved from 0.10499 to 0.09959, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.1018 - jaccard_index_instances: 0.7533 - val_loss: 0.0996 - val_jaccard_index_instances: 0.7734
# Epoch 31/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0986 - jaccard_index_instances: 0.7595
#
# Epoch 00031: val_loss improved from 0.09959 to 0.09844, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 241ms/step - loss: 0.0986 - jaccard_index_instances: 0.7595 - val_loss: 0.0984 - val_jaccard_index_instances: 0.7780
# Epoch 32/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0971 - jaccard_index_instances: 0.7636
#
# Epoch 00032: val_loss improved from 0.09844 to 0.09496, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 246ms/step - loss: 0.0971 - jaccard_index_instances: 0.7636 - val_loss: 0.0950 - val_jaccard_index_instances: 0.7860
# Epoch 33/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0973 - jaccard_index_instances: 0.7617
#
# Epoch 00033: val_loss did not improve from 0.09496
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.0973 - jaccard_index_instances: 0.7617 - val_loss: 0.0964 - val_jaccard_index_instances: 0.7819
# Epoch 34/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0954 - jaccard_index_instances: 0.7683
#
# Epoch 00034: val_loss improved from 0.09496 to 0.09239, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.0954 - jaccard_index_instances: 0.7683 - val_loss: 0.0924 - val_jaccard_index_instances: 0.7870
# Epoch 35/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0946 - jaccard_index_instances: 0.7665
#
# Epoch 00035: val_loss did not improve from 0.09239
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.0946 - jaccard_index_instances: 0.7665 - val_loss: 0.0931 - val_jaccard_index_instances: 0.7869
# Epoch 36/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0941 - jaccard_index_instances: 0.7684
#
# Epoch 00036: val_loss improved from 0.09239 to 0.09172, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 240ms/step - loss: 0.0941 - jaccard_index_instances: 0.7684 - val_loss: 0.0917 - val_jaccard_index_instances: 0.7886
# Epoch 37/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0913 - jaccard_index_instances: 0.7720
#
# Epoch 00037: val_loss improved from 0.09172 to 0.08932, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 241ms/step - loss: 0.0913 - jaccard_index_instances: 0.7720 - val_loss: 0.0893 - val_jaccard_index_instances: 0.7967
# Epoch 38/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0887 - jaccard_index_instances: 0.7812
#
# Epoch 00038: val_loss improved from 0.08932 to 0.08914, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 243ms/step - loss: 0.0887 - jaccard_index_instances: 0.7812 - val_loss: 0.0891 - val_jaccard_index_instances: 0.7929
# Epoch 39/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0902 - jaccard_index_instances: 0.7764
#
# Epoch 00039: val_loss did not improve from 0.08914
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.0902 - jaccard_index_instances: 0.7764 - val_loss: 0.0904 - val_jaccard_index_instances: 0.7906
# Epoch 40/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0866 - jaccard_index_instances: 0.7820
#
# Epoch 00040: val_loss improved from 0.08914 to 0.08693, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 241ms/step - loss: 0.0866 - jaccard_index_instances: 0.7820 - val_loss: 0.0869 - val_jaccard_index_instances: 0.8008
# Epoch 41/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0877 - jaccard_index_instances: 0.7818
#
# Epoch 00041: val_loss did not improve from 0.08693
#
#
# 97/97 [==============================] - 26s 244ms/step - loss: 0.0877 - jaccard_index_instances: 0.7818 - val_loss: 0.0933 - val_jaccard_index_instances: 0.7950
# Epoch 42/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0863 - jaccard_index_instances: 0.7868
#
# Epoch 00042: val_loss improved from 0.08693 to 0.08426, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.0863 - jaccard_index_instances: 0.7868 - val_loss: 0.0843 - val_jaccard_index_instances: 0.8040
# Epoch 43/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0828 - jaccard_index_instances: 0.7918
#
# Epoch 00043: val_loss improved from 0.08426 to 0.08356, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.0828 - jaccard_index_instances: 0.7918 - val_loss: 0.0836 - val_jaccard_index_instances: 0.8044
# Epoch 44/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0854 - jaccard_index_instances: 0.7874
#
# Epoch 00044: val_loss did not improve from 0.08356
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.0854 - jaccard_index_instances: 0.7874 - val_loss: 0.0890 - val_jaccard_index_instances: 0.7877
# Epoch 45/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0816 - jaccard_index_instances: 0.7934
#
# ...
#
# Epoch 00088: val_loss did not improve from 0.06293
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.0630 - jaccard_index_instances: 0.8346 - val_loss: 0.0636 - val_jaccard_index_instances: 0.8468
# Epoch 89/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0641 - jaccard_index_instances: 0.8320
#
# Epoch 00089: val_loss did not improve from 0.06293
#
#
# 97/97 [==============================] - 25s 243ms/step - loss: 0.0641 - jaccard_index_instances: 0.8320 - val_loss: 0.0634 - val_jaccard_index_instances: 0.8434
# Epoch 90/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0628 - jaccard_index_instances: 0.8324
#
# Epoch 00090: val_loss improved from 0.06293 to 0.06183, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.0628 - jaccard_index_instances: 0.8324 - val_loss: 0.0618 - val_jaccard_index_instances: 0.8476
# Epoch 91/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0637 - jaccard_index_instances: 0.8314
#
# Epoch 00091: val_loss improved from 0.06183 to 0.06164, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.0637 - jaccard_index_instances: 0.8314 - val_loss: 0.0616 - val_jaccard_index_instances: 0.8489
# Epoch 92/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0622 - jaccard_index_instances: 0.8346
#
# Epoch 00092: val_loss did not improve from 0.06164
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.0622 - jaccard_index_instances: 0.8346 - val_loss: 0.0630 - val_jaccard_index_instances: 0.8467
# Epoch 93/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0628 - jaccard_index_instances: 0.8333
#
# Epoch 00093: val_loss improved from 0.06164 to 0.06153, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 239ms/step - loss: 0.0628 - jaccard_index_instances: 0.8333 - val_loss: 0.0615 - val_jaccard_index_instances: 0.8487
# Epoch 94/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0623 - jaccard_index_instances: 0.8349
#
# Epoch 00094: val_loss did not improve from 0.06153
#
#
# 97/97 [==============================] - 25s 237ms/step - loss: 0.0623 - jaccard_index_instances: 0.8349 - val_loss: 0.0616 - val_jaccard_index_instances: 0.8491
# Epoch 95/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0642 - jaccard_index_instances: 0.8288
#
# Epoch 00095: val_loss did not improve from 0.06153
#
#
# 97/97 [==============================] - 26s 245ms/step - loss: 0.0642 - jaccard_index_instances: 0.8288 - val_loss: 0.0639 - val_jaccard_index_instances: 0.8414
# Epoch 96/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0609 - jaccard_index_instances: 0.8381
#
# Epoch 00096: val_loss improved from 0.06153 to 0.06128, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 244ms/step - loss: 0.0609 - jaccard_index_instances: 0.8381 - val_loss: 0.0613 - val_jaccard_index_instances: 0.8499
# Epoch 97/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0615 - jaccard_index_instances: 0.8360
#
# Epoch 00097: val_loss did not improve from 0.06128
#
#
# 97/97 [==============================] - 26s 246ms/step - loss: 0.0615 - jaccard_index_instances: 0.8360 - val_loss: 0.0645 - val_jaccard_index_instances: 0.8435
# Epoch 98/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0621 - jaccard_index_instances: 0.8359
#
# Epoch 00098: val_loss improved from 0.06128 to 0.06090, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 243ms/step - loss: 0.0621 - jaccard_index_instances: 0.8359 - val_loss: 0.0609 - val_jaccard_index_instances: 0.8514
# Epoch 99/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0617 - jaccard_index_instances: 0.8352
#
# Epoch 00099: val_loss improved from 0.06090 to 0.06002, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.0617 - jaccard_index_instances: 0.8352 - val_loss: 0.0600 - val_jaccard_index_instances: 0.8514
# Epoch 100/100
# 97/97 [==============================] - ETA: 0s - loss: 0.0598 - jaccard_index_instances: 0.8400
#
# Epoch 00100: val_loss did not improve from 0.06002
#
#
# 97/97 [==============================] - 25s 238ms/step - loss: 0.0598 - jaccard_index_instances: 0.8400 - val_loss: 0.0601 - val_jaccard_index_instances: 0.8531
# Creating training plots . . .
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:10,  1.30it/s]
#
#  14% 2/14 [00:00<00:04,  2.52it/s]
#
#  21% 3/14 [00:01<00:03,  3.61it/s]
#
#  29% 4/14 [00:01<00:02,  4.52it/s]
#
#  36% 5/14 [00:01<00:01,  4.55it/s]
#
#  43% 6/14 [00:01<00:01,  4.56it/s]
#
#  50% 7/14 [00:01<00:01,  4.54it/s]
#
#  57% 8/14 [00:02<00:01,  4.60it/s]
#
#  64% 9/14 [00:02<00:00,  5.22it/s]
#
#  71% 10/14 [00:02<00:00,  5.76it/s]
#
#  79% 11/14 [00:02<00:00,  6.40it/s]
#
#  86% 12/14 [00:02<00:00,  6.97it/s]
#
#  93% 13/14 [00:02<00:00,  7.27it/s]
#
# 100% 14/14 [00:03<00:00,  3.32it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:04,  3.24it/s]
#
#  14% 2/14 [00:00<00:02,  5.30it/s]
#
#  21% 3/14 [00:00<00:01,  6.63it/s]
#
#  29% 4/14 [00:00<00:01,  7.45it/s]
#
#  36% 5/14 [00:00<00:01,  8.06it/s]
#
#  43% 6/14 [00:00<00:00,  8.32it/s]
#
#  57% 8/14 [00:01<00:00,  9.06it/s]
#
#  64% 9/14 [00:01<00:00,  9.12it/s]
#
#  79% 11/14 [00:01<00:00,  9.29it/s]
#
#  86% 12/14 [00:01<00:00,  9.43it/s]
#
#  93% 13/14 [00:01<00:00,  9.32it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.18it/s]
#
#                                  Creating instances with watershed . . .
# Creating the central points . . .
#
#
# 100% 45/45 [00:00<00:00, 290374.89it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.3, 'fp': 7, 'tp': 38, 'fn': 13, 'precision': 0.8444444444444444, 'recall': 0.7450980392156863, 'accuracy': 0.6551724137931034, 'f1': 0.7916666666666666, 'n_true': 51, 'n_pred': 45, 'mean_true_score': 0.5103392507515702, 'mean_matched_score': 0.6849289944297389, 'panoptic_quality': 0.5422354539235433}
# Creating the image with a summary of detected points and false positives with colors . . .
# Painting TPs and FNs . . .
#
#
#   0% 0/45 [00:00<?, ?it/s]
#
# 100% 45/45 [00:00<00:00, 315.05it/s]
#
#
# 100% 6/6 [00:00<00:00, 322.57it/s]
# Painting FPs . . .
#
#
# 100% 13/13 [00:00<00:00, 323.63it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          DatasetMatching: {'criterion': 'iou', 'thresh': 0.5, 'fp': 18, 'tp': 27, 'fn': 24, 'precision': 0.6, 'recall': 0.5294117647058824, 'accuracy': 0.391304347826087, 'f1': 0.5625, 'n_true': 51, 'n_pred': 45, 'mean_true_score': 0.42200032402487364, 'mean_matched_score': 0.7971117231580946, 'panoptic_quality': 0.4483753442764282}
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.75, 'fp': 26, 'tp': 19, 'fn': 32, 'precision': 0.4222222222222222, 'recall': 0.37254901960784315, 'accuracy': 0.24675324675324675, 'f1': 0.3958333333333333, 'n_true': 51, 'n_pred': 45, 'mean_true_score': 0.32421194338331033, 'mean_matched_score': 0.8702531111867804, 'panoptic_quality': 0.34447518984476727}
#
# 100% 1/1 [00:07<00:00,  7.20s/it]
#  33% 1/3 [00:07<00:14,  7.24s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  5.11it/s]
#
#  14% 2/14 [00:00<00:02,  5.13it/s]
#
#  21% 3/14 [00:00<00:02,  5.07it/s]
#
#  29% 4/14 [00:00<00:01,  5.57it/s]
#
#  36% 5/14 [00:00<00:01,  5.41it/s]
#
#  43% 6/14 [00:01<00:01,  5.85it/s]
#
#  50% 7/14 [00:01<00:01,  6.27it/s]
#
#  57% 8/14 [00:01<00:01,  5.86it/s]
#
#  64% 9/14 [00:01<00:00,  5.58it/s]
#
#  71% 10/14 [00:01<00:00,  6.22it/s]
#
#  79% 11/14 [00:01<00:00,  6.83it/s]
#
#  86% 12/14 [00:01<00:00,  7.33it/s]
#
#  93% 13/14 [00:02<00:00,  7.72it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.54it/s]
#
#  14% 2/14 [00:00<00:01,  9.48it/s]
#
#  21% 3/14 [00:00<00:01,  9.30it/s]
#
#  29% 4/14 [00:00<00:01,  9.55it/s]
#
#  43% 6/14 [00:00<00:00,  9.83it/s]
#
#  50% 7/14 [00:00<00:00,  9.64it/s]
#
#  57% 8/14 [00:00<00:00,  9.66it/s]
#
#  64% 9/14 [00:00<00:00,  9.69it/s]
#
#  71% 10/14 [00:01<00:00,  9.64it/s]
#
#  86% 12/14 [00:01<00:00,  9.88it/s]
#
# 100% 14/14 [00:01<00:00,  9.87it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.34it/s]
#
#                                  Creating instances with watershed . . .
# Creating the central points . . .
#
#
# 100% 14/14 [00:00<00:00, 187604.65it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.3, 'fp': 1, 'tp': 13, 'fn': 7, 'precision': 0.9285714285714286, 'recall': 0.65, 'accuracy': 0.6190476190476191, 'f1': 0.7647058823529411, 'n_true': 20, 'n_pred': 14, 'mean_true_score': 0.4312281131744385, 'mean_matched_score': 0.6634278664222131, 'panoptic_quality': 0.5073271919699276}
# Creating the image with a summary of detected points and false positives with colors . . .
# Painting TPs and FNs . . .
#
#
# 100% 14/14 [00:00<00:00, 315.05it/s]
#
#
# 100% 6/6 [00:00<00:00, 306.65it/s]
# Painting FPs . . .
#
#
# 100% 7/7 [00:00<00:00, 330.18it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          DatasetMatching: {'criterion': 'iou', 'thresh': 0.5, 'fp': 4, 'tp': 10, 'fn': 10, 'precision': 0.7142857142857143, 'recall': 0.5, 'accuracy': 0.4166666666666667, 'f1': 0.5882352941176471, 'n_true': 20, 'n_pred': 14, 'mean_true_score': 0.3685505151748657, 'mean_matched_score': 0.7371010303497314, 'panoptic_quality': 0.43358884138219494}
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.75, 'fp': 10, 'tp': 4, 'fn': 16, 'precision': 0.2857142857142857, 'recall': 0.2, 'accuracy': 0.13333333333333333, 'f1': 0.23529411764705882, 'n_true': 20, 'n_pred': 14, 'mean_true_score': 0.1769230604171753, 'mean_matched_score': 0.8846153020858765, 'panoptic_quality': 0.2081447769613827}
#
# 100% 1/1 [00:04<00:00,  4.38s/it]
#  67% 2/3 [00:11<00:05,  5.58s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  5.12it/s]
#
#  14% 2/14 [00:00<00:01,  6.69it/s]
#
#  21% 3/14 [00:00<00:01,  7.69it/s]
#
#  29% 4/14 [00:00<00:01,  8.11it/s]
#
#  36% 5/14 [00:00<00:01,  8.12it/s]
#
#  43% 6/14 [00:00<00:01,  7.84it/s]
#
#  50% 7/14 [00:01<00:01,  6.47it/s]
#
#  57% 8/14 [00:01<00:00,  6.69it/s]
#
#  64% 9/14 [00:01<00:00,  6.82it/s]
#
#  71% 10/14 [00:01<00:00,  5.93it/s]
#
#  79% 11/14 [00:01<00:00,  6.27it/s]
#
#  86% 12/14 [00:01<00:00,  6.52it/s]
#
#  93% 13/14 [00:01<00:00,  6.84it/s]
#
# 100% 14/14 [00:02<00:00,  6.98it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  7.64it/s]
#
#  14% 2/14 [00:00<00:01,  7.75it/s]
#
#  21% 3/14 [00:00<00:01,  8.22it/s]
#
#  29% 4/14 [00:00<00:01,  7.96it/s]
#
#  36% 5/14 [00:00<00:01,  7.54it/s]
#
#  43% 6/14 [00:00<00:01,  7.66it/s]
#
#  50% 7/14 [00:00<00:00,  7.72it/s]
#
#  57% 8/14 [00:01<00:00,  7.86it/s]
#
#  64% 9/14 [00:01<00:00,  8.09it/s]
#
#  71% 10/14 [00:01<00:00,  8.42it/s]
#
#  79% 11/14 [00:01<00:00,  8.72it/s]
#
#  93% 13/14 [00:01<00:00,  8.97it/s]
#
# 100% 14/14 [00:01<00:00,  8.96it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.42it/s]
#
#                                  Creating instances with watershed . . .
# Creating the central points . . .
#
#
# 100% 177/177 [00:00<00:00, 493939.99it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.3, 'fp': 28, 'tp': 149, 'fn': 15, 'precision': 0.8418079096045198, 'recall': 0.9085365853658537, 'accuracy': 0.7760416666666666, 'f1': 0.873900293255132, 'n_true': 164, 'n_pred': 177, 'mean_true_score': 0.6591299103527535, 'mean_matched_score': 0.7254852704553796, 'panoptic_quality': 0.6340017906032349}
# Creating the image with a summary of detected points and false positives with colors . . .
# Painting TPs and FNs . . .
#
#
#   0% 0/164 [00:00<?, ?it/s]
#
#  20% 33/164 [00:00<00:00, 318.66it/s]
#
#  40% 65/164 [00:00<00:00, 297.71it/s]
#
#  58% 95/164 [00:00<00:00, 296.59it/s]
#
#  77% 127/164 [00:00<00:00, 305.39it/s]
#
# 100% 164/164 [00:00<00:00, 306.25it/s]
#
#
# 0it [00:00, ?it/s]
# Painting FPs . . .
#
#
# 100% 28/28 [00:00<00:00, 329.65it/s]
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          DatasetMatching: {'criterion': 'iou', 'thresh': 0.5, 'fp': 45, 'tp': 132, 'fn': 32, 'precision': 0.7457627118644068, 'recall': 0.8048780487804879, 'accuracy': 0.631578947368421, 'f1': 0.7741935483870968, 'n_true': 164, 'n_pred': 177, 'mean_true_score': 0.6134998507615996, 'mean_matched_score': 0.7622270873098662, 'panoptic_quality': 0.5901112934011867}
# DatasetMatching: {'criterion': 'iou', 'thresh': 0.75, 'fp': 88, 'tp': 89, 'fn': 75, 'precision': 0.5028248587570622, 'recall': 0.5426829268292683, 'accuracy': 0.3531746031746032, 'f1': 0.5219941348973607, 'n_true': 164, 'n_pred': 177, 'mean_true_score': 0.4506196743104516, 'mean_matched_score': 0.8303553549091468, 'panoptic_quality': 0.433440625143191}
#
# 100% 1/1 [00:05<00:00,  5.19s/it]
# 100% 3/3 [00:16<00:00,  5.63s/it]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 25.225274634361266
# Epoch number: 100
# Train time (s): 2522.5274634361267
# Train loss: 0.059787966310977936
# Train jaccard_index_instances: 0.8400071263313293
# Validation loss: 0.06001831218600273
# Validation jaccard_index_instances: 0.8531129956245422
# Loss (per patch): 0.03169908603354369
# Test Foreground IoU (per patch): 0.4304502348840972
#
# Test Foreground IoU (merge patches): 0.8560638048218046
# Test Overall IoU (merge patches): 0.9224683783271154
#
# Instance segmentation specific metrics:
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=36, tp=200, fn=35, precision=0.847457627118644, recall=0.851063829787234, accuracy=0.7380073800738007, f1=0.8492569002123143, n_true=235, n_pred=236, mean_true_score=0.6074432738283847, mean_matched_score=0.7137458467483521, panoptic_quality=0.6061535853489189, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=67, tp=169, fn=66, precision=0.7161016949152542, recall=0.7191489361702128, accuracy=0.5596026490066225, f1=0.7176220806794055, n_true=235, n_pred=236, mean_true_score=0.551093627036886, mean_matched_score=0.7663136233944865, panoptic_quality=0.5499235768733257, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=124, tp=112, fn=123, precision=0.4745762711864407, recall=0.4765957446808511, accuracy=0.31197771587743733, f1=0.47558386411889597, n_true=235, n_pred=236, mean_true_score=0.39989317833109106, mean_matched_score=0.8390615795339856, panoptic_quality=0.3990441482284773, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **Jaccard index or Intersection over Union** (IoU) metric is a method that can be used to quantify the overlap between the target mask and your prediction output. **Therefore, the closer to 1, the better the performance.** This metric can be used to assess the quality of your model to accurately predict cells.

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and IoU vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_jaccard_index_instances.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Intersection over Union (IoU) vs epoch number', fontdict = {'fontsize':22})

# %% [markdown]
# ## **Visualize instance segmentation results**

# %%
#@markdown ###Play to visualize results in 3D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact, fixed
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
instance_results = os.path.join(final_results, "per_image_instances")

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(aux)
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(aux)

# function to show results in 3D within a widget
def scroll_in_z(z, j):

    plt.figure(figsize=(25,5))
    # Source
    plt.subplot(1,4,1)
    plt.axis('off')
    plt.imshow(test_samples[j][z-1], cmap='gray')
    plt.title('Source (z = ' + str(z) + ')', fontsize=15)

    # Target (Ground-truth)
    plt.subplot(1,4,2)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Ground truth (z = ' + str(z) + ')', fontsize=15)

    # Prediction
    plt.subplot(1,4,3)
    plt.axis('off')
    plt.imshow(test_sample_preds[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Prediction (z = ' + str(z) + ')', fontsize=15)
    
    # Overlay
    plt.subplot(1,4,4)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap='Greens')
    plt.imshow(test_sample_preds[j][z-1], alpha=0.5, cmap='Purples')
    plt.title('Overlay (z = ' + str(z) + ')', fontsize=15)

for j in range(samples_to_show):
    interact(scroll_in_z, z=widgets.IntSlider(min=1, max=test_sample_gt[j].shape[0], step=1, value=test_sample_gt[j].shape[0]//2), j=fixed(j));
# Out:
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…

# %%
#@markdown ###Play to display the path to the output files (one 3D TIFF label image for each input image).

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

instance_results = os.path.join(final_results, "per_image_instances")

print("Output paths:")
print("    Instance segmentation files are in {}".format(instance_results))
# Out:
# Output paths:
#     Instance segmentation files are in /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances

# %% [markdown]
# ## **Download instance segmentation results**

# %%
#@markdown ###Play to download a zip file with all instance segmentation results in test.

from google.colab import files

# !zip -q -j /content/instance_segmentation_results.zip $instance_results/*.tif

files.download("/content/instance_segmentation_results.zip")

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))

# %% [markdown]
# ## **Advanced options**

# %% [markdown]
# ### **Adjust marker-controlled watershed threshold values**

# %%
#@markdown ### Marker-controlled watershed parameters:
binary_mask_seed_threshold =  0.2#@param {type:"number"}
contour_threshold =  0.1 #@param {type:"number"}
central_point_threshold =  0.1 #@param {type:"number"}
binary_mask_grow_threshold =  0.1#@param {type:"number"}
distance_seed_threshold =  1.5 #@param {type:"number"}

# %%
#@markdown ### Play to create inference YAML with new parameters
# Transcribe model architecture

biapy_config_inference = biapy_config

# set the training to false to peform inference
biapy_config_inference['TRAIN']['ENABLE'] = False

biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_BINARY_MASK'] = binary_mask_seed_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_CONTOUR'] = contour_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_POINTS'] = central_point_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_FOREGROUND'] = binary_mask_grow_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_DISTANCE'] = distance_seed_threshold

# save file
inference_file = "/content/"+str(job_name)+"_inference.yaml"

with open( inference_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Inference configuration finished.")
# Out:
# Inference configuration finished.

# %% [markdown]
# ### **Run inference**

# %%
#@markdown ### Play to run inference on test with the new parameters

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'_inference.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2023-02-10 16:20:51
# Arguments: Namespace(config='/content/my_3d_instance_segmentation_inference.yaml', gpu='0', name='my_3d_instance_segmentation', result_dir='/content/output', run_id=1)
# Job: my_3d_instance_segmentation_1
# Python       : 3.8.10 (default, Nov 14 2022, 12:59:47)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     MINIMUM_FOREGROUND_PER: -1.0
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [3072, 768]
#   UNETR_NUM_HEADS: 4
#   UNETR_TOKEN_SIZE: 16
#   UNETR_VIT_HIDD_MULT: 3
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     AS_3D_STACK_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/as_3d_stack_post_processing
#     DET_ASSOC_POINTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/point_associations
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CENTRAL_POINT_DILATION: 3
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH_BINARY_MASK: 0.2
#     DATA_MW_TH_CONTOUR: 0.1
#     DATA_MW_TH_DISTANCE: 1.5
#     DATA_MW_TH_DIST_FOREGROUND: 1.2
#     DATA_MW_TH_FOREGROUND: 0.1
#     DATA_MW_TH_POINTS: 0.5
#     DATA_REMOVE_AFTER_MW: False
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ_AFTER: 100
#     DATA_REMOVE_SMALL_OBJ_BEFORE: 10
#     ERODE_AND_DILATE_FOREGROUND: False
#     FORE_DILATION_RADIUS: 5
#     FORE_EROSION_RADIUS: 5
#     SEED_MORPH_RADIUS: []
#     SEED_MORPH_SEQUENCE: []
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   ANALIZE_2D_IMGS_AS_3D_STACK: False
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     DET_WATERSHED: False
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [10.0]
#     REPARE_LARGE_BLOBS_SIZE: -1
#     VORONOI_ON_MASK: False
#     WATERSHED_CIRCULARITY: -1.0
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: False
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ####################
# #  PRE-PROCESSING  #
# ####################
#
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BC_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BC_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BC_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BC_thick
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# #################
# #  BUILD MODEL  #
# #################
#
# 2023-02-10 16:20:53.024653: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 32, 64, 64, 1)]          0                 []
#
#  conv3d_1 (Conv3D)                               (None, 32, 64, 64, 36)           1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, 32, 64, 64, 36)           0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, 32, 64, 64, 36)           72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, 32, 64, 64, 36)           35028             ['elu[0][0]']
#
#  add (Add)                                       (None, 32, 64, 64, 36)           0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, 32, 32, 32, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, 32, 32, 32, 36)           0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, 32, 32, 32, 48)           46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, 32, 32, 32, 48)           1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, 32, 32, 32, 48)           62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, 32, 16, 16, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, 32, 16, 16, 48)           0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, 32, 16, 16, 64)           83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, 32, 16, 16, 64)           3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, 32, 16, 16, 64)           110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, 32, 32, 32, 48)           24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, 32, 32, 32, 96)           0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, 32, 32, 32, 96)           0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, 32, 32, 32, 48)           124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, 32, 32, 32, 48)           4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, 32, 32, 32, 48)           62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, 32, 64, 64, 36)           13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, 32, 64, 64, 72)           0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, 32, 64, 64, 72)           0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, 32, 64, 64, 36)           70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, 32, 64, 64, 36)           2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, 32, 64, 64, 36)           35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, 32, 64, 64, 2)            578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:04<01:02,  4.81s/it]
#
#  14% 2/14 [00:04<00:25,  2.09s/it]
#
#  21% 3/14 [00:05<00:13,  1.21s/it]
#
#  29% 4/14 [00:05<00:07,  1.28it/s]
#
#  36% 5/14 [00:05<00:04,  1.82it/s]
#
#  43% 6/14 [00:05<00:03,  2.39it/s]
#
#  50% 7/14 [00:05<00:02,  2.95it/s]
#
#  57% 8/14 [00:05<00:01,  3.60it/s]
#
#  64% 9/14 [00:06<00:01,  4.26it/s]
#
#  71% 10/14 [00:06<00:00,  4.44it/s]
#
#  79% 11/14 [00:06<00:00,  4.76it/s]
#
#  86% 12/14 [00:06<00:00,  5.14it/s]
#
#  93% 13/14 [00:06<00:00,  5.64it/s]
#
# 100% 14/14 [00:07<00:00,  3.46it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:07,  1.82it/s]
#
#  14% 2/14 [00:00<00:04,  2.90it/s]
#
#  21% 3/14 [00:00<00:02,  4.00it/s]
#
#  29% 4/14 [00:01<00:02,  4.57it/s]
#
#  36% 5/14 [00:01<00:01,  4.71it/s]
#
#  43% 6/14 [00:01<00:01,  4.95it/s]
#
#  50% 7/14 [00:01<00:01,  4.54it/s]
#
#  57% 8/14 [00:01<00:01,  4.62it/s]
#
#  64% 9/14 [00:02<00:01,  4.53it/s]
#
#  71% 10/14 [00:02<00:00,  4.28it/s]
#
#  79% 11/14 [00:02<00:00,  4.97it/s]
#
#  86% 12/14 [00:02<00:00,  4.94it/s]
#
#  93% 13/14 [00:03<00:00,  4.50it/s]
#
# 100% 14/14 [00:03<00:00,  5.14it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  1.70it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.5, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.75, fp=47, tp=25, fn=26, precision=0.3472222222222222, recall=0.49019607843137253, accuracy=0.25510204081632654, f1=0.4065040650406504, n_true=51, n_pred=72, mean_true_score=0.3875579086004519, mean_matched_score=0.7906181335449218, panoptic_quality=0.3213894851808626))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.5, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.75, fp=47, tp=25, fn=26, precision=0.3472222222222222, recall=0.49019607843137253, accuracy=0.25510204081632654, f1=0.4065040650406504, n_true=51, n_pred=72, mean_true_score=0.3875579086004519, mean_matched_score=0.7906181335449218, panoptic_quality=0.3213894851808626))
#
# 100% 1/1 [00:13<00:00, 13.98s/it]
#  33% 1/3 [00:13<00:27, 14.00s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  4.87it/s]
#
#  14% 2/14 [00:00<00:03,  3.80it/s]
#
#  21% 3/14 [00:00<00:03,  3.66it/s]
#
#  29% 4/14 [00:00<00:02,  4.47it/s]
#
#  36% 5/14 [00:01<00:01,  5.34it/s]
#
#  43% 6/14 [00:01<00:01,  5.26it/s]
#
#  50% 7/14 [00:01<00:01,  5.88it/s]
#
#  57% 8/14 [00:01<00:00,  6.36it/s]
#
#  64% 9/14 [00:01<00:00,  6.89it/s]
#
#  71% 10/14 [00:01<00:00,  7.22it/s]
#
#  79% 11/14 [00:01<00:00,  7.38it/s]
#
#  86% 12/14 [00:02<00:00,  6.49it/s]
#
#  93% 13/14 [00:02<00:00,  6.76it/s]
#
# 100% 14/14 [00:02<00:00,  7.14it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  7.74it/s]
#
#  14% 2/14 [00:00<00:01,  8.02it/s]
#
#  29% 4/14 [00:00<00:01,  9.35it/s]
#
#  43% 6/14 [00:00<00:00,  9.85it/s]
#
#  57% 8/14 [00:00<00:00, 10.03it/s]
#
#  71% 10/14 [00:01<00:00, 10.25it/s]
#
#  86% 12/14 [00:01<00:00, 10.20it/s]
#
# 100% 14/14 [00:01<00:00, 10.28it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.36it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.75, fp=15, tp=14, fn=6, precision=0.4827586206896552, recall=0.7, accuracy=0.4, f1=0.5714285714285714, n_true=20, n_pred=29, mean_true_score=0.5661441326141358, mean_matched_score=0.8087773323059082, panoptic_quality=0.46215847560337614))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.75, fp=15, tp=14, fn=6, precision=0.4827586206896552, recall=0.7, accuracy=0.4, f1=0.5714285714285714, n_true=20, n_pred=29, mean_true_score=0.5661441326141358, mean_matched_score=0.8087773323059082, panoptic_quality=0.46215847560337614))
#
# 100% 1/1 [00:04<00:00,  4.45s/it]
#  67% 2/3 [00:18<00:08,  8.39s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.31it/s]
#
#  14% 2/14 [00:00<00:01,  9.49it/s]
#
#  21% 3/14 [00:00<00:01,  9.44it/s]
#
#  29% 4/14 [00:00<00:01,  9.28it/s]
#
#  36% 5/14 [00:00<00:00,  9.32it/s]
#
#  43% 6/14 [00:00<00:00,  9.29it/s]
#
#  50% 7/14 [00:00<00:00,  9.08it/s]
#
#  57% 8/14 [00:00<00:00,  9.28it/s]
#
#  64% 9/14 [00:00<00:00,  9.44it/s]
#
#  71% 10/14 [00:01<00:00,  9.57it/s]
#
#  79% 11/14 [00:01<00:00,  9.63it/s]
#
#  86% 12/14 [00:01<00:00,  9.71it/s]
#
#  93% 13/14 [00:01<00:00,  9.77it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#  14% 2/14 [00:00<00:01, 10.22it/s]
#
#  29% 4/14 [00:00<00:00, 10.28it/s]
#
#  43% 6/14 [00:00<00:00, 10.37it/s]
#
#  57% 8/14 [00:00<00:00, 10.47it/s]
#
#  71% 10/14 [00:00<00:00, 10.56it/s]
#
#  86% 12/14 [00:01<00:00, 10.49it/s]
#
# 100% 14/14 [00:01<00:00, 10.41it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.39it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6773291331965748, mean_matched_score=0.6773291331965748, panoptic_quality=0.6773291331965748), Matching(criterion='iou', thresh=0.5, fp=3, tp=161, fn=3, precision=0.9817073170731707, recall=0.9817073170731707, accuracy=0.9640718562874252, f1=0.9817073170731707, n_true=164, n_pred=164, mean_true_score=0.668599710231874, mean_matched_score=0.6810580899256357, panoptic_quality=0.668599710231874), Matching(criterion='iou', thresh=0.75, fp=130, tp=34, fn=130, precision=0.2073170731707317, recall=0.2073170731707317, accuracy=0.11564625850340136, f1=0.2073170731707317, n_true=164, n_pred=164, mean_true_score=0.1595983970456007, mean_matched_score=0.7698275622199563, panoptic_quality=0.1595983970456007))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6773291331965748, mean_matched_score=0.6773291331965748, panoptic_quality=0.6773291331965748), Matching(criterion='iou', thresh=0.5, fp=3, tp=161, fn=3, precision=0.9817073170731707, recall=0.9817073170731707, accuracy=0.9640718562874252, f1=0.9817073170731707, n_true=164, n_pred=164, mean_true_score=0.668599710231874, mean_matched_score=0.6810580899256357, panoptic_quality=0.668599710231874), Matching(criterion='iou', thresh=0.75, fp=130, tp=34, fn=130, precision=0.2073170731707317, recall=0.2073170731707317, accuracy=0.11564625850340136, f1=0.2073170731707317, n_true=164, n_pred=164, mean_true_score=0.1595983970456007, mean_matched_score=0.7698275622199563, panoptic_quality=0.1595983970456007))
#
# 100% 1/1 [00:03<00:00,  3.53s/it]
# 100% 3/3 [00:21<00:00,  7.33s/it]
# #############
# #  RESULTS  #
# #############
#
# Loss (per patch): 0.0740075225447431
# Test Foreground IoU (per patch): 0.36868306001027423
#
# Test Foreground IoU (merge patches): 0.7598582573718332
# Test Overall IoU (merge patches): 0.8664509508783474
#
# Instance segmentation specific metrics:
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.6948487748491003, mean_matched_score=0.6978182140578572, panoptic_quality=0.6531578483581543, by_image=False)
# IoU (post-processing) TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.6948487748491003, mean_matched_score=0.6978182140578572, panoptic_quality=0.6531578483581543, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=34, tp=231, fn=4, precision=0.8716981132075472, recall=0.9829787234042553, accuracy=0.8587360594795539, f1=0.924, n_true=235, n_pred=265, mean_true_score=0.6887567520141602, mean_matched_score=0.7006832758585612, panoptic_quality=0.6474313468933105, by_image=False)
# IoU (post-processing) TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=34, tp=231, fn=4, precision=0.8716981132075472, recall=0.9829787234042553, accuracy=0.8587360594795539, f1=0.924, n_true=235, n_pred=265, mean_true_score=0.6887567520141602, mean_matched_score=0.7006832758585612, panoptic_quality=0.6474313468933105, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=192, tp=73, fn=162, precision=0.27547169811320754, recall=0.31063829787234043, accuracy=0.17096018735362997, f1=0.292, n_true=235, n_pred=265, mean_true_score=0.24367009832503947, mean_matched_score=0.7844174398134832, panoptic_quality=0.2290498924255371, by_image=False)
# IoU (post-processing) TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=192, tp=73, fn=162, precision=0.27547169811320754, recall=0.31063829787234043, accuracy=0.17096018735362997, f1=0.292, n_true=235, n_pred=265, mean_true_score=0.24367009832503947, mean_matched_score=0.7844174398134832, panoptic_quality=0.2290498924255371, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %%
#@markdown ###Play to visualize results in 3D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact, fixed
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
instance_results = os.path.join(final_results, "per_image_instances")

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(aux)
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(aux)

# function to show results in 3D within a widget
def scroll_in_z(z, j):

    plt.figure(figsize=(25,5))
    # Source
    plt.subplot(1,4,1)
    plt.axis('off')
    plt.imshow(test_samples[j][z-1], cmap='gray')
    plt.title('Source (z = ' + str(z) + ')', fontsize=15)

    # Target (Ground-truth)
    plt.subplot(1,4,2)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Ground truth (z = ' + str(z) + ')', fontsize=15)

    # Prediction
    plt.subplot(1,4,3)
    plt.axis('off')
    plt.imshow(test_sample_preds[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Prediction (z = ' + str(z) + ')', fontsize=15)
    
    # Overlay
    plt.subplot(1,4,4)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap='Greens')
    plt.imshow(test_sample_preds[j][z-1], alpha=0.5, cmap='Purples')
    plt.title('Overlay (z = ' + str(z) + ')', fontsize=15)

for j in range(samples_to_show):
    interact(scroll_in_z, z=widgets.IntSlider(min=1, max=test_sample_gt[j].shape[0], step=1, value=test_sample_gt[j].shape[0]//2), j=fixed(j));
# Out:
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…

# %% [markdown]
# ## **Acknowledgments**
# We would like to acknowledge the inspiration provided by the excellent [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki). In particular, we have reused some of their descriptions of metrics and parameters, as well as their 3D visualization widget code from their [U-Net 3D notebook](https://colab.research.google.com/github/HenriquesLab/ZeroCostDL4Mic/blob/master/Colab_notebooks/U-Net_3D_ZeroCostDL4Mic.ipynb). We would also like to extend our special thanks to [Estibaliz Gomez-de-Mariscal](https://scholar.google.es/citations?user=gsg-TAUAAAAJ) for her support and insightful comments, which helped us to improve this notebook.
