# %% [markdown]
# # **3D Instance Segmentation pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **3D instance segmentation** of microscopy data.
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume.gif' width='300px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume_mask.gif' width='300px'/>
# <figcaption><b>Figure 1</b>: Example of a 3D instance segmentation problem. From left to right: 3D electron microscopy image and its corresponding nuclei instance labels (source: NucMM, <a href="https://link.springer.com/chapter/10.1007/978-3-030-87193-2_16">Lin et al, 2021</a>).</figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their corresponding instance label images,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the segmentation results** to your local machine.
#
# **Disclaimer:** the structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 3D images to train the model.
# * **Training label images**: with the instance-label 3D images to train the model. Their number and sizes must match those of the training raw images.
# * **Test raw images**: with the raw 3D images to test the model.
# * **Test label images**: with the instance-label 3D images to test the model. Their number and sizes must match those of the validation raw images.
# * **Output folder**: a path to store the segmentation results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing one result **TIFF image** for each test image. The result images contain the instances of the "objects" of interest as predicted by our pipeline.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3'**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`.

# %%
#@markdown ##Play the cell to upload local files (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/x
# %cd /content/input/train/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (train label images)

from google.colab import files
# !mkdir -p /content/input/train/y 
# %cd /content/input/train/y
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test raw images)

from google.colab import files
# !mkdir -p /content/input/val/x
# %cd /content/input/val/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test label images)

from google.colab import files
# !mkdir -p /content/input/val/y
# %cd /content/input/val/y
uploaded = files.upload()
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use the [3D demo dataset from the StarDist 0.3.0 release](https://github.com/mpicbg-csbd/stardist/releases/download/0.3.0/demo3D.zip), publicly available online.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')

# !curl -L -s -o demo3D.zip 'https://drive.google.com/uc?id=1fdL35ZTNw5hhiKau1gadaGu-rc5ZU_C7&confirm=t'

# !unzip -q demo3D.zip
# !rm demo3D.zip

print( 'Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train/x', train_data_mask_path as '/content/data/train/y', test_data_path as '/content/data/test/x', test_data_mask_path as '/content/data/test/y', and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train/x' #@param {type:"string"}
#@markdown #####Path to train instances
train_data_mask_path = '/content/data/train/y' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test/x' #@param {type:"string"}
#@markdown #####Path to test instances
test_data_mask_path = '/content/data/test/y' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone https://github.com/danifranco/BiaPy.git
    # !git checkout 81072f1c0734412be3daf1312bf1c6bb139b6b66 &> /dev/null
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Cloning into 'BiaPy'...
# remote: Enumerating objects: 15364, done.
# remote: Counting objects: 100% (1433/1433), done.
# remote: Compressing objects: 100% (485/485), done.
# remote: Total 15364 (delta 1007), reused 1351 (delta 931), pack-reused 13931
# Receiving objects: 100% (15364/15364), 819.07 MiB | 29.37 MiB/s, done.
# Resolving deltas: 100% (8276/8276), done.

# %% [markdown]
# ## **Configure and train the DNN model**
# [BiaPy](https://biapy.readthedocs.io/en/latest/) uses a bottom-up approach to instance segmentation in 2D and 3D by learning the binary masks, contours, and
# (optionally) the distance map of the objects of interest, to be later post-processed using marker-controlled watershed (see [Wei et al. 2020](https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7)).
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/cysto_instance_bcd_scheme.svg' width='300px'/>
# <figcaption><b>Figure 2</b>: Example of multi-channel representation for instance segmentation. Label instances can be learnt by predicting their contours, binary masks and distance maps (<a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>).</figcaption></center>
# </figure>
#
# The use of these representations and other pipeline hyperparameters can be configured by editing the YAML configuration file or (easier) by running the next cell.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
# #### **Basic training parameters**
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, preliminary results can already be observed after 50 epochs, but better results are obtained when running the model longer. **Default value: 100**
#
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. **Default value: 10**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: U-Net, Residual U-Net (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1))  **Default value: Residual U-Net**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 8**
#
# * **`patch_size_xy`:** Input the XY size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 64**
#
# * **`patch_size_z`:** Input the Z size of the patches use to train your model (length in pixels in Z). The value should be smaller or equal to the dimensions of the image. **Default value: 32**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 1**
#
# * **`anisotropic_data`:** Select if your image data is anisotropic (lower resolution in Z with respect to XY). The model downsampling step size will be set accordingly. **Default value: True**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: ADAM**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.0001**
#
# * **`problem_representation`:** Select the type of representation that the model must learn to identify the instances. Options: "Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask" (see <a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>). **Default value: "Binary mask + Contours"**
#
# * **`test_time_augmentation`:** Select to apply augmentation (flips and rotations) at test time. It usually provides more robust results but uses more time to produce each result. **Default value: False**

# %%
#@markdown ###Name of the model:
model_name = "my_3d_instance_segmentation" #@param {type:"string"}

#@markdown ### Basic training parameters:
number_of_epochs =  100#@param {type:"number"}
percentage_validation =  10 #@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "Residual U-Net" #@param ["U-Net", "Residual U-Net"]

batch_size =  2#@param {type:"number"}
patch_size_xy = 64 #@param {type:"number"}
patch_size_z = 32 #@param {type:"number"}

input_channels = 1 #@param {type:"number"}
anisotropic_data = True #@param {type:"boolean"}

optimizer = "ADAM" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.0001 #@param {type:"number"}

problem_representation = "Binary mask + Contours" #@param ["Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask"]

test_time_augmentation = False #@param {type:"boolean"}

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# remove template file it is exists
template_file = 'resunet_3d_instances.yaml'
if os.path.exists( template_file ):
    os.remove( template_file )

# Download template file 
# !wget https://raw.githubusercontent.com/danifranco/BiaPy/master/templates/instance_segmentation/resunet_3d_instances.yaml &> /dev/null

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_path))
if not os.path.exists(train_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_mask_path)
ids = sorted(next(os.walk(train_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_mask_path))

# Check folders before modifying the .yaml file
if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_path))
if not os.path.exists(test_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_mask_path)
ids = sorted(next(os.walk(test_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_mask_path))


# open template configuration file
import yaml
with open( template_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['TRAIN']['MASK_PATH'] = train_data_mask_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path
biapy_config['DATA']['TEST']['MASK_PATH'] = test_data_mask_path

# make sure ground truth labels are loaded
biapy_config['DATA']['TEST']['LOAD_GT'] = True

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size_z)+', '+ str(patch_size_xy)+', '+ str(patch_size_xy)+ ', ' + str(input_channels)+')'
# adjust test padding accordingly
padding_xy = patch_size_xy // 8
padding_z = patch_size_z // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+str(padding_z)+', '+ str(padding_xy)+', '+ str(padding_xy)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = True
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe problem representation
#   BC = "Binary mask + Contours"
#   BCM = "Binary mask + Contours + Foreground mask"
#   BCD = "Binary mask + Contours + Distance map"
#   BCDv2 = "Binary mask + Contours + Distance map with background"
#   Dv2 = "Distance map with background"
#   BDv2 = "Binary mask + Distance map with background"
problem_channels = 'BC'
if problem_representation == "Binary mask + Contours":
    problem_channels = 'BC'
elif problem_representation == "Binary mask + Contours + Foreground mask":
    problem_channels = 'BCM'
elif problem_representation == "Binary mask + Contours + Distance map":
    problem_channels = 'BCD'
elif problem_representation == "Binary mask + Contours + Distance map with background":
    problem_channels = 'BCDv2'
elif problem_representation == "Distance map with background":
    problem_channels = 'Dv2'
else:
    problem_channels = 'BDv2'

biapy_config['PROBLEM']['INSTANCE_SEG']['DATA_CHANNELS'] = problem_channels

# Transcribe model architecture
architecture = 'unet'
if model_architecture == "U-Net":
    architecture = 'unet'
else:
    architecture = 'resunet'
biapy_config['MODEL']['ARCHITECTURE'] = architecture
if anisotropic_data == True:
    biapy_config['MODEL']['Z_DOWN'] = 1
else:
    biapy_config['MODEL']['Z_DOWN'] = 2

# update test parameters
biapy_config['TEST']['AUGMENTATION'] = test_time_augmentation

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2022-12-23 11:23:36
# Arguments: Namespace(config='/content/my_3d_instance_segmentation.yaml', gpu='0', name='my_3d_instance_segmentation', result_dir='/content/output', run_id=1)
# Job: my_3d_instance_segmentation_1
# Python       : 3.8.16 (default, Dec  7 2022, 01:12:13)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [2048, 1024]
#   UNETR_NUM_HEADS: 6
#   UNETR_OUT_DIM: 1
#   UNETR_TOKEN_SIZE: 16
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MAP_CODE_DIR:
#   MAP_H5_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/mAP_checkpoints
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     FULL_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_post_processing
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_INST_VORONOI: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances_voronoi
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH1: 0.2
#     DATA_MW_TH2: 0.1
#     DATA_MW_TH3: 0.3
#     DATA_MW_TH4: 1.2
#     DATA_MW_TH5: 1.5
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ: 30
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MAP: False
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     BLENDING: False
#     DET_WATERSHED: False
#     DET_WATERSHED_CIRCULARITY: 0.5
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [10.0]
#     VORONOI_ON_MASK: False
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: True
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# You select to create BC channels from given instance labels and no file is detected in /content/data/train/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TRAIN.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/train/y
# 100% 27/27 [00:00<00:00, 194.28it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating Y_train channels . . .
# 100% 27/27 [00:03<00:00,  8.91it/s]
# Loading data from /content/data/train/x
# 100% 27/27 [00:00<00:00, 226.94it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating X_train channels . . .
# You select to create BC channels from given instance labels and no file is detected in /content/data/test/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TEST.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/test/y
# 100% 3/3 [00:00<00:00, 483.01it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Creating Y_test channels . . .
# 100% 3/3 [00:00<00:00,  9.53it/s]
# Creating X_test channels . . .
# Loading data from /content/data/test/x
# 100% 3/3 [00:00<00:00, 103.03it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BC_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BC_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BC_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BC_thick
# #################
# #   LOAD DATA   #
# #################
#
# ### LOAD ###
# 0) Loading train images . . .
# Loading data from /content/data/train/x_BC_thick
# 100% 27/27 [00:00<00:00, 305.35it/s]
# *** Loaded data shape is (216, 32, 64, 64, 1)
# 1) Loading train masks . . .
# Loading data from /content/data/train/y_BC_thick
# 100% 27/27 [00:00<00:00, 93.15it/s]
# *** Loaded data shape is (216, 32, 64, 64, 2)
# *** Loaded train data shape is: (194, 32, 64, 64, 1)
# *** Loaded train mask shape is: (194, 32, 64, 64, 2)
# *** Loaded validation data shape is: (22, 32, 64, 64, 1)
# *** Loaded validation mask shape is: (22, 32, 64, 64, 2)
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# Initializing train data generator . . .
# Training data normalization - min: 0.0009765774011611938 , max: 0.006027313880622387 , mean: 0.002458977047353983
# Initializing val data generator . . .
# Validation data normalization - min: 0.001144426641985774 , max: 0.005951018538326025 , mean: 0.002492719329893589
# Creating generator samples . . .
# 0) Creating samples of data augmentation . . .
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/imgaug/augmenters/base.py:49: SuspiciousSingleImageShapeWarning: You provided a numpy array of shape (64, 64, 32) as a single-image augmentation input, which was interpreted as (H, W, C). The last dimension however has a size of >=32, which indicates that you provided a multi-image array with shape (N, H, W) instead. If that is the case, you should use e.g. augmenter(imageS=<your input>) or augment_imageS(<your input>). Otherwise your multi-image input will be interpreted as a single image during augmentation.
#   ia.warn(
# 100% 10/10 [00:00<00:00, 74.57it/s]
# #################
# #  BUILD MODEL  #
# #################
#
# 2022-12-23 11:23:47.863358: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 32, 64, 64, 1)]          0                 []
#
#  conv3d_1 (Conv3D)                               (None, 32, 64, 64, 36)           1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, 32, 64, 64, 36)           0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, 32, 64, 64, 36)           72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, 32, 64, 64, 36)           35028             ['elu[0][0]']
#
#  add (Add)                                       (None, 32, 64, 64, 36)           0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, 32, 32, 32, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, 32, 32, 32, 36)           0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, 32, 32, 32, 48)           46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, 32, 32, 32, 48)           1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, 32, 32, 32, 48)           62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, 32, 16, 16, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, 32, 16, 16, 48)           0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, 32, 16, 16, 64)           83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, 32, 16, 16, 64)           3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, 32, 16, 16, 64)           110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, 32, 32, 32, 48)           24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, 32, 32, 32, 96)           0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, 32, 32, 32, 96)           0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, 32, 32, 32, 48)           124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, 32, 32, 32, 48)           4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, 32, 32, 32, 48)           62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, 32, 64, 64, 36)           13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, 32, 64, 64, 72)           0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, 32, 64, 64, 72)           0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, 32, 64, 64, 36)           70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, 32, 64, 64, 36)           2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, 32, 64, 64, 36)           35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, 32, 64, 64, 2)            578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# #####################
# #  TRAIN THE MODEL  #
# #####################
#
# Epoch 1/100
# 97/97 [==============================] - ETA: 0s - loss: 0.7651 - jaccard_index_instances: 0.0133
#
# Epoch 00001: val_loss improved from inf to 0.68448, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 38s 260ms/step - loss: 0.7651 - jaccard_index_instances: 0.0133 - val_loss: 0.6845 - val_jaccard_index_instances: 1.6376e-06
# Epoch 2/100
# 97/97 [==============================] - ETA: 0s - loss: 0.6186 - jaccard_index_instances: 0.0206
#
# Epoch 00002: val_loss improved from 0.68448 to 0.65049, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 262ms/step - loss: 0.6186 - jaccard_index_instances: 0.0206 - val_loss: 0.6505 - val_jaccard_index_instances: 0.0000e+00
# Epoch 3/100
# 97/97 [==============================] - ETA: 0s - loss: 0.6014 - jaccard_index_instances: 0.0212
#
# Epoch 00003: val_loss improved from 0.65049 to 0.61077, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 266ms/step - loss: 0.6014 - jaccard_index_instances: 0.0212 - val_loss: 0.6108 - val_jaccard_index_instances: 0.0000e+00
# Epoch 4/100
# 97/97 [==============================] - ETA: 0s - loss: 0.5301 - jaccard_index_instances: 0.0827
#
# Epoch 00004: val_loss improved from 0.61077 to 0.54295, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 26s 270ms/step - loss: 0.5301 - jaccard_index_instances: 0.0827 - val_loss: 0.5429 - val_jaccard_index_instances: 0.0348
# Epoch 5/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4857 - jaccard_index_instances: 0.1246
#
# Epoch 00005: val_loss improved from 0.54295 to 0.49736, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 274ms/step - loss: 0.4857 - jaccard_index_instances: 0.1246 - val_loss: 0.4974 - val_jaccard_index_instances: 0.1388
# Epoch 6/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4682 - jaccard_index_instances: 0.1399
#
# Epoch 00006: val_loss improved from 0.49736 to 0.48332, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 277ms/step - loss: 0.4682 - jaccard_index_instances: 0.1399 - val_loss: 0.4833 - val_jaccard_index_instances: 0.0550
# Epoch 7/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4392 - jaccard_index_instances: 0.1685
#
# Epoch 00007: val_loss improved from 0.48332 to 0.44941, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.4392 - jaccard_index_instances: 0.1685 - val_loss: 0.4494 - val_jaccard_index_instances: 0.1941
# Epoch 8/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4185 - jaccard_index_instances: 0.1972
#
# Epoch 00008: val_loss improved from 0.44941 to 0.44681, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.4185 - jaccard_index_instances: 0.1972 - val_loss: 0.4468 - val_jaccard_index_instances: 0.0932
# Epoch 9/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4012 - jaccard_index_instances: 0.2174
#
# Epoch 00009: val_loss improved from 0.44681 to 0.42307, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.4012 - jaccard_index_instances: 0.2174 - val_loss: 0.4231 - val_jaccard_index_instances: 0.1759
# Epoch 10/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3891 - jaccard_index_instances: 0.2359
#
# Epoch 00010: val_loss improved from 0.42307 to 0.40232, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.3891 - jaccard_index_instances: 0.2359 - val_loss: 0.4023 - val_jaccard_index_instances: 0.2488
# Epoch 11/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3764 - jaccard_index_instances: 0.2485
#
# Epoch 00011: val_loss improved from 0.40232 to 0.39552, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.3764 - jaccard_index_instances: 0.2485 - val_loss: 0.3955 - val_jaccard_index_instances: 0.2650
# Epoch 12/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3561 - jaccard_index_instances: 0.2817
#
# Epoch 00012: val_loss improved from 0.39552 to 0.37692, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 28s 283ms/step - loss: 0.3561 - jaccard_index_instances: 0.2817 - val_loss: 0.3769 - val_jaccard_index_instances: 0.2372
# Epoch 13/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3412 - jaccard_index_instances: 0.3124
#
# Epoch 00013: val_loss improved from 0.37692 to 0.35543, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 28s 284ms/step - loss: 0.3412 - jaccard_index_instances: 0.3124 - val_loss: 0.3554 - val_jaccard_index_instances: 0.3272
# Epoch 14/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3323 - jaccard_index_instances: 0.3442
#
# Epoch 00014: val_loss did not improve from 0.35543
#
#
# 97/97 [==============================] - 27s 279ms/step - loss: 0.3323 - jaccard_index_instances: 0.3442 - val_loss: 0.3730 - val_jaccard_index_instances: 0.3033
# Epoch 15/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3204 - jaccard_index_instances: 0.3703
#
# Epoch 00015: val_loss improved from 0.35543 to 0.33227, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.3204 - jaccard_index_instances: 0.3703 - val_loss: 0.3323 - val_jaccard_index_instances: 0.3834
# Epoch 16/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3113 - jaccard_index_instances: 0.4028
#
# Epoch 00016: val_loss did not improve from 0.33227
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.3113 - jaccard_index_instances: 0.4028 - val_loss: 0.3348 - val_jaccard_index_instances: 0.4022
# Epoch 17/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3033 - jaccard_index_instances: 0.4179
#
# Epoch 00017: val_loss improved from 0.33227 to 0.31466, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.3033 - jaccard_index_instances: 0.4179 - val_loss: 0.3147 - val_jaccard_index_instances: 0.4398
# Epoch 18/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2921 - jaccard_index_instances: 0.4428
#
# Epoch 00018: val_loss improved from 0.31466 to 0.30463, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.2921 - jaccard_index_instances: 0.4428 - val_loss: 0.3046 - val_jaccard_index_instances: 0.4603
# Epoch 19/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2878 - jaccard_index_instances: 0.4560
#
# Epoch 00019: val_loss improved from 0.30463 to 0.29205, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2878 - jaccard_index_instances: 0.4560 - val_loss: 0.2921 - val_jaccard_index_instances: 0.4713
# Epoch 20/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2750 - jaccard_index_instances: 0.4771
#
# Epoch 00020: val_loss did not improve from 0.29205
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.2750 - jaccard_index_instances: 0.4771 - val_loss: 0.2923 - val_jaccard_index_instances: 0.4829
# Epoch 21/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2722 - jaccard_index_instances: 0.4793
#
# Epoch 00021: val_loss improved from 0.29205 to 0.28121, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2722 - jaccard_index_instances: 0.4793 - val_loss: 0.2812 - val_jaccard_index_instances: 0.4930
# Epoch 22/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2696 - jaccard_index_instances: 0.4892
#
# Epoch 00022: val_loss improved from 0.28121 to 0.27397, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 283ms/step - loss: 0.2696 - jaccard_index_instances: 0.4892 - val_loss: 0.2740 - val_jaccard_index_instances: 0.5284
# Epoch 23/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2589 - jaccard_index_instances: 0.5094
#
# Epoch 00023: val_loss improved from 0.27397 to 0.25943, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 28s 284ms/step - loss: 0.2589 - jaccard_index_instances: 0.5094 - val_loss: 0.2594 - val_jaccard_index_instances: 0.5457
# Epoch 24/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2553 - jaccard_index_instances: 0.5114
#
# Epoch 00024: val_loss did not improve from 0.25943
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.2553 - jaccard_index_instances: 0.5114 - val_loss: 0.2621 - val_jaccard_index_instances: 0.5403
# Epoch 25/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2585 - jaccard_index_instances: 0.5126
#
# Epoch 00025: val_loss improved from 0.25943 to 0.25844, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2585 - jaccard_index_instances: 0.5126 - val_loss: 0.2584 - val_jaccard_index_instances: 0.5280
# Epoch 26/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2455 - jaccard_index_instances: 0.5352
#
# Epoch 00026: val_loss improved from 0.25844 to 0.25290, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2455 - jaccard_index_instances: 0.5352 - val_loss: 0.2529 - val_jaccard_index_instances: 0.5451
# Epoch 27/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2395 - jaccard_index_instances: 0.5455
#
# Epoch 00027: val_loss did not improve from 0.25290
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2395 - jaccard_index_instances: 0.5455 - val_loss: 0.2612 - val_jaccard_index_instances: 0.5409
# Epoch 28/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2361 - jaccard_index_instances: 0.5525
#
# Epoch 00028: val_loss improved from 0.25290 to 0.23571, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2361 - jaccard_index_instances: 0.5525 - val_loss: 0.2357 - val_jaccard_index_instances: 0.5882
# Epoch 29/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2271 - jaccard_index_instances: 0.5681
#
# Epoch 00029: val_loss improved from 0.23571 to 0.22896, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 283ms/step - loss: 0.2271 - jaccard_index_instances: 0.5681 - val_loss: 0.2290 - val_jaccard_index_instances: 0.5803
# Epoch 30/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2218 - jaccard_index_instances: 0.5730
#
# Epoch 00030: val_loss improved from 0.22896 to 0.22086, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2218 - jaccard_index_instances: 0.5730 - val_loss: 0.2209 - val_jaccard_index_instances: 0.6059
# Epoch 31/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2165 - jaccard_index_instances: 0.5871
#
# Epoch 00031: val_loss improved from 0.22086 to 0.21610, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2165 - jaccard_index_instances: 0.5871 - val_loss: 0.2161 - val_jaccard_index_instances: 0.6163
# Epoch 32/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2151 - jaccard_index_instances: 0.5879
#
# Epoch 00032: val_loss improved from 0.21610 to 0.21274, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2151 - jaccard_index_instances: 0.5879 - val_loss: 0.2127 - val_jaccard_index_instances: 0.6327
# Epoch 33/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2141 - jaccard_index_instances: 0.5889
#
# Epoch 00033: val_loss improved from 0.21274 to 0.21110, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2141 - jaccard_index_instances: 0.5889 - val_loss: 0.2111 - val_jaccard_index_instances: 0.6256
# Epoch 34/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2091 - jaccard_index_instances: 0.5999
#
# Epoch 00034: val_loss improved from 0.21110 to 0.20744, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2091 - jaccard_index_instances: 0.5999 - val_loss: 0.2074 - val_jaccard_index_instances: 0.6400
# Epoch 35/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2056 - jaccard_index_instances: 0.6110
#
# Epoch 00035: val_loss did not improve from 0.20744
#
#
# 97/97 [==============================] - 27s 280ms/step - loss: 0.2056 - jaccard_index_instances: 0.6110 - val_loss: 0.2087 - val_jaccard_index_instances: 0.6168
# Epoch 36/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2009 - jaccard_index_instances: 0.6143
#
# Epoch 00036: val_loss improved from 0.20744 to 0.20296, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.2009 - jaccard_index_instances: 0.6143 - val_loss: 0.2030 - val_jaccard_index_instances: 0.6488
# Epoch 37/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2071 - jaccard_index_instances: 0.6095
#
# Epoch 00037: val_loss improved from 0.20296 to 0.19989, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.2071 - jaccard_index_instances: 0.6095 - val_loss: 0.1999 - val_jaccard_index_instances: 0.6443
# Epoch 38/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1960 - jaccard_index_instances: 0.6268
#
# Epoch 00038: val_loss improved from 0.19989 to 0.19239, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1960 - jaccard_index_instances: 0.6268 - val_loss: 0.1924 - val_jaccard_index_instances: 0.6569
# Epoch 39/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1918 - jaccard_index_instances: 0.6314
#
# Epoch 00039: val_loss improved from 0.19239 to 0.19092, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1918 - jaccard_index_instances: 0.6314 - val_loss: 0.1909 - val_jaccard_index_instances: 0.6571
# Epoch 40/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1894 - jaccard_index_instances: 0.6369
#
# Epoch 00040: val_loss did not improve from 0.19092
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1894 - jaccard_index_instances: 0.6369 - val_loss: 0.1911 - val_jaccard_index_instances: 0.6654
# Epoch 41/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1916 - jaccard_index_instances: 0.6332
#
# Epoch 00041: val_loss did not improve from 0.19092
#
#
# 97/97 [==============================] - 28s 285ms/step - loss: 0.1916 - jaccard_index_instances: 0.6332 - val_loss: 0.1938 - val_jaccard_index_instances: 0.6608
# Epoch 42/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1897 - jaccard_index_instances: 0.6345
#
# Epoch 00042: val_loss improved from 0.19092 to 0.18653, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 279ms/step - loss: 0.1897 - jaccard_index_instances: 0.6345 - val_loss: 0.1865 - val_jaccard_index_instances: 0.6644
# Epoch 43/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1901 - jaccard_index_instances: 0.6387
#
# Epoch 00043: val_loss improved from 0.18653 to 0.18061, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1901 - jaccard_index_instances: 0.6387 - val_loss: 0.1806 - val_jaccard_index_instances: 0.6697
# Epoch 44/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1825 - jaccard_index_instances: 0.6500
#
# Epoch 00044: val_loss improved from 0.18061 to 0.18005, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 283ms/step - loss: 0.1825 - jaccard_index_instances: 0.6500 - val_loss: 0.1800 - val_jaccard_index_instances: 0.6713
# Epoch 45/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1807 - jaccard_index_instances: 0.6522
#
# Epoch 00045: val_loss improved from 0.18005 to 0.17784, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1807 - jaccard_index_instances: 0.6522 - val_loss: 0.1778 - val_jaccard_index_instances: 0.6779
# Epoch 46/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1822 - jaccard_index_instances: 0.6492
#
# Epoch 00046: val_loss did not improve from 0.17784
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1822 - jaccard_index_instances: 0.6492 - val_loss: 0.1852 - val_jaccard_index_instances: 0.6738
# Epoch 47/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1779 - jaccard_index_instances: 0.6572
#
# Epoch 00047: val_loss did not improve from 0.17784
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1779 - jaccard_index_instances: 0.6572 - val_loss: 0.1843 - val_jaccard_index_instances: 0.6810
# Epoch 48/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1803 - jaccard_index_instances: 0.6525
#
# Epoch 00048: val_loss improved from 0.17784 to 0.17704, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1803 - jaccard_index_instances: 0.6525 - val_loss: 0.1770 - val_jaccard_index_instances: 0.6825
# Epoch 49/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1773 - jaccard_index_instances: 0.6587
#
# Epoch 00049: val_loss improved from 0.17704 to 0.17657, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1773 - jaccard_index_instances: 0.6587 - val_loss: 0.1766 - val_jaccard_index_instances: 0.6904
# Epoch 50/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1736 - jaccard_index_instances: 0.6639
#
# Epoch 00050: val_loss improved from 0.17657 to 0.17336, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1736 - jaccard_index_instances: 0.6639 - val_loss: 0.1734 - val_jaccard_index_instances: 0.6871
# Epoch 51/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1708 - jaccard_index_instances: 0.6695
#
# Epoch 00051: val_loss did not improve from 0.17336
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1708 - jaccard_index_instances: 0.6695 - val_loss: 0.1748 - val_jaccard_index_instances: 0.6904
# Epoch 52/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1696 - jaccard_index_instances: 0.6721
#
# Epoch 00052: val_loss improved from 0.17336 to 0.16683, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1696 - jaccard_index_instances: 0.6721 - val_loss: 0.1668 - val_jaccard_index_instances: 0.7046
# ...
# Epoch 80/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1495 - jaccard_index_instances: 0.7076
#
# Epoch 00080: val_loss did not improve from 0.14748
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1495 - jaccard_index_instances: 0.7076 - val_loss: 0.1481 - val_jaccard_index_instances: 0.7297
# Epoch 81/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1499 - jaccard_index_instances: 0.7056
#
# Epoch 00081: val_loss improved from 0.14748 to 0.14642, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1499 - jaccard_index_instances: 0.7056 - val_loss: 0.1464 - val_jaccard_index_instances: 0.7353
# Epoch 82/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1497 - jaccard_index_instances: 0.7063
#
# Epoch 00082: val_loss improved from 0.14642 to 0.14431, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1497 - jaccard_index_instances: 0.7063 - val_loss: 0.1443 - val_jaccard_index_instances: 0.7397
# Epoch 83/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1502 - jaccard_index_instances: 0.7066
#
# Epoch 00083: val_loss did not improve from 0.14431
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1502 - jaccard_index_instances: 0.7066 - val_loss: 0.1482 - val_jaccard_index_instances: 0.7354
# Epoch 84/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1486 - jaccard_index_instances: 0.7092
#
# Epoch 00084: val_loss did not improve from 0.14431
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1486 - jaccard_index_instances: 0.7092 - val_loss: 0.1485 - val_jaccard_index_instances: 0.7335
# Epoch 85/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1464 - jaccard_index_instances: 0.7120
#
# Epoch 00085: val_loss did not improve from 0.14431
#
#
# 97/97 [==============================] - 27s 280ms/step - loss: 0.1464 - jaccard_index_instances: 0.7120 - val_loss: 0.1467 - val_jaccard_index_instances: 0.7351
# Epoch 86/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1476 - jaccard_index_instances: 0.7107
#
# Epoch 00086: val_loss did not improve from 0.14431
#
#
# 97/97 [==============================] - 27s 280ms/step - loss: 0.1476 - jaccard_index_instances: 0.7107 - val_loss: 0.1490 - val_jaccard_index_instances: 0.7309
# Epoch 87/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1496 - jaccard_index_instances: 0.7088
#
# Epoch 00087: val_loss did not improve from 0.14431
#
#
# 97/97 [==============================] - 27s 280ms/step - loss: 0.1496 - jaccard_index_instances: 0.7088 - val_loss: 0.1484 - val_jaccard_index_instances: 0.7345
# Epoch 88/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1470 - jaccard_index_instances: 0.7110
#
# Epoch 00088: val_loss improved from 0.14431 to 0.14306, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 282ms/step - loss: 0.1470 - jaccard_index_instances: 0.7110 - val_loss: 0.1431 - val_jaccard_index_instances: 0.7416
# Epoch 89/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1447 - jaccard_index_instances: 0.7138
#
# Epoch 00089: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1447 - jaccard_index_instances: 0.7138 - val_loss: 0.1480 - val_jaccard_index_instances: 0.7289
# Epoch 90/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1443 - jaccard_index_instances: 0.7171
#
# Epoch 00090: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1443 - jaccard_index_instances: 0.7171 - val_loss: 0.1444 - val_jaccard_index_instances: 0.7385
# Epoch 91/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1452 - jaccard_index_instances: 0.7149
#
# Epoch 00091: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1452 - jaccard_index_instances: 0.7149 - val_loss: 0.1472 - val_jaccard_index_instances: 0.7355
# Epoch 92/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1449 - jaccard_index_instances: 0.7187
#
# Epoch 00092: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1449 - jaccard_index_instances: 0.7187 - val_loss: 0.1645 - val_jaccard_index_instances: 0.6931
# Epoch 93/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1425 - jaccard_index_instances: 0.7214
#
# Epoch 00093: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1425 - jaccard_index_instances: 0.7214 - val_loss: 0.1438 - val_jaccard_index_instances: 0.7381
# Epoch 94/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1449 - jaccard_index_instances: 0.7169
#
# Epoch 00094: val_loss did not improve from 0.14306
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1449 - jaccard_index_instances: 0.7169 - val_loss: 0.1431 - val_jaccard_index_instances: 0.7408
# Epoch 95/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1439 - jaccard_index_instances: 0.7197
#
# Epoch 00095: val_loss improved from 0.14306 to 0.14173, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 27s 283ms/step - loss: 0.1439 - jaccard_index_instances: 0.7197 - val_loss: 0.1417 - val_jaccard_index_instances: 0.7431
# Epoch 96/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1434 - jaccard_index_instances: 0.7195
#
# Epoch 00096: val_loss did not improve from 0.14173
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1434 - jaccard_index_instances: 0.7195 - val_loss: 0.1436 - val_jaccard_index_instances: 0.7424
# Epoch 97/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1432 - jaccard_index_instances: 0.7184
#
# Epoch 00097: val_loss did not improve from 0.14173
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1432 - jaccard_index_instances: 0.7184 - val_loss: 0.1427 - val_jaccard_index_instances: 0.7417
# Epoch 98/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1432 - jaccard_index_instances: 0.7183
#
# Epoch 00098: val_loss did not improve from 0.14173
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1432 - jaccard_index_instances: 0.7183 - val_loss: 0.1419 - val_jaccard_index_instances: 0.7414
# Epoch 99/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1423 - jaccard_index_instances: 0.7212
#
# Epoch 00099: val_loss did not improve from 0.14173
#
#
# 97/97 [==============================] - 27s 280ms/step - loss: 0.1423 - jaccard_index_instances: 0.7212 - val_loss: 0.1419 - val_jaccard_index_instances: 0.7455
# Epoch 100/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1405 - jaccard_index_instances: 0.7214
#
# Epoch 00100: val_loss did not improve from 0.14173
#
#
# 97/97 [==============================] - 27s 281ms/step - loss: 0.1405 - jaccard_index_instances: 0.7214 - val_loss: 0.1426 - val_jaccard_index_instances: 0.7395
# Creating training plots . . .
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:06,  2.08it/s]
#
#  14% 2/14 [00:00<00:03,  3.82it/s]
#
#  21% 3/14 [00:00<00:02,  5.20it/s]
#
#  29% 4/14 [00:00<00:01,  6.17it/s]
#
#  36% 5/14 [00:00<00:01,  6.94it/s]
#
#  43% 6/14 [00:01<00:01,  7.55it/s]
#
#  50% 7/14 [00:01<00:00,  8.00it/s]
#
#  57% 8/14 [00:01<00:00,  8.32it/s]
#
#  64% 9/14 [00:01<00:00,  8.53it/s]
#
#  71% 10/14 [00:01<00:00,  8.63it/s]
#
#  79% 11/14 [00:01<00:00,  8.77it/s]
#
#  86% 12/14 [00:01<00:00,  8.55it/s]
#
#  93% 13/14 [00:01<00:00,  8.76it/s]
#
# 100% 14/14 [00:02<00:00,  4.57it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:03,  3.33it/s]
#
#  14% 2/14 [00:00<00:02,  4.39it/s]
#
#  21% 3/14 [00:00<00:02,  4.89it/s]
#
#  29% 4/14 [00:00<00:01,  5.16it/s]
#
#  36% 5/14 [00:01<00:01,  5.28it/s]
#
#  43% 6/14 [00:01<00:01,  6.24it/s]
#
#  50% 7/14 [00:01<00:01,  6.04it/s]
#
#  57% 8/14 [00:01<00:00,  6.90it/s]
#
#  64% 9/14 [00:01<00:00,  6.49it/s]
#
#  71% 10/14 [00:01<00:00,  7.14it/s]
#
#  79% 11/14 [00:01<00:00,  6.60it/s]
#
#  86% 12/14 [00:02<00:00,  6.25it/s]
#
# 100% 14/14 [00:02<00:00,  7.61it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=51, fn=0, precision=0.8360655737704918, recall=1.0, accuracy=0.8360655737704918, f1=0.9107142857142857, n_true=51, n_pred=61, mean_true_score=0.6859757666494332, mean_matched_score=0.6859757666494332, panoptic_quality=0.6247279303414481), Matching(criterion='iou', thresh=0.5, fp=11, tp=50, fn=1, precision=0.819672131147541, recall=0.9803921568627451, accuracy=0.8064516129032258, f1=0.8928571428571429, n_true=51, n_pred=61, mean_true_score=0.6763340071135876, mean_matched_score=0.6898606872558594, panoptic_quality=0.6159470421927316), Matching(criterion='iou', thresh=0.75, fp=51, tp=10, fn=41, precision=0.16393442622950818, recall=0.19607843137254902, accuracy=0.09803921568627451, f1=0.17857142857142858, n_true=51, n_pred=61, mean_true_score=0.15347151662789138, mean_matched_score=0.7827047348022461, panoptic_quality=0.13976870264325822))
#
# 100% 1/1 [00:06<00:00,  6.11s/it]
#  33% 1/3 [00:06<00:12,  6.13s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  8.85it/s]
#
#  14% 2/14 [00:00<00:01,  9.00it/s]
#
#  21% 3/14 [00:00<00:01,  9.07it/s]
#
#  29% 4/14 [00:00<00:01,  9.14it/s]
#
#  36% 5/14 [00:00<00:00,  9.10it/s]
#
#  43% 6/14 [00:00<00:00,  9.17it/s]
#
#  50% 7/14 [00:00<00:00,  9.03it/s]
#
#  57% 8/14 [00:00<00:00,  8.91it/s]
#
#  64% 9/14 [00:01<00:00,  8.74it/s]
#
#  71% 10/14 [00:01<00:00,  8.73it/s]
#
#  79% 11/14 [00:01<00:00,  8.85it/s]
#
#  86% 12/14 [00:01<00:00,  9.00it/s]
#
#  93% 13/14 [00:01<00:00,  9.10it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.14it/s]
#
#  21% 3/14 [00:00<00:01,  9.52it/s]
#
#  29% 4/14 [00:00<00:01,  9.65it/s]
#
#  36% 5/14 [00:00<00:01,  7.84it/s]
#
#  43% 6/14 [00:00<00:00,  8.30it/s]
#
#  50% 7/14 [00:00<00:00,  8.69it/s]
#
#  57% 8/14 [00:00<00:00,  8.89it/s]
#
#  64% 9/14 [00:01<00:00,  7.56it/s]
#
#  79% 11/14 [00:01<00:00,  8.36it/s]
#
#  86% 12/14 [00:01<00:00,  7.41it/s]
#
#  93% 13/14 [00:01<00:00,  7.78it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=6, tp=20, fn=0, precision=0.7692307692307693, recall=1.0, accuracy=0.7692307692307693, f1=0.8695652173913043, n_true=20, n_pred=26, mean_true_score=0.7608535766601563, mean_matched_score=0.7608535766601563, panoptic_quality=0.6616118057914402), Matching(criterion='iou', thresh=0.5, fp=6, tp=20, fn=0, precision=0.7692307692307693, recall=1.0, accuracy=0.7692307692307693, f1=0.8695652173913043, n_true=20, n_pred=26, mean_true_score=0.7608535766601563, mean_matched_score=0.7608535766601563, panoptic_quality=0.6616118057914402), Matching(criterion='iou', thresh=0.75, fp=15, tp=11, fn=9, precision=0.4230769230769231, recall=0.55, accuracy=0.3142857142857143, f1=0.4782608695652174, n_true=20, n_pred=26, mean_true_score=0.43602547645568845, mean_matched_score=0.7927735935557972, panoptic_quality=0.3791525882223378))
#
# 100% 1/1 [00:03<00:00,  3.39s/it]
#  67% 2/3 [00:09<00:04,  4.53s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.12it/s]
#
#  14% 2/14 [00:00<00:01,  8.77it/s]
#
#  21% 3/14 [00:00<00:01,  8.91it/s]
#
#  29% 4/14 [00:00<00:01,  8.72it/s]
#
#  36% 5/14 [00:00<00:01,  8.73it/s]
#
#  43% 6/14 [00:00<00:00,  8.84it/s]
#
#  50% 7/14 [00:00<00:00,  9.01it/s]
#
#  57% 8/14 [00:00<00:00,  9.05it/s]
#
#  64% 9/14 [00:01<00:00,  9.08it/s]
#
#  71% 10/14 [00:01<00:00,  9.15it/s]
#
#  79% 11/14 [00:01<00:00,  9.17it/s]
#
#  86% 12/14 [00:01<00:00,  9.08it/s]
#
#  93% 13/14 [00:01<00:00,  9.11it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  5.48it/s]
#
#  21% 3/14 [00:00<00:01,  8.17it/s]
#
#  29% 4/14 [00:00<00:01,  8.69it/s]
#
#  36% 5/14 [00:00<00:00,  9.08it/s]
#
#  43% 6/14 [00:00<00:00,  9.31it/s]
#
#  50% 7/14 [00:00<00:00,  7.78it/s]
#
#  57% 8/14 [00:01<00:00,  6.95it/s]
#
#  64% 9/14 [00:01<00:00,  7.58it/s]
#
#  71% 10/14 [00:01<00:00,  6.85it/s]
#
#  79% 11/14 [00:01<00:00,  7.57it/s]
#
#  86% 12/14 [00:01<00:00,  6.70it/s]
#
#  93% 13/14 [00:01<00:00,  7.15it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6362692670124334, mean_matched_score=0.6362692670124334, panoptic_quality=0.6362692670124334), Matching(criterion='iou', thresh=0.5, fp=4, tp=160, fn=4, precision=0.975609756097561, recall=0.975609756097561, accuracy=0.9523809523809523, f1=0.975609756097561, n_true=164, n_pred=164, mean_true_score=0.6251629620063596, mean_matched_score=0.6407920360565186, panoptic_quality=0.6251629620063596), Matching(criterion='iou', thresh=0.75, fp=157, tp=7, fn=157, precision=0.042682926829268296, recall=0.042682926829268296, accuracy=0.021806853582554516, f1=0.042682926829268296, n_true=164, n_pred=164, mean_true_score=0.03256620430364841, mean_matched_score=0.7629796436854771, panoptic_quality=0.03256620430364841))
#
# 100% 1/1 [00:03<00:00,  3.62s/it]
# 100% 3/3 [00:13<00:00,  4.39s/it]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 27.30483920097351
# Epoch number: 100
# Train time (s): 2730.483920097351
# Train loss: 0.14052462577819824
# Train Foreground jaccard_index_instances: 0.7214323282241821
# Validation loss: 0.14172689616680145
# Validation Foreground jaccard_index_instances: 0.7454696297645569
# Loss (per patch): 0.07092274148247124
# Test Foreground IoU (per patch): 0.3740342053366296
#
# Test Foreground IoU (merge patches): 0.7715411578231416
# Test Overall IoU (merge patches): 0.8729000551250309
#
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=16, tp=235, fn=0, precision=0.9362549800796812, recall=1.0, accuracy=0.9362549800796812, f1=0.9670781893004116, n_true=235, n_pred=251, mean_true_score=0.6576595549887799, mean_matched_score=0.6576595549887799, panoptic_quality=0.6360082116146637, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=21, tp=230, fn=5, precision=0.9163346613545816, recall=0.9787234042553191, accuracy=0.8984375, f1=0.9465020576131687, n_true=235, n_pred=251, mean_true_score=0.647816304957613, mean_matched_score=0.6618992681088655, panoptic_quality=0.6264890191976916, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=223, tp=28, fn=207, precision=0.11155378486055777, recall=0.11914893617021277, accuracy=0.0611353711790393, f1=0.11522633744855967, n_true=235, n_pred=251, mean_true_score=0.09314218886355136, mean_matched_score=0.7817290851048061, panoptic_quality=0.09007577935364021, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **Jaccard index or Intersection over Union** (IoU) metric is a method that can be used to quantify the overlap between the target mask and your prediction output. **Therefore, the closer to 1, the better the performance.** This metric can be used to assess the quality of your model to accurately predict cells.

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and IoU vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_jaccard_index_instances.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Intersection over Union (IoU) vs epoch number', fontdict = {'fontsize':22})

# %% [markdown]
# ## **Visualize instance segmentation results**

# %%
#@markdown ###Play to visualize results in 3D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
instance_results = os.path.join(final_results, "per_image_instances")

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(aux)
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(aux)

# function to show results in 3D within a widget
def scroll_in_z(z):

    plt.figure(figsize=(25,5))
    # Source
    plt.subplot(1,4,1)
    plt.axis('off')
    plt.imshow(test_source[z-1], cmap='gray')
    plt.title('Source (z = ' + str(z) + ')', fontsize=15)

    # Target (Ground-truth)
    plt.subplot(1,4,2)
    plt.axis('off')
    plt.imshow(test_target[z-1], cmap=cmap, interpolation='nearest')
    plt.title('Ground truth (z = ' + str(z) + ')', fontsize=15)

    # Prediction
    plt.subplot(1,4,3)
    plt.axis('off')
    plt.imshow(test_prediction[z-1], cmap=cmap, interpolation='nearest')
    plt.title('Prediction (z = ' + str(z) + ')', fontsize=15)
    
    # Overlay
    plt.subplot(1,4,4)
    plt.axis('off')
    plt.imshow(test_target[z-1], cmap='Greens')
    plt.imshow(test_prediction[z-1], alpha=0.5, cmap='Purples')
    plt.title('Overlay (z = ' + str(z) + ')', fontsize=15)

for j in range(samples_to_show):
    test_source = test_samples[j]
    test_target = test_sample_gt[j]
    test_prediction = test_sample_preds[j]

    interact(scroll_in_z, z=widgets.IntSlider(min=1, max=test_source.shape[0], step=1, value=0));
# Out:
# interactive(children=(IntSlider(value=1, description='z', max=64, min=1), Output()), _dom_classes=('widget-int…
# interactive(children=(IntSlider(value=1, description='z', max=64, min=1), Output()), _dom_classes=('widget-int…
# interactive(children=(IntSlider(value=1, description='z', max=64, min=1), Output()), _dom_classes=('widget-int…

# %%
#@markdown ###Play to display the path to the output files (one 3D TIFF label image for each input image).

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

instance_results = os.path.join(final_results, "per_image_instances")

print("Output paths:")
print("    Instance segmentation files are in {}".format(instance_results))
# Out:
# Output paths:
#     Instance segmentation files are in /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances

# %% [markdown]
# ## **Download instance segmentation results**

# %%
#@markdown ###Play to download a zip file with all instance segmentation results in test.

from google.colab import files

# !zip -q -j /content/instance_segmentation_results.zip $instance_results/*.tif

files.download("/content/instance_segmentation_results.zip")

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))

# %% [markdown]
# ## **Acknowledgments**
# We would like to acknowledge the inspiration provided by the excellent [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki). In particular, we have reused some of their descriptions of metrics and parameters, as well as their 3D visualization widget code from their [U-Net 3D notebook](https://colab.research.google.com/github/HenriquesLab/ZeroCostDL4Mic/blob/master/Colab_notebooks/U-Net_3D_ZeroCostDL4Mic.ipynb). We would also like to extend our special thanks to [Estibaliz Gomez-de-Mariscal](https://scholar.google.es/citations?user=gsg-TAUAAAAJ) for her support and insightful comments, which helped us to improve this notebook.
