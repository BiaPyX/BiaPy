# %% [markdown]
# # **3D Instance Segmentation pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **3D instance segmentation** of microscopy data.
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume.gif' width='300px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/nucmm_z_volume_mask.gif' width='300px'/>
# <figcaption><b>Figure 1</b>: Example of a 3D instance segmentation problem. From left to right: 3D electron microscopy image and its corresponding nuclei instance labels (source: NucMM, <a href="https://link.springer.com/chapter/10.1007/978-3-030-87193-2_16">Lin et al, 2021</a>).</figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their corresponding instance label images,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the segmentation results** to your local machine.
#
# **Disclaimer:** the structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 3D images to train the model.
# * **Training label images**: with the instance-label 3D images to train the model. Their number and sizes must match those of the training raw images.
# * **Test raw images**: with the raw 3D images to test the model.
# * **Test label images**: with the instance-label 3D images to test the model. Their number and sizes must match those of the validation raw images.
# * **Output folder**: a path to store the segmentation results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing one result **TIFF image** for each test image. The result images contain the instances of the "objects" of interest as predicted by our pipeline.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3'**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`.

# %%
#@markdown ##Play the cell to upload local files (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/x
# %cd /content/input/train/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (train label images)

from google.colab import files
# !mkdir -p /content/input/train/y 
# %cd /content/input/train/y
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test raw images)

from google.colab import files
# !mkdir -p /content/input/val/x
# %cd /content/input/val/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test label images)

from google.colab import files
# !mkdir -p /content/input/val/y
# %cd /content/input/val/y
uploaded = files.upload()
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use the [3D demo dataset from the StarDist 0.3.0 release](https://github.com/mpicbg-csbd/stardist/releases/download/0.3.0/demo3D.zip), publicly available online.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')

# !curl -L -s -o demo3D.zip 'https://drive.google.com/uc?id=1fdL35ZTNw5hhiKau1gadaGu-rc5ZU_C7&confirm=t'

# !unzip -q demo3D.zip
# !rm demo3D.zip

print( 'Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train/x', train_data_mask_path as '/content/data/train/y', test_data_path as '/content/data/test/x', test_data_mask_path as '/content/data/test/y', and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train/x' #@param {type:"string"}
#@markdown #####Path to train instances
train_data_mask_path = '/content/data/train/y' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test/x' #@param {type:"string"}
#@markdown #####Path to test instances
test_data_mask_path = '/content/data/test/y' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone https://github.com/danifranco/BiaPy.git
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs fill_voids &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Cloning into 'BiaPy'...
# remote: Enumerating objects: 15880, done.
# remote: Counting objects: 100% (1949/1949), done.
# remote: Compressing objects: 100% (651/651), done.
# remote: Total 15880 (delta 1371), reused 1850 (delta 1278), pack-reused 13931
# Receiving objects: 100% (15880/15880), 824.84 MiB | 14.92 MiB/s, done.
# Resolving deltas: 100% (8640/8640), done.

# %% [markdown]
# ## **Configure and train the DNN model**
# [BiaPy](https://biapy.readthedocs.io/en/latest/) uses a bottom-up approach to instance segmentation in 2D and 3D by learning the binary masks, contours, and
# (optionally) the distance map of the objects of interest, to be later post-processed using marker-controlled watershed (see [Wei et al. 2020](https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7)).
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/cysto_instance_bcd_scheme.svg' width='300px'/>
# <figcaption><b>Figure 2</b>: Example of multi-channel representation for instance segmentation. Label instances can be learnt by predicting their contours, binary masks and distance maps (<a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>).</figcaption></center>
# </figure>
#
# The use of these representations and other pipeline hyperparameters can be configured by editing the YAML configuration file or (easier) by running the next cell.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
# #### **Basic training parameters**
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, preliminary results can already be observed after 50 epochs, but better results are obtained when running the model longer. **Default value: 100**
#
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. **Default value: 10**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: U-Net, Residual U-Net (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1))  **Default value: Residual U-Net**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 8**
#
# * **`patch_size_xy`:** Input the XY size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 64**
#
# * **`patch_size_z`:** Input the Z size of the patches use to train your model (length in pixels in Z). The value should be smaller or equal to the dimensions of the image. **Default value: 32**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 1**
#
# * **`anisotropic_data`:** Select if your image data is anisotropic (lower resolution in Z with respect to XY). The model downsampling step size will be set accordingly. **Default value: True**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: ADAM**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.0001**
#
# * **`problem_representation`:** Select the type of representation that the model must learn to identify the instances. Options: "Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask" (see <a href="https://link.springer.com/chapter/10.1007/978-3-030-59722-1_7">[Wei et al. 2020]</a>). **Default value: "Binary mask + Contours"**
#
# * **`test_time_augmentation`:** Select to apply augmentation (flips and rotations) at test time. It usually provides more robust results but uses more time to produce each result. **Default value: False**

# %%
#@markdown ###Name of the model:
model_name = "my_3d_instance_segmentation" #@param {type:"string"}

#@markdown ### Basic training parameters:
number_of_epochs =  100#@param {type:"number"}
percentage_validation =  10 #@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "Residual U-Net" #@param ["U-Net", "Residual U-Net"]

batch_size =  2#@param {type:"number"}
patch_size_xy = 64 #@param {type:"number"}
patch_size_z = 32 #@param {type:"number"}

input_channels = 1 #@param {type:"number"}
anisotropic_data = True #@param {type:"boolean"}

optimizer = "ADAM" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.0001 #@param {type:"number"}

problem_representation = "Binary mask + Contours" #@param ["Binary mask + Contours", "Binary mask + Contours + Distance map", "Binary mask + Contours + Foreground mask"]

test_time_augmentation = False #@param {type:"boolean"}

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# remove template file it is exists
template_file = '3d_instances.yaml'
if os.path.exists( template_file ):
    os.remove( template_file )

# Download template file 
# !wget https://raw.githubusercontent.com/danifranco/BiaPy/master/templates/instance_segmentation/3d_instances.yaml &> /dev/null

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_path))
if not os.path.exists(train_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_mask_path)
ids = sorted(next(os.walk(train_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_data_mask_path))

# Check folders before modifying the .yaml file
if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_path))
if not os.path.exists(test_data_mask_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_mask_path)
ids = sorted(next(os.walk(test_data_mask_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_mask_path))


# open template configuration file
import yaml
with open( template_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['TRAIN']['MASK_PATH'] = train_data_mask_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path
biapy_config['DATA']['TEST']['MASK_PATH'] = test_data_mask_path

# make sure ground truth labels are loaded
biapy_config['DATA']['TEST']['LOAD_GT'] = True

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size_z)+', '+ str(patch_size_xy)+', '+ str(patch_size_xy)+ ', ' + str(input_channels)+')'
# adjust test padding accordingly
padding_xy = patch_size_xy // 8
padding_z = patch_size_z // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+str(padding_z)+', '+ str(padding_xy)+', '+ str(padding_xy)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = True
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe problem representation
#   BC = "Binary mask + Contours"
#   BCM = "Binary mask + Contours + Foreground mask"
#   BCD = "Binary mask + Contours + Distance map"
#   BCDv2 = "Binary mask + Contours + Distance map with background"
#   Dv2 = "Distance map with background"
#   BDv2 = "Binary mask + Distance map with background"
problem_channels = 'BC'
if problem_representation == "Binary mask + Contours":
    problem_channels = 'BC'
elif problem_representation == "Binary mask + Contours + Foreground mask":
    problem_channels = 'BCM'
elif problem_representation == "Binary mask + Contours + Distance map":
    problem_channels = 'BCD'
elif problem_representation == "Binary mask + Contours + Distance map with background":
    problem_channels = 'BCDv2'
elif problem_representation == "Distance map with background":
    problem_channels = 'Dv2'
else:
    problem_channels = 'BDv2'

biapy_config['PROBLEM']['INSTANCE_SEG']['DATA_CHANNELS'] = problem_channels

# Transcribe model architecture
architecture = 'unet'
if model_architecture == "U-Net":
    architecture = 'unet'
else:
    architecture = 'resunet'
biapy_config['MODEL']['ARCHITECTURE'] = architecture
if anisotropic_data == True:
    biapy_config['MODEL']['Z_DOWN'] = 1
else:
    biapy_config['MODEL']['Z_DOWN'] = 2

# update test parameters
biapy_config['TEST']['AUGMENTATION'] = test_time_augmentation

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2023-02-10 15:25:17
# Arguments: Namespace(config='/content/my_3d_instance_segmentation.yaml', gpu='0', name='my_3d_instance_segmentation', result_dir='/content/output', run_id=1)
# Job: my_3d_instance_segmentation_1
# Python       : 3.8.10 (default, Nov 14 2022, 12:59:47)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     MINIMUM_FOREGROUND_PER: -1.0
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [3072, 768]
#   UNETR_NUM_HEADS: 4
#   UNETR_TOKEN_SIZE: 16
#   UNETR_VIT_HIDD_MULT: 3
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     AS_3D_STACK_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/as_3d_stack_post_processing
#     DET_ASSOC_POINTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/point_associations
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CENTRAL_POINT_DILATION: 3
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH_BINARY_MASK: 0.2
#     DATA_MW_TH_CONTOUR: 0.1
#     DATA_MW_TH_DISTANCE: 1.5
#     DATA_MW_TH_DIST_FOREGROUND: 1.2
#     DATA_MW_TH_FOREGROUND: 0.3
#     DATA_MW_TH_POINTS: 0.5
#     DATA_REMOVE_AFTER_MW: False
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ_AFTER: 100
#     DATA_REMOVE_SMALL_OBJ_BEFORE: 10
#     ERODE_AND_DILATE_FOREGROUND: False
#     FORE_DILATION_RADIUS: 5
#     FORE_EROSION_RADIUS: 5
#     SEED_MORPH_RADIUS: []
#     SEED_MORPH_SEQUENCE: []
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   ANALIZE_2D_IMGS_AS_3D_STACK: False
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     DET_WATERSHED: False
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [10.0]
#     REPARE_LARGE_BLOBS_SIZE: -1
#     VORONOI_ON_MASK: False
#     WATERSHED_CIRCULARITY: -1.0
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: True
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ####################
# #  PRE-PROCESSING  #
# ####################
#
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# You select to create BC channels from given instance labels and no file is detected in /content/data/train/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TRAIN.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/train/y
# 100% 27/27 [00:00<00:00, 191.82it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating Y_train channels . . .
# 100% 27/27 [00:02<00:00,  9.29it/s]
# Loading data from /content/data/train/x
# 100% 27/27 [00:00<00:00, 406.20it/s]
# *** Loaded data shape is (27, 64, 128, 128, 1)
# Creating X_train channels . . .
# You select to create BC channels from given instance labels and no file is detected in /content/data/test/x_BC_thick. So let's prepare the data. Notice that, if you do not modify 'DATA.TEST.INSTANCE_CHANNELS_DIR' path, this process will be done just once!
# Loading data from /content/data/test/y
# 100% 3/3 [00:00<00:00, 157.09it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Creating Y_test channels . . .
# 100% 3/3 [00:00<00:00,  9.33it/s]
# Creating X_test channels . . .
# Loading data from /content/data/test/x
# 100% 3/3 [00:00<00:00, 601.36it/s]
# *** Loaded data shape is (3, 64, 128, 128, 1)
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
# Saving (1, 64, 128, 128, 1) data as .tif in folder: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BC_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BC_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BC_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BC_thick
# #################
# #   LOAD DATA   #
# #################
#
# ### LOAD ###
# 0) Loading train images . . .
# Loading data from /content/data/train/x_BC_thick
# 100% 27/27 [00:00<00:00, 419.16it/s]
# *** Loaded data shape is (216, 32, 64, 64, 1)
# 1) Loading train masks . . .
# Loading data from /content/data/train/y_BC_thick
# 100% 27/27 [00:00<00:00, 372.68it/s]
# *** Loaded data shape is (216, 32, 64, 64, 2)
# *** Loaded train data shape is: (194, 32, 64, 64, 1)
# *** Loaded train mask shape is: (194, 32, 64, 64, 2)
# *** Loaded validation data shape is: (22, 32, 64, 64, 1)
# *** Loaded validation mask shape is: (22, 32, 64, 64, 2)
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# Initializing train data generator . . .
# Training data X normalization - min: 0.0009765774011611938 , max: 0.006027313880622387 , mean: 0.002458977047353983 , dtype: float32
# Training data Y normalization - min: 0 , max: 1 , mean: 0.09539134232039304 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Initializing val data generator . . .
# Validation data X normalization - min: 0.001144426641985774 , max: 0.005951018538326025 , mean: 0.002492719329893589 , dtype: float32
# Validation data Y normalization - min: 0 , max: 1 , mean: 0.10428879477761009 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Creating generator samples . . .
# 0) Creating samples of data augmentation . . .
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/imgaug/augmenters/base.py:49: SuspiciousSingleImageShapeWarning: You provided a numpy array of shape (64, 64, 32) as a single-image augmentation input, which was interpreted as (H, W, C). The last dimension however has a size of >=32, which indicates that you provided a multi-image array with shape (N, H, W) instead. If that is the case, you should use e.g. augmenter(imageS=<your input>) or augment_imageS(<your input>). Otherwise your multi-image input will be interpreted as a single image during augmentation.
#   ia.warn(
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  20% 2/10 [00:00<00:00, 12.93it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  40% 4/10 [00:00<00:00, 11.56it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  60% 6/10 [00:00<00:00, 11.94it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  80% 8/10 [00:00<00:00, 12.97it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 10/10 [00:00<00:00, 12.14it/s]
# 2023-02-10 15:25:27.708108: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# #################
# #  BUILD MODEL  #
# #################
#
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 32, 64, 64, 1)]          0                 []
#
#  conv3d_1 (Conv3D)                               (None, 32, 64, 64, 36)           1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, 32, 64, 64, 36)           0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, 32, 64, 64, 36)           72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, 32, 64, 64, 36)           35028             ['elu[0][0]']
#
#  add (Add)                                       (None, 32, 64, 64, 36)           0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, 32, 32, 32, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, 32, 32, 32, 36)           0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, 32, 32, 32, 48)           46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, 32, 32, 32, 48)           1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, 32, 32, 32, 48)           62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, 32, 16, 16, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, 32, 16, 16, 48)           0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, 32, 16, 16, 64)           83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, 32, 16, 16, 64)           3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, 32, 16, 16, 64)           110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, 32, 32, 32, 48)           24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, 32, 32, 32, 96)           0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, 32, 32, 32, 96)           0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, 32, 32, 32, 48)           124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, 32, 32, 32, 48)           4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, 32, 32, 32, 48)           62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, 32, 64, 64, 36)           13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, 32, 64, 64, 72)           0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, 32, 64, 64, 72)           0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, 32, 64, 64, 36)           70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, 32, 64, 64, 36)           2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, 32, 64, 64, 36)           35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, 32, 64, 64, 2)            578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# #####################
# #  TRAIN THE MODEL  #
# #####################
#
# Epoch 1/100
# 97/97 [==============================] - ETA: 0s - loss: 0.7455 - jaccard_index_instances: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.66797, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 37s 264ms/step - loss: 0.7455 - jaccard_index_instances: 0.0020 - val_loss: 0.6680 - val_jaccard_index_instances: 1.7527e-06
# Epoch 2/100
# 97/97 [==============================] - ETA: 0s - loss: 0.5290 - jaccard_index_instances: 0.0649
#
# Epoch 00002: val_loss improved from 0.66797 to 0.51856, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.5290 - jaccard_index_instances: 0.0649 - val_loss: 0.5186 - val_jaccard_index_instances: 0.1561
# Epoch 3/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4492 - jaccard_index_instances: 0.1404
#
# Epoch 00003: val_loss improved from 0.51856 to 0.46830, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.4492 - jaccard_index_instances: 0.1404 - val_loss: 0.4683 - val_jaccard_index_instances: 0.1607
# Epoch 4/100
# 97/97 [==============================] - ETA: 0s - loss: 0.4083 - jaccard_index_instances: 0.1816
#
# Epoch 00004: val_loss improved from 0.46830 to 0.43588, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.4083 - jaccard_index_instances: 0.1816 - val_loss: 0.4359 - val_jaccard_index_instances: 0.1480
# Epoch 5/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3847 - jaccard_index_instances: 0.2099
#
# Epoch 00005: val_loss improved from 0.43588 to 0.41345, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.3847 - jaccard_index_instances: 0.2099 - val_loss: 0.4135 - val_jaccard_index_instances: 0.1780
# Epoch 6/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3670 - jaccard_index_instances: 0.2352
#
# Epoch 00006: val_loss improved from 0.41345 to 0.39001, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.3670 - jaccard_index_instances: 0.2352 - val_loss: 0.3900 - val_jaccard_index_instances: 0.2131
# Epoch 7/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3518 - jaccard_index_instances: 0.2663
#
# Epoch 00007: val_loss improved from 0.39001 to 0.38091, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.3518 - jaccard_index_instances: 0.2663 - val_loss: 0.3809 - val_jaccard_index_instances: 0.2495
# Epoch 8/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3339 - jaccard_index_instances: 0.2959
#
# Epoch 00008: val_loss improved from 0.38091 to 0.36245, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.3339 - jaccard_index_instances: 0.2959 - val_loss: 0.3624 - val_jaccard_index_instances: 0.3107
# Epoch 9/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3213 - jaccard_index_instances: 0.3248
#
# Epoch 00009: val_loss improved from 0.36245 to 0.34196, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 255ms/step - loss: 0.3213 - jaccard_index_instances: 0.3248 - val_loss: 0.3420 - val_jaccard_index_instances: 0.3560
# Epoch 10/100
# 97/97 [==============================] - ETA: 0s - loss: 0.3059 - jaccard_index_instances: 0.3616
#
# Epoch 00010: val_loss improved from 0.34196 to 0.32676, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.3059 - jaccard_index_instances: 0.3616 - val_loss: 0.3268 - val_jaccard_index_instances: 0.3983
# Epoch 11/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2938 - jaccard_index_instances: 0.4032
#
# Epoch 00011: val_loss improved from 0.32676 to 0.31142, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.2938 - jaccard_index_instances: 0.4032 - val_loss: 0.3114 - val_jaccard_index_instances: 0.4260
# Epoch 12/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2808 - jaccard_index_instances: 0.4400
#
# Epoch 00012: val_loss improved from 0.31142 to 0.29780, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.2808 - jaccard_index_instances: 0.4400 - val_loss: 0.2978 - val_jaccard_index_instances: 0.4613
# Epoch 13/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2670 - jaccard_index_instances: 0.4711
#
# Epoch 00013: val_loss improved from 0.29780 to 0.28310, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.2670 - jaccard_index_instances: 0.4711 - val_loss: 0.2831 - val_jaccard_index_instances: 0.4889
# Epoch 14/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2590 - jaccard_index_instances: 0.4877
#
# Epoch 00014: val_loss improved from 0.28310 to 0.27511, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 255ms/step - loss: 0.2590 - jaccard_index_instances: 0.4877 - val_loss: 0.2751 - val_jaccard_index_instances: 0.5020
# Epoch 15/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2495 - jaccard_index_instances: 0.5049
#
# Epoch 00015: val_loss improved from 0.27511 to 0.26150, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.2495 - jaccard_index_instances: 0.5049 - val_loss: 0.2615 - val_jaccard_index_instances: 0.5271
# Epoch 16/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2400 - jaccard_index_instances: 0.5238
#
# Epoch 00016: val_loss improved from 0.26150 to 0.25207, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.2400 - jaccard_index_instances: 0.5238 - val_loss: 0.2521 - val_jaccard_index_instances: 0.5477
# Epoch 17/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2333 - jaccard_index_instances: 0.5355
#
# Epoch 00017: val_loss improved from 0.25207 to 0.24588, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.2333 - jaccard_index_instances: 0.5355 - val_loss: 0.2459 - val_jaccard_index_instances: 0.5502
# Epoch 18/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2262 - jaccard_index_instances: 0.5479
#
# Epoch 00018: val_loss improved from 0.24588 to 0.23980, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.2262 - jaccard_index_instances: 0.5479 - val_loss: 0.2398 - val_jaccard_index_instances: 0.5622
# Epoch 19/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2204 - jaccard_index_instances: 0.5579
#
# Epoch 00019: val_loss improved from 0.23980 to 0.23310, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 255ms/step - loss: 0.2204 - jaccard_index_instances: 0.5579 - val_loss: 0.2331 - val_jaccard_index_instances: 0.5807
# Epoch 20/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2133 - jaccard_index_instances: 0.5742
#
# Epoch 00020: val_loss improved from 0.23310 to 0.22582, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 24s 252ms/step - loss: 0.2133 - jaccard_index_instances: 0.5742 - val_loss: 0.2258 - val_jaccard_index_instances: 0.5922
# Epoch 21/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2083 - jaccard_index_instances: 0.5850
#
# Epoch 00021: val_loss improved from 0.22582 to 0.21853, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.2083 - jaccard_index_instances: 0.5850 - val_loss: 0.2185 - val_jaccard_index_instances: 0.6098
# Epoch 22/100
# 97/97 [==============================] - ETA: 0s - loss: 0.2017 - jaccard_index_instances: 0.5961
#
# Epoch 00022: val_loss improved from 0.21853 to 0.21648, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 261ms/step - loss: 0.2017 - jaccard_index_instances: 0.5961 - val_loss: 0.2165 - val_jaccard_index_instances: 0.6148
# Epoch 23/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1986 - jaccard_index_instances: 0.6047
#
# Epoch 00023: val_loss improved from 0.21648 to 0.21231, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.1986 - jaccard_index_instances: 0.6047 - val_loss: 0.2123 - val_jaccard_index_instances: 0.6159
# Epoch 24/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1952 - jaccard_index_instances: 0.6086
#
# Epoch 00024: val_loss improved from 0.21231 to 0.21044, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1952 - jaccard_index_instances: 0.6086 - val_loss: 0.2104 - val_jaccard_index_instances: 0.6195
# Epoch 25/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1906 - jaccard_index_instances: 0.6160
#
# Epoch 00025: val_loss improved from 0.21044 to 0.20544, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.1906 - jaccard_index_instances: 0.6160 - val_loss: 0.2054 - val_jaccard_index_instances: 0.6331
# Epoch 26/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1889 - jaccard_index_instances: 0.6220
#
# Epoch 00026: val_loss improved from 0.20544 to 0.20026, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1889 - jaccard_index_instances: 0.6220 - val_loss: 0.2003 - val_jaccard_index_instances: 0.6375
# Epoch 27/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1858 - jaccard_index_instances: 0.6281
#
# Epoch 00027: val_loss improved from 0.20026 to 0.19913, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1858 - jaccard_index_instances: 0.6281 - val_loss: 0.1991 - val_jaccard_index_instances: 0.6405
# Epoch 28/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1832 - jaccard_index_instances: 0.6329
#
# Epoch 00028: val_loss improved from 0.19913 to 0.19761, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 259ms/step - loss: 0.1832 - jaccard_index_instances: 0.6329 - val_loss: 0.1976 - val_jaccard_index_instances: 0.6453
# Epoch 29/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1804 - jaccard_index_instances: 0.6389
#
# Epoch 00029: val_loss improved from 0.19761 to 0.19673, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1804 - jaccard_index_instances: 0.6389 - val_loss: 0.1967 - val_jaccard_index_instances: 0.6425
# Epoch 30/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1793 - jaccard_index_instances: 0.6403
#
# Epoch 00030: val_loss improved from 0.19673 to 0.19244, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 258ms/step - loss: 0.1793 - jaccard_index_instances: 0.6403 - val_loss: 0.1924 - val_jaccard_index_instances: 0.6524
# Epoch 31/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1757 - jaccard_index_instances: 0.6479
#
# Epoch 00031: val_loss improved from 0.19244 to 0.19173, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1757 - jaccard_index_instances: 0.6479 - val_loss: 0.1917 - val_jaccard_index_instances: 0.6533
# Epoch 32/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1733 - jaccard_index_instances: 0.6535
#
# Epoch 00032: val_loss improved from 0.19173 to 0.19035, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.1733 - jaccard_index_instances: 0.6535 - val_loss: 0.1903 - val_jaccard_index_instances: 0.6537
# Epoch 33/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1734 - jaccard_index_instances: 0.6506
#
# Epoch 00033: val_loss improved from 0.19035 to 0.18666, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1734 - jaccard_index_instances: 0.6506 - val_loss: 0.1867 - val_jaccard_index_instances: 0.6602
# Epoch 34/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1708 - jaccard_index_instances: 0.6574
#
# Epoch 00034: val_loss improved from 0.18666 to 0.18539, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1708 - jaccard_index_instances: 0.6574 - val_loss: 0.1854 - val_jaccard_index_instances: 0.6650
# Epoch 35/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1691 - jaccard_index_instances: 0.6586
#
# Epoch 00035: val_loss improved from 0.18539 to 0.18225, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.1691 - jaccard_index_instances: 0.6586 - val_loss: 0.1822 - val_jaccard_index_instances: 0.6708
# Epoch 36/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1674 - jaccard_index_instances: 0.6621
#
# Epoch 00036: val_loss improved from 0.18225 to 0.18211, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.1674 - jaccard_index_instances: 0.6621 - val_loss: 0.1821 - val_jaccard_index_instances: 0.6666
# Epoch 37/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1669 - jaccard_index_instances: 0.6618
#
# Epoch 00037: val_loss did not improve from 0.18211
#
#
# 97/97 [==============================] - 24s 250ms/step - loss: 0.1669 - jaccard_index_instances: 0.6618 - val_loss: 0.1829 - val_jaccard_index_instances: 0.6712
# Epoch 38/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1652 - jaccard_index_instances: 0.6691
#
# Epoch 00038: val_loss improved from 0.18211 to 0.17942, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.1652 - jaccard_index_instances: 0.6691 - val_loss: 0.1794 - val_jaccard_index_instances: 0.6745
# Epoch 39/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1637 - jaccard_index_instances: 0.6699
#
# Epoch 00039: val_loss improved from 0.17942 to 0.17885, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 24s 251ms/step - loss: 0.1637 - jaccard_index_instances: 0.6699 - val_loss: 0.1789 - val_jaccard_index_instances: 0.6757
# Epoch 40/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1624 - jaccard_index_instances: 0.6741
#
# Epoch 00040: val_loss did not improve from 0.17885
#
#
# 97/97 [==============================] - 25s 255ms/step - loss: 0.1624 - jaccard_index_instances: 0.6741 - val_loss: 0.1796 - val_jaccard_index_instances: 0.6749
# Epoch 41/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1621 - jaccard_index_instances: 0.6736
#
# Epoch 00041: val_loss improved from 0.17885 to 0.17860, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1621 - jaccard_index_instances: 0.6736 - val_loss: 0.1786 - val_jaccard_index_instances: 0.6766
# Epoch 42/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1598 - jaccard_index_instances: 0.6802
#
# Epoch 00042: val_loss improved from 0.17860 to 0.17547, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 25s 257ms/step - loss: 0.1598 - jaccard_index_instances: 0.6802 - val_loss: 0.1755 - val_jaccard_index_instances: 0.6810
# Epoch 43/100
# ...
# 97/97 [==============================] - ETA: 0s - loss: 0.1341 - jaccard_index_instances: 0.7256
#
# Epoch 00091: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 256ms/step - loss: 0.1341 - jaccard_index_instances: 0.7256 - val_loss: 0.1494 - val_jaccard_index_instances: 0.7285
# Epoch 92/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1341 - jaccard_index_instances: 0.7254
#
# Epoch 00092: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 252ms/step - loss: 0.1341 - jaccard_index_instances: 0.7254 - val_loss: 0.1518 - val_jaccard_index_instances: 0.7235
# Epoch 93/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1332 - jaccard_index_instances: 0.7272
#
# Epoch 00093: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1332 - jaccard_index_instances: 0.7272 - val_loss: 0.1491 - val_jaccard_index_instances: 0.7265
# Epoch 94/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1325 - jaccard_index_instances: 0.7298
#
# Epoch 00094: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1325 - jaccard_index_instances: 0.7298 - val_loss: 0.1494 - val_jaccard_index_instances: 0.7275
# Epoch 95/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1332 - jaccard_index_instances: 0.7263
#
# Epoch 00095: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 253ms/step - loss: 0.1332 - jaccard_index_instances: 0.7263 - val_loss: 0.1519 - val_jaccard_index_instances: 0.7218
# Epoch 96/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1324 - jaccard_index_instances: 0.7287
#
# Epoch 00096: val_loss did not improve from 0.14869
#
#
# 97/97 [==============================] - 25s 254ms/step - loss: 0.1324 - jaccard_index_instances: 0.7287 - val_loss: 0.1500 - val_jaccard_index_instances: 0.7251
# Epoch 97/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1321 - jaccard_index_instances: 0.7306
#
# Epoch 00097: val_loss improved from 0.14869 to 0.14585, saving model to /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#
#
# 97/97 [==============================] - 24s 251ms/step - loss: 0.1321 - jaccard_index_instances: 0.7306 - val_loss: 0.1459 - val_jaccard_index_instances: 0.7337
# Epoch 98/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1317 - jaccard_index_instances: 0.7316
#
# Epoch 00098: val_loss did not improve from 0.14585
#
#
# 97/97 [==============================] - 25s 255ms/step - loss: 0.1317 - jaccard_index_instances: 0.7316 - val_loss: 0.1483 - val_jaccard_index_instances: 0.7291
# Epoch 99/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1328 - jaccard_index_instances: 0.7276
#
# Epoch 00099: val_loss did not improve from 0.14585
#
#
# 97/97 [==============================] - 24s 251ms/step - loss: 0.1328 - jaccard_index_instances: 0.7276 - val_loss: 0.1490 - val_jaccard_index_instances: 0.7255
# Epoch 100/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1316 - jaccard_index_instances: 0.7307
#
# Epoch 00100: val_loss did not improve from 0.14585
#
#
# 97/97 [==============================] - 24s 250ms/step - loss: 0.1316 - jaccard_index_instances: 0.7307 - val_loss: 0.1515 - val_jaccard_index_instances: 0.7223
# Creating training plots . . .
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:06,  2.08it/s]
#
#  14% 2/14 [00:00<00:03,  3.47it/s]
#
#  21% 3/14 [00:00<00:02,  4.81it/s]
#
#  29% 4/14 [00:00<00:01,  5.83it/s]
#
#  36% 5/14 [00:00<00:01,  6.74it/s]
#
#  43% 6/14 [00:01<00:01,  7.55it/s]
#
#  50% 7/14 [00:01<00:00,  8.20it/s]
#
#  57% 8/14 [00:01<00:00,  8.69it/s]
#
#  64% 9/14 [00:01<00:00,  8.86it/s]
#
#  71% 10/14 [00:01<00:00,  8.91it/s]
#
#  79% 11/14 [00:01<00:00,  8.61it/s]
#
#  86% 12/14 [00:01<00:00,  8.37it/s]
#
#  93% 13/14 [00:01<00:00,  8.29it/s]
#
# 100% 14/14 [00:02<00:00,  4.20it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:05,  2.46it/s]
#
#  14% 2/14 [00:00<00:02,  4.24it/s]
#
#  21% 3/14 [00:00<00:01,  5.62it/s]
#
#  29% 4/14 [00:00<00:01,  6.67it/s]
#
#  36% 5/14 [00:00<00:01,  7.31it/s]
#
#  43% 6/14 [00:01<00:01,  6.33it/s]
#
#  50% 7/14 [00:01<00:01,  6.96it/s]
#
#  57% 8/14 [00:01<00:00,  7.41it/s]
#
#  71% 10/14 [00:01<00:00,  8.60it/s]
#
#  86% 12/14 [00:01<00:00,  9.18it/s]
#
#  93% 13/14 [00:01<00:00,  9.35it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.46it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.6430733624626609, mean_matched_score=0.6430733624626609, panoptic_quality=0.5332803493592797), Matching(criterion='iou', thresh=0.5, fp=24, tp=48, fn=3, precision=0.6666666666666666, recall=0.9411764705882353, accuracy=0.64, f1=0.7804878048780488, n_true=51, n_pred=72, mean_true_score=0.6143948798086128, mean_matched_score=0.6527945597966512, panoptic_quality=0.5094981930120205), Matching(criterion='iou', thresh=0.75, fp=68, tp=4, fn=47, precision=0.05555555555555555, recall=0.0784313725490196, accuracy=0.03361344537815126, f1=0.06504065040650407, n_true=51, n_pred=72, mean_true_score=0.059840786690805475, mean_matched_score=0.7629700303077698, panoptic_quality=0.049624067011887464))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.6430733624626609, mean_matched_score=0.6430733624626609, panoptic_quality=0.5332803493592797), Matching(criterion='iou', thresh=0.5, fp=24, tp=48, fn=3, precision=0.6666666666666666, recall=0.9411764705882353, accuracy=0.64, f1=0.7804878048780488, n_true=51, n_pred=72, mean_true_score=0.6143948798086128, mean_matched_score=0.6527945597966512, panoptic_quality=0.5094981930120205), Matching(criterion='iou', thresh=0.75, fp=68, tp=4, fn=47, precision=0.05555555555555555, recall=0.0784313725490196, accuracy=0.03361344537815126, f1=0.06504065040650407, n_true=51, n_pred=72, mean_true_score=0.059840786690805475, mean_matched_score=0.7629700303077698, panoptic_quality=0.049624067011887464))
#
# 100% 1/1 [00:06<00:00,  6.27s/it]
#  33% 1/3 [00:06<00:12,  6.28s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  6.37it/s]
#
#  14% 2/14 [00:00<00:01,  7.06it/s]
#
#  21% 3/14 [00:00<00:01,  7.68it/s]
#
#  29% 4/14 [00:00<00:01,  8.44it/s]
#
#  36% 5/14 [00:00<00:01,  8.74it/s]
#
#  43% 6/14 [00:00<00:00,  9.04it/s]
#
#  50% 7/14 [00:00<00:00,  9.20it/s]
#
#  57% 8/14 [00:00<00:00,  9.42it/s]
#
#  71% 10/14 [00:01<00:00,  9.49it/s]
#
#  79% 11/14 [00:01<00:00,  9.38it/s]
#
#  86% 12/14 [00:01<00:00,  9.48it/s]
#
#  93% 13/14 [00:01<00:00,  9.55it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#  14% 2/14 [00:00<00:01,  7.30it/s]
#
#  29% 4/14 [00:00<00:01,  8.72it/s]
#
#  36% 5/14 [00:00<00:01,  7.52it/s]
#
#  43% 6/14 [00:00<00:00,  8.04it/s]
#
#  57% 8/14 [00:00<00:00,  9.04it/s]
#
#  71% 10/14 [00:01<00:00,  9.51it/s]
#
#  86% 12/14 [00:01<00:00,  9.80it/s]
#
# 100% 14/14 [00:01<00:00, 10.05it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.33it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.6739877700805664, mean_matched_score=0.7094608106111225, panoptic_quality=0.5501940980249521), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.6739877700805664, mean_matched_score=0.7094608106111225, panoptic_quality=0.5501940980249521), Matching(criterion='iou', thresh=0.75, fp=24, tp=5, fn=15, precision=0.1724137931034483, recall=0.25, accuracy=0.11363636363636363, f1=0.20408163265306123, n_true=20, n_pred=29, mean_true_score=0.1957477807998657, mean_matched_score=0.7829911231994628, panoptic_quality=0.1597941067754006))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.6739877700805664, mean_matched_score=0.7094608106111225, panoptic_quality=0.5501940980249521), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.6739877700805664, mean_matched_score=0.7094608106111225, panoptic_quality=0.5501940980249521), Matching(criterion='iou', thresh=0.75, fp=24, tp=5, fn=15, precision=0.1724137931034483, recall=0.25, accuracy=0.11363636363636363, f1=0.20408163265306123, n_true=20, n_pred=29, mean_true_score=0.1957477807998657, mean_matched_score=0.7829911231994628, panoptic_quality=0.1597941067754006))
#
# 100% 1/1 [00:03<00:00,  3.73s/it]
#  67% 2/3 [00:10<00:04,  4.79s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.41it/s]
#
#  14% 2/14 [00:00<00:01,  8.80it/s]
#
#  21% 3/14 [00:00<00:01,  6.93it/s]
#
#  29% 4/14 [00:00<00:01,  7.80it/s]
#
#  36% 5/14 [00:00<00:01,  6.72it/s]
#
#  43% 6/14 [00:00<00:01,  7.49it/s]
#
#  50% 7/14 [00:00<00:00,  8.10it/s]
#
#  57% 8/14 [00:01<00:00,  8.57it/s]
#
#  64% 9/14 [00:01<00:00,  8.67it/s]
#
#  71% 10/14 [00:01<00:00,  9.00it/s]
#
#  79% 11/14 [00:01<00:00,  9.14it/s]
#
#  86% 12/14 [00:01<00:00,  9.10it/s]
#
#  93% 13/14 [00:01<00:00,  9.19it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#  14% 2/14 [00:00<00:01, 10.51it/s]
#
#  29% 4/14 [00:00<00:00, 10.26it/s]
#
#  43% 6/14 [00:00<00:00, 10.29it/s]
#
#  57% 8/14 [00:00<00:00, 10.16it/s]
#
#  71% 10/14 [00:00<00:00, 10.09it/s]
#
#  86% 12/14 [00:01<00:00, 10.20it/s]
#
# 100% 14/14 [00:01<00:00, 10.91it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.45it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.5719611470292254, mean_matched_score=0.5719611470292254, panoptic_quality=0.5719611470292254), Matching(criterion='iou', thresh=0.5, fp=30, tp=134, fn=30, precision=0.8170731707317073, recall=0.8170731707317073, accuracy=0.6907216494845361, f1=0.8170731707317073, n_true=164, n_pred=164, mean_true_score=0.4901865517220846, mean_matched_score=0.5999298095703125, panoptic_quality=0.4901865517220846), Matching(criterion='iou', thresh=0.75, fp=163, tp=1, fn=163, precision=0.006097560975609756, recall=0.006097560975609756, accuracy=0.0030581039755351682, f1=0.006097560975609756, n_true=164, n_pred=164, mean_true_score=0.0047243735412272015, mean_matched_score=0.774797260761261, panoptic_quality=0.0047243735412272015))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.5719611470292254, mean_matched_score=0.5719611470292254, panoptic_quality=0.5719611470292254), Matching(criterion='iou', thresh=0.5, fp=30, tp=134, fn=30, precision=0.8170731707317073, recall=0.8170731707317073, accuracy=0.6907216494845361, f1=0.8170731707317073, n_true=164, n_pred=164, mean_true_score=0.4901865517220846, mean_matched_score=0.5999298095703125, panoptic_quality=0.4901865517220846), Matching(criterion='iou', thresh=0.75, fp=163, tp=1, fn=163, precision=0.006097560975609756, recall=0.006097560975609756, accuracy=0.0030581039755351682, f1=0.006097560975609756, n_true=164, n_pred=164, mean_true_score=0.0047243735412272015, mean_matched_score=0.774797260761261, panoptic_quality=0.0047243735412272015))
#
# 100% 1/1 [00:03<00:00,  3.71s/it]
# 100% 3/3 [00:13<00:00,  4.58s/it]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 24.715217690467835
# Epoch number: 100
# Train time (s): 2471.5217690467834
# Train loss: 0.13163577020168304
# Train jaccard_index_instances: 0.7316464185714722
# Validation loss: 0.14585381746292114
# Validation jaccard_index_instances: 0.7337016463279724
# Loss (per patch): 0.0740075225447431
# Test Foreground IoU (per patch): 0.36868306001027423
#
# Test Foreground IoU (merge patches): 0.7598582573718332
# Test Overall IoU (merge patches): 0.8664509508783474
#
# Instance segmentation specific metrics:
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.5960771276595744, mean_matched_score=0.5986244658119658, panoptic_quality=0.5603125, by_image=False)
# IoU (post-processing) TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.5960771276595744, mean_matched_score=0.5986244658119658, panoptic_quality=0.5603125, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=64, tp=201, fn=34, precision=0.7584905660377359, recall=0.8553191489361702, accuracy=0.6722408026755853, f1=0.804, n_true=235, n_pred=265, mean_true_score=0.532785058528819, mean_matched_score=0.6229079042501118, panoptic_quality=0.5008179550170898, by_image=False)
# IoU (post-processing) TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=64, tp=201, fn=34, precision=0.7584905660377359, recall=0.8553191489361702, accuracy=0.6722408026755853, f1=0.804, n_true=235, n_pred=265, mean_true_score=0.532785058528819, mean_matched_score=0.6229079042501118, panoptic_quality=0.5008179550170898, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=255, tp=10, fn=225, precision=0.03773584905660377, recall=0.0425531914893617, accuracy=0.02040816326530612, f1=0.04, n_true=235, n_pred=265, mean_true_score=0.03294311914038151, mean_matched_score=0.7741632997989655, panoptic_quality=0.030966531991958618, by_image=False)
# IoU (post-processing) TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=255, tp=10, fn=225, precision=0.03773584905660377, recall=0.0425531914893617, accuracy=0.02040816326530612, f1=0.04, n_true=235, n_pred=265, mean_true_score=0.03294311914038151, mean_matched_score=0.7741632997989655, panoptic_quality=0.030966531991958618, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **Jaccard index or Intersection over Union** (IoU) metric is a method that can be used to quantify the overlap between the target mask and your prediction output. **Therefore, the closer to 1, the better the performance.** This metric can be used to assess the quality of your model to accurately predict cells.

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and IoU vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_jaccard_index_instances.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Intersection over Union (IoU) vs epoch number', fontdict = {'fontsize':22})

# %% [markdown]
# ## **Visualize instance segmentation results**

# %%
#@markdown ###Play to visualize results in 3D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact, fixed
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
instance_results = os.path.join(final_results, "per_image_instances")

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(aux)
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(aux)

# function to show results in 3D within a widget
def scroll_in_z(z, j):

    plt.figure(figsize=(25,5))
    # Source
    plt.subplot(1,4,1)
    plt.axis('off')
    plt.imshow(test_samples[j][z-1], cmap='gray')
    plt.title('Source (z = ' + str(z) + ')', fontsize=15)

    # Target (Ground-truth)
    plt.subplot(1,4,2)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Ground truth (z = ' + str(z) + ')', fontsize=15)

    # Prediction
    plt.subplot(1,4,3)
    plt.axis('off')
    plt.imshow(test_sample_preds[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Prediction (z = ' + str(z) + ')', fontsize=15)
    
    # Overlay
    plt.subplot(1,4,4)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap='Greens')
    plt.imshow(test_sample_preds[j][z-1], alpha=0.5, cmap='Purples')
    plt.title('Overlay (z = ' + str(z) + ')', fontsize=15)

for j in range(samples_to_show):
    interact(scroll_in_z, z=widgets.IntSlider(min=1, max=test_sample_gt[j].shape[0], step=1, value=test_sample_gt[j].shape[0]//2), j=fixed(j));
# Out:
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…

# %%
#@markdown ###Play to display the path to the output files (one 3D TIFF label image for each input image).

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

instance_results = os.path.join(final_results, "per_image_instances")

print("Output paths:")
print("    Instance segmentation files are in {}".format(instance_results))
# Out:
# Output paths:
#     Instance segmentation files are in /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances

# %% [markdown]
# ## **Download instance segmentation results**

# %%
#@markdown ###Play to download a zip file with all instance segmentation results in test.

from google.colab import files

# !zip -q -j /content/instance_segmentation_results.zip $instance_results/*.tif

files.download("/content/instance_segmentation_results.zip")

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))

# %% [markdown]
# ## **Advanced options**

# %% [markdown]
# ### **Adjust marker-controlled watershed threshold values**

# %%
#@markdown ### Marker-controlled watershed parameters:
binary_mask_seed_threshold =  0.2#@param {type:"number"}
contour_threshold =  0.1 #@param {type:"number"}
binary_mask_grow_threshold =  0.1#@param {type:"number"}
distance_seed_threshold =  1.5 #@param {type:"number"}
distance_grow_threshold =  1.2#@param {type:"number"}

# %%
#@markdown ### Play to create inference YAML with new parameters
# Transcribe model architecture

biapy_config_inference = biapy_config

# set the training to false to peform inference
biapy_config_inference['TRAIN']['ENABLE'] = False

biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_BINARY_MASK'] = binary_mask_seed_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_CONTOUR'] = contour_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_FOREGROUND'] = binary_mask_grow_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_DISTANCE'] = distance_seed_threshold
biapy_config_inference['PROBLEM']['INSTANCE_SEG']['DATA_MW_TH_DIST_FOREGROUND'] = distance_grow_threshold

# save file
inference_file = "/content/"+str(job_name)+"_inference.yaml"

with open( inference_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Inference configuration finished.")
# Out:
# Inference configuration finished.

# %% [markdown]
# ### **Run inference**

# %%
#@markdown ### Play to run inference on test with the new parameters

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'_inference.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2023-02-10 16:20:51
# Arguments: Namespace(config='/content/my_3d_instance_segmentation_inference.yaml', gpu='0', name='my_3d_instance_segmentation', result_dir='/content/output', run_id=1)
# Job: my_3d_instance_segmentation_1
# Python       : 3.8.10 (default, Nov 14 2022, 12:59:47)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Python process limited to 1 thread
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: True
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: False
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (32, 64, 64, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: False
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (4, 8, 8)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     MINIMUM_FOREGROUND_PER: -1.0
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /path/to/data/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /path/to/data_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /path/to/data_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /path/to/data_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /path/to/data
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0, 0)
#     PADDING: (0, 0, 0)
#     PATH: /path/to/data
#     RANDOM: True
#     RESOLUTION: (1, 1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /path/to/data_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [3072, 768]
#   UNETR_NUM_HEADS: 4
#   UNETR_TOKEN_SIZE: 16
#   UNETR_VIT_HIDD_MULT: 3
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/charts
#   CHECKPOINT: /content/output/my_3d_instance_segmentation/checkpoints
#   CHECKPOINT_FILE: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
#   DA_SAMPLES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/aug
#   GEN_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/gen_mask_check
#   MEAN_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_3d_instance_segmentation/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     AS_3D_STACK_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/as_3d_stack_post_processing
#     DET_ASSOC_POINTS: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/point_associations
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/full_image_binarized
#     PATH: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1
#     PER_IMAGE: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image
#     PER_IMAGE_BIN: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_instances
#     PER_IMAGE_POST_PROCESSING: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_3d_instance_segmentation/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_3d_instance_segmentation/results/my_3d_instance_segmentation_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CENTRAL_POINT_DILATION: 3
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH_BINARY_MASK: 0.2
#     DATA_MW_TH_CONTOUR: 0.1
#     DATA_MW_TH_DISTANCE: 1.5
#     DATA_MW_TH_DIST_FOREGROUND: 1.2
#     DATA_MW_TH_FOREGROUND: 0.1
#     DATA_MW_TH_POINTS: 0.5
#     DATA_REMOVE_AFTER_MW: False
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ_AFTER: 100
#     DATA_REMOVE_SMALL_OBJ_BEFORE: 10
#     ERODE_AND_DILATE_FOREGROUND: False
#     FORE_DILATION_RADIUS: 5
#     FORE_EROSION_RADIUS: 5
#     SEED_MORPH_RADIUS: []
#     SEED_MORPH_SEQUENCE: []
#   NDIM: 3D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: INSTANCE_SEG
# SYSTEM:
#   NUM_CPUS: 1
#   SEED: 0
# TEST:
#   ANALIZE_2D_IMGS_AS_3D_STACK: False
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: False
#   DET_MIN_TH_TO_BE_PEAK: [0.2]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     DET_WATERSHED: False
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: False
#     REMOVE_CLOSE_POINTS_RADIUS: [10.0]
#     REPARE_LARGE_BLOBS_SIZE: -1
#     VORONOI_ON_MASK: False
#     WATERSHED_CIRCULARITY: -1.0
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: False
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: False
# TRAIN:
#   BATCH_SIZE: 2
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: False
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ####################
# #  PRE-PROCESSING  #
# ####################
#
# ###########################
# #  PREPARE INSTANCE DATA  #
# ###########################
#
# DATA.TRAIN.PATH changed from /content/data/train/x to /content/data/train/x_BC_thick
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_BC_thick
# DATA.TEST.PATH changed from /content/data/test/x to /content/data/test/x_BC_thick
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_BC_thick
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# #################
# #  BUILD MODEL  #
# #################
#
# 2023-02-10 16:20:53.024653: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, 32, 64, 64, 1)]          0                 []
#
#  conv3d_1 (Conv3D)                               (None, 32, 64, 64, 36)           1008              ['input_1[0][0]']
#
#  elu (ELU)                                       (None, 32, 64, 64, 36)           0                 ['conv3d_1[0][0]']
#
#  conv3d (Conv3D)                                 (None, 32, 64, 64, 36)           72                ['input_1[0][0]']
#
#  conv3d_2 (Conv3D)                               (None, 32, 64, 64, 36)           35028             ['elu[0][0]']
#
#  add (Add)                                       (None, 32, 64, 64, 36)           0                 ['conv3d[0][0]',
#                                                                                                      'conv3d_2[0][0]']
#
#  max_pooling3d (MaxPooling3D)                    (None, 32, 32, 32, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, 32, 32, 32, 36)           0                 ['max_pooling3d[0][0]']
#
#  conv3d_4 (Conv3D)                               (None, 32, 32, 32, 48)           46704             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_4[0][0]']
#
#  conv3d_3 (Conv3D)                               (None, 32, 32, 32, 48)           1776              ['max_pooling3d[0][0]']
#
#  conv3d_5 (Conv3D)                               (None, 32, 32, 32, 48)           62256             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_3[0][0]',
#                                                                                                      'conv3d_5[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)                  (None, 32, 16, 16, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, 32, 16, 16, 48)           0                 ['max_pooling3d_1[0][0]']
#
#  conv3d_7 (Conv3D)                               (None, 32, 16, 16, 64)           83008             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_7[0][0]']
#
#  conv3d_6 (Conv3D)                               (None, 32, 16, 16, 64)           3136              ['max_pooling3d_1[0][0]']
#
#  conv3d_8 (Conv3D)                               (None, 32, 16, 16, 64)           110656            ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, 32, 16, 16, 64)           0                 ['conv3d_6[0][0]',
#                                                                                                      'conv3d_8[0][0]']
#
#  conv3d_transpose (Conv3DTranspose)              (None, 32, 32, 32, 48)           24624             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, 32, 32, 32, 96)           0                 ['conv3d_transpose[0][0]',
#                                                                                                      'add_1[0][0]']
#
#  elu_5 (ELU)                                     (None, 32, 32, 32, 96)           0                 ['concatenate[0][0]']
#
#  conv3d_10 (Conv3D)                              (None, 32, 32, 32, 48)           124464            ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_10[0][0]']
#
#  conv3d_9 (Conv3D)                               (None, 32, 32, 32, 48)           4656              ['concatenate[0][0]']
#
#  conv3d_11 (Conv3D)                              (None, 32, 32, 32, 48)           62256             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, 32, 32, 32, 48)           0                 ['conv3d_9[0][0]',
#                                                                                                      'conv3d_11[0][0]']
#
#  conv3d_transpose_1 (Conv3DTranspose)            (None, 32, 64, 64, 36)           13860             ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, 32, 64, 64, 72)           0                 ['conv3d_transpose_1[0][0]',
#                                                                                                      'add[0][0]']
#
#  elu_7 (ELU)                                     (None, 32, 64, 64, 72)           0                 ['concatenate_1[0][0]']
#
#  conv3d_13 (Conv3D)                              (None, 32, 64, 64, 36)           70020             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_13[0][0]']
#
#  conv3d_12 (Conv3D)                              (None, 32, 64, 64, 36)           2628              ['concatenate_1[0][0]']
#
#  conv3d_14 (Conv3D)                              (None, 32, 64, 64, 36)           35028             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, 32, 64, 64, 36)           0                 ['conv3d_12[0][0]',
#                                                                                                      'conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)                              (None, 32, 64, 64, 2)            578               ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 681,758
# Trainable params: 681,758
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Loading model weights from h5_file: /content/output/my_3d_instance_segmentation/checkpoints/model_weights_my_3d_instance_segmentation_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0027.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:04<01:02,  4.81s/it]
#
#  14% 2/14 [00:04<00:25,  2.09s/it]
#
#  21% 3/14 [00:05<00:13,  1.21s/it]
#
#  29% 4/14 [00:05<00:07,  1.28it/s]
#
#  36% 5/14 [00:05<00:04,  1.82it/s]
#
#  43% 6/14 [00:05<00:03,  2.39it/s]
#
#  50% 7/14 [00:05<00:02,  2.95it/s]
#
#  57% 8/14 [00:05<00:01,  3.60it/s]
#
#  64% 9/14 [00:06<00:01,  4.26it/s]
#
#  71% 10/14 [00:06<00:00,  4.44it/s]
#
#  79% 11/14 [00:06<00:00,  4.76it/s]
#
#  86% 12/14 [00:06<00:00,  5.14it/s]
#
#  93% 13/14 [00:06<00:00,  5.64it/s]
#
# 100% 14/14 [00:07<00:00,  3.46it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:07,  1.82it/s]
#
#  14% 2/14 [00:00<00:04,  2.90it/s]
#
#  21% 3/14 [00:00<00:02,  4.00it/s]
#
#  29% 4/14 [00:01<00:02,  4.57it/s]
#
#  36% 5/14 [00:01<00:01,  4.71it/s]
#
#  43% 6/14 [00:01<00:01,  4.95it/s]
#
#  50% 7/14 [00:01<00:01,  4.54it/s]
#
#  57% 8/14 [00:01<00:01,  4.62it/s]
#
#  64% 9/14 [00:02<00:01,  4.53it/s]
#
#  71% 10/14 [00:02<00:00,  4.28it/s]
#
#  79% 11/14 [00:02<00:00,  4.97it/s]
#
#  86% 12/14 [00:02<00:00,  4.94it/s]
#
#  93% 13/14 [00:03<00:00,  4.50it/s]
#
# 100% 14/14 [00:03<00:00,  5.14it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  1.70it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.5, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.75, fp=47, tp=25, fn=26, precision=0.3472222222222222, recall=0.49019607843137253, accuracy=0.25510204081632654, f1=0.4065040650406504, n_true=51, n_pred=72, mean_true_score=0.3875579086004519, mean_matched_score=0.7906181335449218, panoptic_quality=0.3213894851808626))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.5, fp=21, tp=51, fn=0, precision=0.7083333333333334, recall=1.0, accuracy=0.7083333333333334, f1=0.8292682926829268, n_true=51, n_pred=72, mean_true_score=0.7333308201210171, mean_matched_score=0.7333308201210171, panoptic_quality=0.6081279971735264), Matching(criterion='iou', thresh=0.75, fp=47, tp=25, fn=26, precision=0.3472222222222222, recall=0.49019607843137253, accuracy=0.25510204081632654, f1=0.4065040650406504, n_true=51, n_pred=72, mean_true_score=0.3875579086004519, mean_matched_score=0.7906181335449218, panoptic_quality=0.3213894851808626))
#
# 100% 1/1 [00:13<00:00, 13.98s/it]
#  33% 1/3 [00:13<00:27, 14.00s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0028.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:02,  4.87it/s]
#
#  14% 2/14 [00:00<00:03,  3.80it/s]
#
#  21% 3/14 [00:00<00:03,  3.66it/s]
#
#  29% 4/14 [00:00<00:02,  4.47it/s]
#
#  36% 5/14 [00:01<00:01,  5.34it/s]
#
#  43% 6/14 [00:01<00:01,  5.26it/s]
#
#  50% 7/14 [00:01<00:01,  5.88it/s]
#
#  57% 8/14 [00:01<00:00,  6.36it/s]
#
#  64% 9/14 [00:01<00:00,  6.89it/s]
#
#  71% 10/14 [00:01<00:00,  7.22it/s]
#
#  79% 11/14 [00:01<00:00,  7.38it/s]
#
#  86% 12/14 [00:02<00:00,  6.49it/s]
#
#  93% 13/14 [00:02<00:00,  6.76it/s]
#
# 100% 14/14 [00:02<00:00,  7.14it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  7.74it/s]
#
#  14% 2/14 [00:00<00:01,  8.02it/s]
#
#  29% 4/14 [00:00<00:01,  9.35it/s]
#
#  43% 6/14 [00:00<00:00,  9.85it/s]
#
#  57% 8/14 [00:00<00:00, 10.03it/s]
#
#  71% 10/14 [00:01<00:00, 10.25it/s]
#
#  86% 12/14 [00:01<00:00, 10.20it/s]
#
# 100% 14/14 [00:01<00:00, 10.28it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.36it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.75, fp=15, tp=14, fn=6, precision=0.4827586206896552, recall=0.7, accuracy=0.4, f1=0.5714285714285714, n_true=20, n_pred=29, mean_true_score=0.5661441326141358, mean_matched_score=0.8087773323059082, panoptic_quality=0.46215847560337614))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.5, fp=10, tp=19, fn=1, precision=0.6551724137931034, recall=0.95, accuracy=0.6333333333333333, f1=0.7755102040816326, n_true=20, n_pred=29, mean_true_score=0.7403806209564209, mean_matched_score=0.7793480220593905, panoptic_quality=0.6043923436378946), Matching(criterion='iou', thresh=0.75, fp=15, tp=14, fn=6, precision=0.4827586206896552, recall=0.7, accuracy=0.4, f1=0.5714285714285714, n_true=20, n_pred=29, mean_true_score=0.5661441326141358, mean_matched_score=0.8087773323059082, panoptic_quality=0.46215847560337614))
#
# 100% 1/1 [00:04<00:00,  4.45s/it]
#  67% 2/3 [00:18<00:08,  8.39s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['stack_0029.tif']
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#   7% 1/14 [00:00<00:01,  9.31it/s]
#
#  14% 2/14 [00:00<00:01,  9.49it/s]
#
#  21% 3/14 [00:00<00:01,  9.44it/s]
#
#  29% 4/14 [00:00<00:01,  9.28it/s]
#
#  36% 5/14 [00:00<00:00,  9.32it/s]
#
#  43% 6/14 [00:00<00:00,  9.29it/s]
#
#  50% 7/14 [00:00<00:00,  9.08it/s]
#
#  57% 8/14 [00:00<00:00,  9.28it/s]
#
#  64% 9/14 [00:00<00:00,  9.44it/s]
#
#  71% 10/14 [00:01<00:00,  9.57it/s]
#
#  79% 11/14 [00:01<00:00,  9.63it/s]
#
#  86% 12/14 [00:01<00:00,  9.71it/s]
#
#  93% 13/14 [00:01<00:00,  9.77it/s]
#
#
#
#   0% 0/14 [00:00<?, ?it/s]
#
#  14% 2/14 [00:00<00:01, 10.22it/s]
#
#  29% 4/14 [00:00<00:00, 10.28it/s]
#
#  43% 6/14 [00:00<00:00, 10.37it/s]
#
#  57% 8/14 [00:00<00:00, 10.47it/s]
#
#  71% 10/14 [00:00<00:00, 10.56it/s]
#
#  86% 12/14 [00:01<00:00, 10.49it/s]
#
# 100% 14/14 [00:01<00:00, 10.41it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.39it/s]
#
#                                  Creating instances with watershed . . .
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6773291331965748, mean_matched_score=0.6773291331965748, panoptic_quality=0.6773291331965748), Matching(criterion='iou', thresh=0.5, fp=3, tp=161, fn=3, precision=0.9817073170731707, recall=0.9817073170731707, accuracy=0.9640718562874252, f1=0.9817073170731707, n_true=164, n_pred=164, mean_true_score=0.668599710231874, mean_matched_score=0.6810580899256357, panoptic_quality=0.668599710231874), Matching(criterion='iou', thresh=0.75, fp=130, tp=34, fn=130, precision=0.2073170731707317, recall=0.2073170731707317, accuracy=0.11564625850340136, f1=0.2073170731707317, n_true=164, n_pred=164, mean_true_score=0.1595983970456007, mean_matched_score=0.7698275622199563, panoptic_quality=0.1595983970456007))
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Calculating matching stats after post-processing . . .
# (Matching(criterion='iou', thresh=0.3, fp=0, tp=164, fn=0, precision=1.0, recall=1.0, accuracy=1.0, f1=1.0, n_true=164, n_pred=164, mean_true_score=0.6773291331965748, mean_matched_score=0.6773291331965748, panoptic_quality=0.6773291331965748), Matching(criterion='iou', thresh=0.5, fp=3, tp=161, fn=3, precision=0.9817073170731707, recall=0.9817073170731707, accuracy=0.9640718562874252, f1=0.9817073170731707, n_true=164, n_pred=164, mean_true_score=0.668599710231874, mean_matched_score=0.6810580899256357, panoptic_quality=0.668599710231874), Matching(criterion='iou', thresh=0.75, fp=130, tp=34, fn=130, precision=0.2073170731707317, recall=0.2073170731707317, accuracy=0.11564625850340136, f1=0.2073170731707317, n_true=164, n_pred=164, mean_true_score=0.1595983970456007, mean_matched_score=0.7698275622199563, panoptic_quality=0.1595983970456007))
#
# 100% 1/1 [00:03<00:00,  3.53s/it]
# 100% 3/3 [00:21<00:00,  7.33s/it]
# #############
# #  RESULTS  #
# #############
#
# Loss (per patch): 0.0740075225447431
# Test Foreground IoU (per patch): 0.36868306001027423
#
# Test Foreground IoU (merge patches): 0.7598582573718332
# Test Overall IoU (merge patches): 0.8664509508783474
#
# Instance segmentation specific metrics:
# IoU TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.6948487748491003, mean_matched_score=0.6978182140578572, panoptic_quality=0.6531578483581543, by_image=False)
# IoU (post-processing) TH=0.3
# DatasetMatching(criterion='iou', thresh=0.3, fp=31, tp=234, fn=1, precision=0.8830188679245283, recall=0.9957446808510638, accuracy=0.8796992481203008, f1=0.936, n_true=235, n_pred=265, mean_true_score=0.6948487748491003, mean_matched_score=0.6978182140578572, panoptic_quality=0.6531578483581543, by_image=False)
# IoU TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=34, tp=231, fn=4, precision=0.8716981132075472, recall=0.9829787234042553, accuracy=0.8587360594795539, f1=0.924, n_true=235, n_pred=265, mean_true_score=0.6887567520141602, mean_matched_score=0.7006832758585612, panoptic_quality=0.6474313468933105, by_image=False)
# IoU (post-processing) TH=0.5
# DatasetMatching(criterion='iou', thresh=0.5, fp=34, tp=231, fn=4, precision=0.8716981132075472, recall=0.9829787234042553, accuracy=0.8587360594795539, f1=0.924, n_true=235, n_pred=265, mean_true_score=0.6887567520141602, mean_matched_score=0.7006832758585612, panoptic_quality=0.6474313468933105, by_image=False)
# IoU TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=192, tp=73, fn=162, precision=0.27547169811320754, recall=0.31063829787234043, accuracy=0.17096018735362997, f1=0.292, n_true=235, n_pred=265, mean_true_score=0.24367009832503947, mean_matched_score=0.7844174398134832, panoptic_quality=0.2290498924255371, by_image=False)
# IoU (post-processing) TH=0.75
# DatasetMatching(criterion='iou', thresh=0.75, fp=192, tp=73, fn=162, precision=0.27547169811320754, recall=0.31063829787234043, accuracy=0.17096018735362997, f1=0.292, n_true=235, n_pred=265, mean_true_score=0.24367009832503947, mean_matched_score=0.7844174398134832, panoptic_quality=0.2290498924255371, by_image=False)
# FINISHED JOB my_3d_instance_segmentation_1 !!

# %%
#@markdown ###Play to visualize results in 3D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact, fixed
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
instance_results = os.path.join(final_results, "per_image_instances")

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(instance_results))[2])
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(aux)
    
    aux = imread(os.path.join(instance_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(aux)
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(aux)

# function to show results in 3D within a widget
def scroll_in_z(z, j):

    plt.figure(figsize=(25,5))
    # Source
    plt.subplot(1,4,1)
    plt.axis('off')
    plt.imshow(test_samples[j][z-1], cmap='gray')
    plt.title('Source (z = ' + str(z) + ')', fontsize=15)

    # Target (Ground-truth)
    plt.subplot(1,4,2)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Ground truth (z = ' + str(z) + ')', fontsize=15)

    # Prediction
    plt.subplot(1,4,3)
    plt.axis('off')
    plt.imshow(test_sample_preds[j][z-1], cmap=cmap, interpolation='nearest')
    plt.title('Prediction (z = ' + str(z) + ')', fontsize=15)
    
    # Overlay
    plt.subplot(1,4,4)
    plt.axis('off')
    plt.imshow(test_sample_gt[j][z-1], cmap='Greens')
    plt.imshow(test_sample_preds[j][z-1], alpha=0.5, cmap='Purples')
    plt.title('Overlay (z = ' + str(z) + ')', fontsize=15)

for j in range(samples_to_show):
    interact(scroll_in_z, z=widgets.IntSlider(min=1, max=test_sample_gt[j].shape[0], step=1, value=test_sample_gt[j].shape[0]//2), j=fixed(j));
# Out:
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=32, description='z', max=64, min=1), Output()), _dom_classes=('widget-in…

# %% [markdown]
# ## **Acknowledgments**
# We would like to acknowledge the inspiration provided by the excellent [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki). In particular, we have reused some of their descriptions of metrics and parameters, as well as their 3D visualization widget code from their [U-Net 3D notebook](https://colab.research.google.com/github/HenriquesLab/ZeroCostDL4Mic/blob/master/Colab_notebooks/U-Net_3D_ZeroCostDL4Mic.ipynb). We would also like to extend our special thanks to [Estibaliz Gomez-de-Mariscal](https://scholar.google.es/citations?user=gsg-TAUAAAAJ) for her support and insightful comments, which helped us to improve this notebook.
