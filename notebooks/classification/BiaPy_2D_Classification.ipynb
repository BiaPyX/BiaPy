# %% [markdown]
# # **2D Classification pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **2D classification** of microscopy data.
#
# <figure>
# <center>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test1008_0.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test10_1.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test1002_2.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test1030_3.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test1003_4.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test0_5.png' width='50px'/>
# <img src='https://biapy.readthedocs.io/en/latest/_images/MedMNIST_DermaMNIST_test1021_6.png' width='50px'/>
# <figcaption><b>Figure 1</b>: Example of a 2D classification problem. These examples belong to various classes and were sourced from  <a href="https://medmnist.com/">MedMNIST v2</a>, specifically from the DermaMNIST dataset which is a large collection of multi-source dermatoscopic images of common pigmented skin lesions.</figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their corresponding semantic label images,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the classification results** to your local machine.
#
# **Disclaimer:** The structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 2D images to train the model.
# * **Test raw images**: with the raw 2D images to test the model.
# * **Output folder**: a path to store the classification results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing the classification results. The resulting csv file can be downloaded at the end of the notebook.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`. The file uploaded need to be a ZIP file containing train, val (if used) and test folders.

# %%
#@markdown ##Play the cell to upload local files in a .zip file (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/
# %cd /content/input/train/
uploaded = files.upload()
filename = list(uploaded.keys())[0]
if not filename.endswith('.zip'):
    raise ValueError("{} file uploaded has not .zip extension".format(filename))
# !unzip -q {filename}
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use a particular subset of [MedMNIST v2](https://medmnist.com/") dataset, concretely DermaMNIST dataset publicly available online.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')

# !curl -L -s -o DermaMNIST.zip 'https://drive.google.com/uc?id=15_pnH4_tJcwhOhNqFsm26NQuJbNbFSIN&confirm=t'

# !unzip -q DermaMNIST.zip
# !rm DermaMNIST.zip

print('Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train', val_data_path as '/content/data/val' (if not using validation from train which can be ignored if so), test_data_path as '/content/data/test' and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train' #@param {type:"string"}
#@markdown #####Path to validation images (necessary only if you do not want to extract validation from train, i.e. when **validation_from_train** variable below is **False**)
val_data_path = '/content/data/validation' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone https://github.com/danifranco/BiaPy.git
    # !git checkout b3a0cce3c8d07217a7bf8723bc15cb1745154cc9 &> /dev/null
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs fill_voids &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Cloning into 'BiaPy'...
# remote: Enumerating objects: 15560, done.
# remote: Counting objects: 100% (1629/1629), done.
# remote: Compressing objects: 100% (453/453), done.
# remote: Total 15560 (delta 1159), reused 1624 (delta 1157), pack-reused 13931
# Receiving objects: 100% (15560/15560), 820.00 MiB | 36.28 MiB/s, done.
# Resolving deltas: 100% (8428/8428), done.

# %% [markdown]
# ## **Configure and train the DNN model**
# [BiaPy](https://biapy.readthedocs.io/en/latest/) contains a few deep learning models to perform classification.
#
# The selection of the model and the pipeline hyperparameters can be configured by editing the YAML configuration file or (easier) by running the next cell.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
#
# #### **Data training parameters**
# * **`validation_from_train`:** Select to extract validation data from the training samples. If is not selected the validation data path must be set in **val_data_path** variable above.
#
#
# #### **Basic training parameters**
# * **`number_of_classes`:** Input number of classes present in the problem. It must be equal to the number of subfolders in training and validation (if not extracted from train) folders.
#
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, reasonable results can already be observed after 100 epochs. **Default value: 100**
#
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. Only needed when **validation_from_train** is **True**. **Default value: 10**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: EfficientNet B0 and a simple CNN. **Default value: EfficientNet B0**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 12**
#
# * **`patch_size`:** Input the size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 28**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 3**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: SGD**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.001**

# %%
#@markdown ###Name of the model:
model_name = "my_2d_classification" #@param {type:"string"}

#@markdown ### Data management parameters:
validation_from_train = False #@param {type:"boolean"}

#@markdown ### Basic training parameters:
number_of_classes = 7#@param {type:"number"}
number_of_epochs =  100#@param {type:"number"}
percentage_validation =  10 #@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "simple_cnn" #@param ["EfficientNetB0", "simple_cnn"]

batch_size =  12#@param {type:"number"}
patch_size = 28 #@param {type:"number"}

input_channels = 3 #@param {type:"number"}

optimizer = "SGD" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.001 #@param {type:"number"}

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# Download template file 
import shutil
shutil.copy("/content/BiaPy/templates/classification/classification_2d.yaml", yaml_file)

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[1])
if len(ids) == 0:
    raise ValueError("No folders found in dir {}".format(train_data_path))

if not os.path.exists(val_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), val_data_path)
ids = sorted(next(os.walk(val_data_path))[1])
if len(ids) == 0:
    raise ValueError("No folders found in dir {}".format(val_data_path))

if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[1])
if len(ids) == 0:
    raise ValueError("No folders found in dir {}".format(test_data_path))


# open template configuration file
import yaml
with open( yaml_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['VAL']['PATH'] = val_data_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size)+', '+ str(patch_size)+', ' + str(input_channels)+')'
# adjust test padding accordingly
padding = patch_size // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+str(padding)+', '+ str(padding)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = validation_from_train
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe model architecture
# Available models: "simple_cnn", "EfficientNetB0"
architecture = 'simple_cnn'
if model_architecture == "simple_cnn":
    architecture = 'simple_cnn'
else:
    architecture = 'EfficientNetB0'
biapy_config['MODEL']['N_CLASSES'] = number_of_classes   
biapy_config['MODEL']['ARCHITECTURE'] = architecture

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1893_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1894_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1295/2005 [00:50<00:28, 25.07it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1895_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1896_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1897_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1298/2005 [00:51<00:27, 25.38it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1899_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test18_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1902_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1301/2005 [00:51<00:26, 26.56it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1903_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1904_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1907_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1304/2005 [00:51<00:26, 26.05it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1909_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test190_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1910_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1307/2005 [00:51<00:26, 26.19it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1912_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1913_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1915_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1310/2005 [00:51<00:25, 27.00it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1918_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1919_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1920_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  65% 1313/2005 [00:51<00:26, 26.10it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1921_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1922_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1924_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1316/2005 [00:51<00:25, 26.67it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1925_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1926_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1927_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1319/2005 [00:51<00:25, 26.60it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1928_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1930_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1931_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1322/2005 [00:51<00:24, 27.33it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1933_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1936_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  3.77it/s]
#
#
# 100% 1/1 [00:00<00:00,  3.76it/s]
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1937_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1325/2005 [00:52<00:41, 16.46it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1938_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1939_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test193_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1328/2005 [00:52<00:36, 18.62it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1941_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1942_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1945_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  66% 1331/2005 [00:52<00:32, 20.96it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1946_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1947_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1948_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1334/2005 [00:52<00:30, 22.02it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1949_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1951_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1952_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1337/2005 [00:52<00:28, 23.31it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1953_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1954_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1955_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1340/2005 [00:52<00:27, 24.49it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1957_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1958_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test195_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1343/2005 [00:52<00:27, 24.41it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1960_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1961_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1964_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1346/2005 [00:53<00:26, 25.04it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1965_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1967_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1969_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1349/2005 [00:53<00:25, 26.06it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test196_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1971_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1972_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  67% 1352/2005 [00:53<00:24, 26.85it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1973_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1974_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1975_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1355/2005 [00:53<00:25, 25.96it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1976_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1977_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1979_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1358/2005 [00:53<00:24, 26.94it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test197_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1980_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1981_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1361/2005 [00:53<00:23, 27.48it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1985_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1986_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test198_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1364/2005 [00:53<00:24, 26.45it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1991_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1993_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1994_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1367/2005 [00:53<00:23, 27.25it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1996_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1997_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1998_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1370/2005 [00:53<00:23, 26.76it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1999_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test2001_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test2002_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  68% 1373/2005 [00:54<00:24, 25.90it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test2003_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test2004_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test200_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1376/2005 [00:54<00:23, 26.27it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test201_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test202_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test203_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1379/2005 [00:54<00:22, 27.23it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test205_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test206_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test207_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1382/2005 [00:54<00:23, 26.26it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test208_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test20_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test211_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1385/2005 [00:54<00:23, 26.91it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test212_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test213_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test216_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1388/2005 [00:54<00:24, 25.67it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test217_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test219_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test21_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  69% 1391/2005 [00:54<00:24, 24.93it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test220_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test223_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test224_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1394/2005 [00:54<00:23, 25.48it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test225_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test226_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test227_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1397/2005 [00:54<00:22, 26.52it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test228_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test229_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test22_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1400/2005 [00:55<00:23, 25.39it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test230_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test231_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test232_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1403/2005 [00:55<00:24, 24.57it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test233_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test236_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test238_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1406/2005 [00:55<00:23, 25.24it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test239_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test23_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test240_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1409/2005 [00:55<00:23, 25.43it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test241_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test243_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test245_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  70% 1412/2005 [00:55<00:23, 25.49it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test246_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test247_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test24_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1415/2005 [00:55<00:22, 26.33it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test250_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test252_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test253_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1418/2005 [00:55<00:21, 26.79it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test254_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test256_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test257_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1421/2005 [00:55<00:21, 26.70it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test258_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test25_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test260_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1424/2005 [00:56<00:21, 27.11it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test264_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test265_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test267_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1427/2005 [00:56<00:20, 27.74it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test268_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test26_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test270_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1430/2005 [00:56<00:21, 27.32it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test271_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test272_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test274_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  71% 1433/2005 [00:56<00:21, 26.00it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test275_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test277_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test278_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1436/2005 [00:56<00:21, 26.30it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test279_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test27_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test280_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1439/2005 [00:56<00:21, 26.76it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test281_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test282_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test283_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1442/2005 [00:56<00:21, 26.72it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test284_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test287_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test289_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1445/2005 [00:56<00:20, 26.71it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test28_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test291_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test292_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1448/2005 [00:56<00:21, 25.94it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test295_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test298_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test299_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  72% 1451/2005 [00:57<00:21, 26.29it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test301_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test303_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test305_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1454/2005 [00:57<00:21, 25.32it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test306_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test307_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test308_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1457/2005 [00:57<00:21, 26.02it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test309_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test30_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test311_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1460/2005 [00:57<00:20, 26.25it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test313_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test314_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test317_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1463/2005 [00:57<00:21, 25.76it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test318_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test319_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test31_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1466/2005 [00:57<00:20, 26.26it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test320_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test322_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test324_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1469/2005 [00:57<00:20, 25.94it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test326_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test327_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test330_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  73% 1472/2005 [00:57<00:20, 26.08it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test331_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test332_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test334_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1475/2005 [00:57<00:19, 26.78it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test336_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test337_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test338_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1478/2005 [00:58<00:19, 26.81it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test339_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test33_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test342_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1481/2005 [00:58<00:21, 24.71it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test343_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test347_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test348_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1484/2005 [00:58<00:20, 25.49it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test350_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test353_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test354_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1487/2005 [00:58<00:20, 25.09it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test355_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test357_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test358_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1490/2005 [00:58<00:19, 26.24it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test359_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test361_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test363_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  74% 1493/2005 [00:58<00:19, 25.69it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test364_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test365_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test366_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1496/2005 [00:58<00:19, 26.03it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test367_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test373_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test374_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1499/2005 [00:58<00:19, 26.63it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test375_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test377_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test378_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1502/2005 [00:59<00:20, 24.53it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test379_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test37_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test380_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1505/2005 [00:59<00:20, 23.86it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test382_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test383_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test384_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1508/2005 [00:59<00:20, 24.77it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test385_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test386_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test387_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  75% 1511/2005 [00:59<00:19, 25.77it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test391_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test392_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test393_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1514/2005 [00:59<00:19, 24.81it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test394_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test395_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test396_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1517/2005 [00:59<00:18, 25.72it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test397_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test398_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test400_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1520/2005 [00:59<00:18, 25.77it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test401_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test403_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test404_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1523/2005 [00:59<00:18, 25.45it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test406_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test409_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test40_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1526/2005 [00:59<00:18, 25.42it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test410_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test412_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test413_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1529/2005 [01:00<00:18, 26.04it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test414_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test415_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test417_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  76% 1532/2005 [01:00<00:17, 26.32it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test419_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test41_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test420_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1535/2005 [01:00<00:17, 26.24it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test421_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test424_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test425_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1538/2005 [01:00<00:17, 26.58it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test426_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test427_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test429_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1541/2005 [01:00<00:18, 24.72it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test42_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test431_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test432_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1544/2005 [01:00<00:18, 25.21it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test433_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test434_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test437_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1547/2005 [01:00<00:18, 25.07it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test438_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test43_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test440_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1550/2005 [01:00<00:17, 25.84it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test441_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test442_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test444_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  77% 1553/2005 [01:01<00:17, 26.23it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test445_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test446_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test447_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1556/2005 [01:01<00:17, 25.02it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test448_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test44_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test450_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1559/2005 [01:01<00:17, 25.53it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test454_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test455_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test456_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1562/2005 [01:01<00:17, 25.68it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test458_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test459_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test460_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1565/2005 [01:01<00:17, 24.86it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test462_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test463_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test465_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1568/2005 [01:01<00:17, 25.07it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test466_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test467_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test468_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  78% 1571/2005 [01:01<00:16, 26.02it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test469_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test46_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test471_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1574/2005 [01:01<00:16, 25.72it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test472_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test474_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test475_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1577/2005 [01:01<00:16, 26.37it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test477_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test478_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test479_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1580/2005 [01:02<00:16, 26.15it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test47_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test481_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test482_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1583/2005 [01:02<00:16, 25.26it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test483_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test484_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test485_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1586/2005 [01:02<00:16, 26.17it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test486_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test488_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test48_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1589/2005 [01:02<00:15, 26.19it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test490_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test491_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test492_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  79% 1592/2005 [01:02<00:15, 26.24it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test494_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test496_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test497_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1595/2005 [01:02<00:15, 27.07it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test498_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test499_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test49_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1598/2005 [01:02<00:15, 26.28it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test4_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test500_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test501_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1601/2005 [01:02<00:15, 25.42it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test502_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test503_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test504_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1604/2005 [01:03<00:16, 25.01it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test505_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test506_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test507_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1607/2005 [01:03<00:16, 24.80it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test508_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test50_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test510_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  80% 1610/2005 [01:03<00:15, 25.45it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test511_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test513_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ...
#
#
#  95% 1901/2005 [01:14<00:03, 26.78it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test89_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test8_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test900_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  95% 1904/2005 [01:14<00:04, 24.62it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test903_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test909_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test90_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  95% 1907/2005 [01:14<00:03, 25.48it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test910_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test912_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test913_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  95% 1910/2005 [01:15<00:03, 25.96it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test915_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test916_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test918_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  95% 1913/2005 [01:15<00:03, 26.56it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test919_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test91_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test920_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1916/2005 [01:15<00:03, 26.85it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test922_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test923_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test924_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1919/2005 [01:15<00:03, 26.90it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test926_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test927_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test928_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1922/2005 [01:15<00:03, 26.97it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test931_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test932_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test934_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1925/2005 [01:15<00:02, 26.85it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test935_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test937_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test938_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1928/2005 [01:15<00:02, 27.04it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test939_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test93_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test940_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1931/2005 [01:15<00:02, 27.05it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test941_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test942_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test945_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  96% 1934/2005 [01:15<00:02, 26.09it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test946_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test947_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test94_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1937/2005 [01:16<00:02, 26.70it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test950_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test951_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test952_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1940/2005 [01:16<00:02, 26.04it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test955_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test956_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test95_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1943/2005 [01:16<00:02, 26.55it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test960_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test961_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test962_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1946/2005 [01:16<00:02, 26.93it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test963_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test964_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test965_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1949/2005 [01:16<00:02, 26.46it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test966_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test970_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test975_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  97% 1952/2005 [01:16<00:02, 26.50it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test976_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test977_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test979_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1955/2005 [01:16<00:02, 24.40it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test97_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test980_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test981_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1958/2005 [01:16<00:01, 25.31it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test982_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test983_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test985_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1961/2005 [01:17<00:01, 24.16it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test987_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test988_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test989_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1964/2005 [01:17<00:01, 24.88it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test98_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test990_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test991_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1967/2005 [01:17<00:01, 25.94it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test992_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test993_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test994_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1970/2005 [01:17<00:01, 24.91it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test995_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test996_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test997_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  98% 1973/2005 [01:17<00:01, 24.86it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test998_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test999_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test99_5.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1976/2005 [01:17<00:01, 22.87it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1021_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1069_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1089_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1979/2005 [01:17<00:01, 22.95it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1162_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1324_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1327_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1982/2005 [01:17<00:01, 21.31it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1376_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1532_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1539_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1985/2005 [01:18<00:00, 22.06it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1636_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1718_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1743_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1988/2005 [01:18<00:00, 22.41it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1746_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test175_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1784_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1991/2005 [01:18<00:00, 23.25it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1962_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test1984_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test218_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#  99% 1994/2005 [01:18<00:00, 23.80it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test286_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test346_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test368_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
# 100% 1997/2005 [01:18<00:00, 24.72it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test381_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test449_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test470_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
# 100% 2000/2005 [01:18<00:00, 25.05it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test631_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test707_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test757_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
# 100% 2003/2005 [01:18<00:00, 25.34it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test797_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
#
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['test806_6.png']
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#
# 100% 2005/2005 [01:18<00:00, 25.42it/s]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 9.627382203152305
# Epoch number: 95
# Train time (s): 914.601309299469
# Train loss: 0.6583276987075806
# Train Foreground accuracy: 0.7468607425689697
# Validation loss: 0.7278345823287964
# Validation Foreground accuracy: 0.7347956299781799
# FINISHED JOB my_2d_classification_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **accuracy** metric is is a metric that generally describes how the model performs across all classes comparing the target class and your prediction output. **Therefore, the closer to 1, the better the performance.**

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and accuracy vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_accuracy.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Accuracy vs epoch number', fontdict = {'fontsize':22})

# %%
#@markdown ###Play to display the path to the output CSV file 

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

class_results = os.path.join(final_results, "predictions.csv")

print("Output paths:")
print("    Predicted test classes are in {}".format(class_results))
# Out:
# Output paths:
#     Predicted test classes are in /content/output/my_2d_classification/results/my_2d_classification_1/predictions.csv

# %% [markdown]
# ## **Download classification results**

# %%
#@markdown ###Play to download the CSV file with all classification results in test.

from google.colab import files

files.download(class_results)

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))

# %% [markdown]
# ## **Acknowledgments**
# We would like to acknowledge the inspiration provided by the excellent [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki). In particular, we have reused some of their descriptions of metrics and parameters.
