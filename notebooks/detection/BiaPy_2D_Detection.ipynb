# %% [markdown]
# # **2D Detection pipeline**
# ___
#
# In this notebook we show how to apply a [BiaPy](https://biapy.readthedocs.io/en/latest/) pipeline for **2D detection** of microscopy data.
#
# <figure>
# <center>
# <img src='https://github.com/danifranco/BiaPy-doc/blob/master/source/img/detection_2d_overview.svg?raw=true' width='400px'/>
# <figcaption><b>Figure 1</b>: Example of a 2D detection problem. From left to right: 2D brainbow image and its corresponding CSV file with the coordinates of the center of each cell. </figcaption></center>
# </figure>
#
# **Without any coding**, we explain step by step how to
# 1. **upload a set of training and test images** with their coordinates of the center of each cell,
# 2. **train a deep neural network (DNN)** model on the training set,
# 3. **apply the model** to the test images, and
# 4. **download the detection results** to your local machine.
#
# **Disclaimer:** the structure of the notebook is heavily inspired in the fantastic [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).
#
# **Contact:** This notebook has been made by [Ignacio Arganda-Carreras](mailto:ignacio.arganda@ehu.eus) and [Daniel Franco-Barranco](mailto:daniel.franco@dipc.org). If you have any suggestion or comment, or find any problem, please write us an email or [create an issue in BiaPy's repository](https://github.com/danifranco/BiaPy/issues). Thanks!

# %% [markdown]
# ## **Expected inputs and outputs**
# ___
# **Inputs**
#
# This notebook expects five folders as input:
# * **Training raw images**: with the raw 2D images to train the model.
# * **Training csv files**: with the coordinates of the center of each cell to train the model. Their number and sizes must match those of the training raw images.
# * **Test raw images**: with the raw 2D images to test the model.
# * **Test csv files**: with the coordinates of the center of each cell to test the model. Their number and sizes must match those of the validation raw images.
# * **Output folder**: a path to store the segmentation results.
#
# **Outputs**
#
# If the execution is successful, a folder will be created containing one result **CSV file** and a **TIFF image** for each test image. The CSV files contain the coordinates of the center of each cell and the result images contain those central points as predicted by our pipeline.
#
# <font color='red'><b>Note</b></font>: for testing purposes, you can also run this notebook with the **example datasets provided in 'Manage file(s) source > Option 3'**.

# %% [markdown]
# ## **Prepare the environment**
# ___
#
# Establish connection with Google services. You **must be logged in to Google** to continue.
# Since this is not Google's own code, you will probably see a message warning you of the dangers of running unfamiliar code. This is completely normal.

# %% [markdown]
# ## **Manage file(s) source**
# ---
# The input folder can be provided using three different options: by directly uploading the folder (option 1), by using a folder stored in Google Drive (option 2) or by using a few samples of our data (option 3).
#
# Depending on the option chosen, different steps will have to be taken, as explained in the following cells.

# %% [markdown]
# ### **Option 1: use your local files and upload them to the notebook**
# ---
# You will be prompted to upload your files to Colab and they will be stored under `/content/input/`.

# %%
#@markdown ##Play the cell to upload local files (train raw images)
from google.colab import files
# !mkdir -p /content/input/train/x
# %cd /content/input/train/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload csv files (instance coordinates)

from google.colab import files
# !mkdir -p /content/input/train/y 
# %cd /content/input/train/y
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload local files (test raw images)

from google.colab import files
# !mkdir -p /content/input/val/x
# %cd /content/input/val/x
uploaded = files.upload()
# %cd /content

# %%
#@markdown ##Play the cell to upload csv files (instance coordinates)

from google.colab import files
# !mkdir -p /content/input/val/y
# %cd /content/input/val/y
uploaded = files.upload()
# %cd /content

# %% [markdown]
# ### **Option 2: mount your Google Drive**
# ---
# To use this notebook on your own data from Google Drive, you need to mount Google Drive first.
#
# Play the cell below to mount your Google Drive and follow the link that will be shown. In the new browser window, select your drive and select 'Allow', copy the code, paste into the cell and press enter. This will give Colab access to the data on the drive.
#
# Once this is done, your data are available in the **Files** tab on the top left of notebook.

# %%
#@markdown ##Play the cell to connect your Google Drive to Colab

#@markdown * Click on the URL. 

#@markdown * Sign in your Google Account. 

#@markdown * Copy the authorization code. 

#@markdown * Enter the authorization code. 

#@markdown * Click on "Files" site on the right. Refresh the site. Your Google Drive folder should now be available here as "drive". 

# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### **Option 3: download an example dataset**
# ---
# If you do not have data at hand but would like to test the notebook, no worries! You can run the following cell to download an example dataset.
#
# In particular, we will use the [ZeroCostDL4Mic - Stardist example training and test dataset](https://zenodo.org/record/3715492#.Y4m7FjPMJH6) publicly available online. This dataset is for instance segmentation but we create the CSV file of each instance center so we can use it in this workflow.

# %%
#@markdown ##Play to download an example dataset

import os

os.chdir('/content/')
# !curl -L -s -o Stardist_v2_detection.zip 'https://drive.google.com/uc?id=1pWqQhcWY15b5fVLZDkPS-vnE-RU6NlYf&confirm=t'
# !unzip -q Stardist_v2_detection.zip
# !rm Stardist_v2_detection.zip

print( 'Dataset downloaded and unzipped under /content/data')
# Out:
# Dataset downloaded and unzipped under /content/data

# %% [markdown]
# ## **Check for GPU access**
# ---
#
# By default, the session should be using Python 3 and GPU acceleration, but it is possible to ensure that these are set properly by doing the following:
#
# Go to **Runtime -> Change the Runtime type**
#
# **Runtime type: Python 3** *(Python 3 is programming language in which this program is written)*
#
# **Accelerator: GPU** *(Graphics processing unit)*

# %% [markdown]
# ## **Paths to load input images and save output files**
# ___
#
# If option 1 (uploading the folder) or option 3 (downloading our prepared data samples) were chosen, define train_data_path as '/content/data/train/x', train_data_mask_path as '/content/data/train/y', test_data_path as '/content/data/test/x', test_data_mask_path as '/content/data/test/y', and output_path as '/content/out'. Please make sure you download the results from the '/content/out' folder later!
#
# If option 2 is chosen, introduce here the paths to your input files and to the folder where you want to store the results. E.g. '/content/gdrive/MyDrive/...'.
#
# In case you have troubles finding the path to your folders, at the top left of this notebook you will find a small folder icon. Explore until you find the folders. There you can copy the folder path by right clicking and clicking "copy".

# %%
#@markdown #####Path to train images
train_data_path = '/content/data/train/x' #@param {type:"string"}
#@markdown #####Path to train CSV files
train_csv_path = '/content/data/train/y' #@param {type:"string"}
#@markdown #####Path to test images
test_data_path = '/content/data/test/x' #@param {type:"string"}
#@markdown #####Path to test CSV files
test_csv_path = '/content/data/test/y' #@param {type:"string"}
#@markdown #####Path to store the resulting images (it'll be created if not existing):
output_path = '/content/output' #@param {type:"string"}

# %% [markdown]
# ## **Install BiaPy library**

# %%
#@markdown ##Play to install BiaPy and its dependences

import os
import sys
import numpy as np
from tqdm.notebook import tqdm
from skimage.io import imread
from skimage.exposure import match_histograms                                                                           

# Clone the repo
os.chdir('/content/')
if not os.path.exists('BiaPy'):
    # !git clone https://github.com/danifranco/BiaPy.git
    # !git checkout 81072f1c0734412be3daf1312bf1c6bb139b6b66 &> /dev/null
    # !pip install --upgrade --no-cache-dir gdown &> /dev/null
    sys.path.insert(0, 'BiaPy')
    os.chdir('/content/BiaPy')
    
    # Install dependencies 
    # !pip install git+https://github.com/aleju/imgaug.git &> /dev/null
    # !pip install numpy_indexed yacs fill_voids &> /dev/null
else:
    print( 'Using existing installed version of BiaPy' )
# Out:
# Cloning into 'BiaPy'...
# remote: Enumerating objects: 15822, done.
# remote: Counting objects: 100% (1891/1891), done.
# remote: Compressing objects: 100% (612/612), done.
# remote: Total 15822 (delta 1332), reused 1814 (delta 1260), pack-reused 13931
# Receiving objects: 100% (15822/15822), 823.25 MiB | 22.73 MiB/s, done.
# Resolving deltas: 100% (8601/8601), done.

# %% [markdown]
# ### **Select your parameters**
# ---
# #### **Name of the model**
# * **`model_name`:** Use only my_model -style, not my-model (Use "_" not "-"). Do not use spaces in the name. Avoid using the name of an existing model (saved in the same folder) as it will be overwritten.
#
# #### **Basic training parameters**
# * **`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. For the example dataset, preliminary results can already be observed after 50 epochs, but better results are obtained when running the model longer. **Default value: 100**
#
# * **`percentage_validation`:**  Input the percentage of your training dataset you want to use to validate the network during the training. **Default value: 10**
#
# * **`patience`:**  Input how many epochs you want to wait without the model improving its results in the validation set to stop training. **Default value: 20**
#
# #### **Advanced Parameters - experienced users only**
# * **`model_architecture`:**  Select the architecture of the DNN used as backbone of the pipeline. Options: U-Net, Residual U-Net, Attention U-Net, SEUNet (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1)) (see [Franco-Barranco et al., 2021](https://link.springer.com/article/10.1007/s12021-021-09556-1))  **Default value: Residual U-Net**
#
# * **`batch_size:`** This parameter defines the number of patches seen in each training step. Reducing or increasing the **batch size** may slow or speed up your training, respectively, and can influence network performance. **Default value: 8**
#
# * **`patch_size`:** Input the size of the patches use to train your model (length in pixels in X and Y). The value should be smaller or equal to the dimensions of the image. **Default value: 256**
#
# * **`input_channels`:** Input the number of channels of your images (grayscale = 1, RGB = 3). **Default value: 1**
#
# * **`optimizer`:** Select the optimizer used to train your model. Options: ADAM, Stocastic Gradient Descent (SGD). ADAM converges usually faster but SGD is known for better generalization. **Default value: ADAM**
#
# * **`initial_learning_rate`:** Input the initial value to be used as learning rate. If you select ADAM as optimizer, this value should be around 10e-4. **Default value: 0.0001**
#
# * **`test_time_augmentation`:** Select to apply augmentation (flips and rotations) at test time. It usually provides more robust results but uses more time to produce each result. **Default value: False**
#
# * **`min_value_to_be_peak`:** Minimun value to consider a point as a peak. This value needs to between 0 and 1. **Default value: 0.1**
#
# * **`resolution`:** Data resolution. **Default value: 1**
#
# * **`tolerance`:** Maximum distance far away from a GT point to consider a point as a true positive. **Default value: 10**
#
# * **`remove_close_points`:** Distance between points to be considered the same so only one will be kept. **Default value: True**
#
# * **`remove_close_points_radius`:** Maximum distance far away from a GT point to consider a point as a true positive. **Default value: 15**
#
# * **`central_point_dilation`:** Size of the disk that will be used to dilate the central point created from the CSV file to train the network. Set it to 0 to not dilate and only create a 3x3 square. Normally it is set to 3 but here we set it to 0 because the nuclei of this dataset are very small. **Default value: 0**

# %%
#@markdown ###Name of the model:
model_name = "my_2d_detection" #@param {type:"string"}

#@markdown ### Basic training parameters:
number_of_epochs =  100#@param {type:"number"}
percentage_validation =  10 #@param {type:"number"}
patience =  20#@param {type:"number"}

#@markdown ### Advanced training parameters:

model_architecture = "Residual U-Net" #@param ["U-Net", "Residual U-Net", "Attention U-Net", 'SEUNet']

batch_size =  8#@param {type:"number"}
patch_size = 256 #@param {type:"number"}
resolution = 1 #@param {type:"number"}

input_channels = 1 #@param {type:"number"}
optimizer = "ADAM" #@param ["ADAM", "SGD"]
initial_learning_rate = 0.0001 #@param {type:"number"}

test_time_augmentation = False #@param {type:"boolean"}

min_value_to_be_peak = 0.5 #@param {type:"number"}
tolerance = 10 #@param {type:"number"}
remove_close_points = True #@param {type:"boolean"}
remove_close_points_radius= 3 #@param {type:"number"}
central_point_dilation = 3 #@param {type:"number"}

# %%
#@markdown ##Play to download the YAML configuration file and update it to train the model
import errno

os.chdir('/content/') 

job_name = model_name
yaml_file = "/content/"+str(job_name)+".yaml"

# remove previous configuration file if it exists with the same name
if os.path.exists( yaml_file ):
    os.remove( yaml_file )

# remove template file it is exists
template_file = '2d_detection.yaml'
if os.path.exists( template_file ):
    os.remove( template_file )

# Download template file 
# !wget https://raw.githubusercontent.com/danifranco/BiaPy/master/templates/detection/2d_detection.yaml &> /dev/null

# Check folders before modifying the .yaml file
if not os.path.exists(train_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_data_path)
ids = sorted(next(os.walk(train_data_path))[2])
if len(ids) == 0:
    raise ValueError("No csv files in dir {}".format(train_data_path))
if not os.path.exists(train_csv_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), train_csv_path)
ids = sorted(next(os.walk(train_csv_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(train_csv_path))

# Check folders before modifying the .yaml file
if not os.path.exists(test_data_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_data_path)
ids = sorted(next(os.walk(test_data_path))[2])
if len(ids) == 0:
    raise ValueError("No images found in dir {}".format(test_data_path))
if not os.path.exists(test_csv_path):
    raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), test_csv_path)
ids = sorted(next(os.walk(test_csv_path))[2])
if len(ids) == 0:
    raise ValueError("No csv files in dir {}".format(test_csv_path))


# open template configuration file
import yaml
with open( template_file, 'r') as stream:
    try:
        biapy_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

biapy_config['SYSTEM']['NUM_CPUS'] = -1
biapy_config['PROBLEM']['DETECTION'] = {}
biapy_config['PROBLEM']['DETECTION']['CENTRAL_POINT_DILATION'] = central_point_dilation

# update paths to data
biapy_config['DATA']['TRAIN']['PATH'] = train_data_path
biapy_config['DATA']['TRAIN']['MASK_PATH'] = train_csv_path
biapy_config['DATA']['TEST']['PATH'] = test_data_path
biapy_config['DATA']['TEST']['MASK_PATH'] = test_csv_path

# make sure ground truth labels are loaded
biapy_config['DATA']['TEST']['LOAD_GT'] = True

# update data patch size
biapy_config['DATA']['PATCH_SIZE'] = '('+str(patch_size)+', '+ str(patch_size)+', '+str(input_channels)+')'
# adjust test padding accordingly
padding = patch_size // 8
biapy_config['DATA']['TEST']['PADDING'] = '('+ str(padding)+', '+ str(padding)+')'
biapy_config['DATA']['TEST']['RESOLUTION'] = '('+str(resolution)+', ' + str(resolution)+')'

# update training parameters
biapy_config['DATA']['VAL']['FROM_TRAIN'] = True
biapy_config['DATA']['VAL']['SPLIT_TRAIN'] = percentage_validation/100.0
biapy_config['TRAIN']['EPOCHS'] = number_of_epochs
biapy_config['TRAIN']['PATIENCE'] = patience
biapy_config['TRAIN']['BATCH_SIZE'] = batch_size
biapy_config['TRAIN']['OPTIMIZER'] = optimizer
biapy_config['TRAIN']['LR'] = initial_learning_rate

# Transcribe model architecture
# Available models: "U-Net", "Residual U-Net", "Attention U-Net", 'SEUNet'
architecture = 'unet'
if model_architecture == "U-Net":
    architecture = 'unet'
elif model_architecture == "Residual U-Net":
    architecture = 'resunet'
elif model_architecture == "Attention U-Net":
    architecture = 'attention_unet'
elif model_architecture == "SEUNet":
    architecture = 'seunet'
biapy_config['MODEL']['ARCHITECTURE'] = architecture

# update test parameters
biapy_config['TEST']['AUGMENTATION'] = test_time_augmentation

# Detection parameters
biapy_config['TEST']['DET_MIN_TH_TO_BE_PEAK'] = [min_value_to_be_peak]
biapy_config['TEST']['DET_TOLERANCE'] = [tolerance]
biapy_config['TEST']['POST_PROCESSING']['REMOVE_CLOSE_POINTS'] = remove_close_points
biapy_config['TEST']['POST_PROCESSING']['REMOVE_CLOSE_POINTS_RADIUS'] = [remove_close_points_radius]

# save file
with open( yaml_file, 'w') as outfile:
    yaml.dump(biapy_config, outfile, default_flow_style=False)

print( "Training configuration finished.")
# Out:
# Training configuration finished.

# %% [markdown]
# ### **Train the model**
# ---

# %%
#@markdown ##Play to train the model

import os
import errno

# Run the code 
os.chdir('/content/BiaPy')
# !python -u main.py --config '/content/'{job_name}'.yaml' --result_dir {output_path} --name {job_name} --run_id 1 --gpu 0
# Out:
# Date: 2023-02-05 11:40:57
# Arguments: Namespace(config='/content/my_2d_detection.yaml', gpu='0', name='my_2d_detection', result_dir='/content/output', run_id=1)
# Job: my_2d_detection_1
# Python       : 3.8.10 (default, Nov 14 2022, 12:59:47)
# Keras        : 2.9.0
# Tensorflow   : 2.9.2
# Num GPUs Available:  1
# Configuration details:
# AUGMENTOR:
#   AFFINE_MODE: constant
#   AUG_NUM_SAMPLES: 10
#   AUG_SAMPLES: True
#   BRIGHTNESS: False
#   BRIGHTNESS_EM: False
#   BRIGHTNESS_EM_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_EM_MODE: 3D
#   BRIGHTNESS_FACTOR: (-0.1, 0.1)
#   BRIGHTNESS_MODE: 3D
#   CBLUR_DOWN_RANGE: (2, 8)
#   CBLUR_INSIDE: True
#   CBLUR_SIZE: (0.2, 0.4)
#   CHANNEL_SHUFFLE: False
#   CMIX_SIZE: (0.2, 0.4)
#   CNOISE_NB_ITERATIONS: (1, 3)
#   CNOISE_SCALE: (0.05, 0.1)
#   CNOISE_SIZE: (0.2, 0.4)
#   CONTRAST: False
#   CONTRAST_EM: False
#   CONTRAST_EM_FACTOR: (-0.1, 0.1)
#   CONTRAST_EM_MODE: 3D
#   CONTRAST_FACTOR: (-0.1, 0.1)
#   CONTRAST_MODE: 3D
#   COUT_APPLY_TO_MASK: False
#   COUT_CVAL: 0
#   COUT_NB_ITERATIONS: (1, 3)
#   COUT_SIZE: (0.05, 0.3)
#   CUTBLUR: False
#   CUTMIX: False
#   CUTNOISE: False
#   CUTOUT: False
#   DA_PROB: 0.5
#   DRAW_GRID: True
#   DROPOUT: False
#   DROP_RANGE: (0, 0.2)
#   ELASTIC: False
#   ENABLE: True
#   E_ALPHA: (12, 16)
#   E_MODE: constant
#   E_SIGMA: 4
#   GAMMA_CONTRAST: False
#   GC_GAMMA: (1.25, 1.75)
#   GRAYSCALE: False
#   GRIDMASK: False
#   GRID_D_RANGE: (0.4, 1)
#   GRID_INVERT: False
#   GRID_RATIO: 0.6
#   GRID_ROTATE: 1
#   G_BLUR: False
#   G_SIGMA: (1.0, 2.0)
#   HFLIP: True
#   MB_KERNEL: (3, 7)
#   MEDIAN_BLUR: False
#   MISALIGNMENT: False
#   MISSING_SECTIONS: False
#   MISSP_ITERATIONS: (10, 30)
#   MOTB_K_RANGE: (8, 12)
#   MOTION_BLUR: False
#   MS_DISPLACEMENT: 16
#   MS_ROTATE_RATIO: 0.5
#   RANDOM_ROT: False
#   RANDOM_ROT_RANGE: (-180, 180)
#   ROT90: False
#   SHEAR: False
#   SHEAR_RANGE: (-20, 20)
#   SHIFT: False
#   SHIFT_RANGE: (0.1, 0.2)
#   SHUFFLE_TRAIN_DATA_EACH_EPOCH: True
#   SHUFFLE_VAL_DATA_EACH_EPOCH: False
#   VFLIP: True
#   ZFLIP: True
#   ZOOM: False
#   ZOOM_RANGE: (0.8, 1.2)
# DATA:
#   CHECK_GENERATORS: False
#   EXTRACT_RANDOM_PATCH: False
#   NORMALIZATION:
#     CUSTOM_MEAN: -1.0
#     CUSTOM_STD: -1.0
#     TYPE: div
#   PATCH_SIZE: (256, 256, 1)
#   PROBABILITY_MAP: False
#   REFLECT_TO_COMPLETE_SHAPE: True
#   TEST:
#     ARGMAX_TO_OUTPUT: False
#     BINARY_MASKS: /content/data/test/x/../bin_mask
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/test/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/test/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/test/y_BC_thick
#     IN_MEMORY: False
#     LOAD_GT: True
#     MASK_PATH: /content/data/test/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0)
#     PADDING: (32, 32)
#     PATH: /content/data/test/x
#     RESOLUTION: (1, 1)
#     SSL_SOURCE_DIR: /content/data/test/x_ssl_source
#     USE_VAL_AS_TEST: False
#   TRAIN:
#     CHECK_DATA: True
#     DETECTION_MASK_DIR: /content/data/train/y_detection_masks
#     INSTANCE_CHANNELS_DIR: /content/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /content/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /content/data/train/y
#     MINIMUM_FOREGROUND_PER: -1.0
#     OVERLAP: (0, 0)
#     PADDING: (0, 0)
#     PATH: /content/data/train/x
#     REPLICATE: 0
#     RESOLUTION: (1, 1)
#     SSL_SOURCE_DIR: /content/data/train/x_ssl_source
#   VAL:
#     BINARY_MASKS: /data2/dfranco/datasets/demo3D/detection/data/train/x/../bin_mask
#     CROSS_VAL: False
#     CROSS_VAL_FOLD: 1
#     CROSS_VAL_NFOLD: 5
#     DETECTION_MASK_DIR: /data2/dfranco/datasets/demo3D/detection/data/train/y_detection_masks
#     FROM_TRAIN: True
#     INSTANCE_CHANNELS_DIR: /data2/dfranco/datasets/demo3D/detection/data/train/x_BC_thick
#     INSTANCE_CHANNELS_MASK_DIR: /data2/dfranco/datasets/demo3D/detection/data/train/y_BC_thick
#     IN_MEMORY: True
#     MASK_PATH: /data2/dfranco/datasets/demo3D/detection/data/train/y
#     MEDIAN_PADDING: False
#     OVERLAP: (0, 0)
#     PADDING: (0, 0)
#     PATH: /data2/dfranco/datasets/demo3D/detection/data/train/x
#     RANDOM: True
#     RESOLUTION: (1, 1)
#     SPLIT_TRAIN: 0.1
#     SSL_SOURCE_DIR: /data2/dfranco/datasets/demo3D/detection/data/train/x_ssl_source
#   W_BACKGROUND: 0.06
#   W_FOREGROUND: 0.94
# LOSS:
#   TYPE: CE
# MODEL:
#   ACTIVATION: elu
#   ARCHITECTURE: resunet
#   BATCH_NORMALIZATION: False
#   DROPOUT_VALUES: [0, 0, 0]
#   FEATURE_MAPS: [36, 48, 64]
#   KERNEL_INIT: he_normal
#   KERNEL_SIZE: 3
#   LAST_ACTIVATION: sigmoid
#   LOAD_CHECKPOINT: False
#   N_CLASSES: 1
#   SPATIAL_DROPOUT: False
#   TIRAMISU_DEPTH: 3
#   UNETR_DEPTH: 12
#   UNETR_EMBED_DIM: 768
#   UNETR_MLP_HIDDEN_UNITS: [3072, 768]
#   UNETR_NUM_HEADS: 4
#   UNETR_TOKEN_SIZE: 16
#   UNETR_VIT_HIDD_MULT: 3
#   UPSAMPLE_LAYER: convtranspose
#   Z_DOWN: 1
# PATHS:
#   CHARTS: /content/output/my_2d_detection/results/my_2d_detection_1/charts
#   CHECKPOINT: /content/output/my_2d_detection/checkpoints
#   CHECKPOINT_FILE: /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#   DA_SAMPLES: /content/output/my_2d_detection/results/my_2d_detection_1/aug
#   GEN_CHECKS: /content/output/my_2d_detection/results/my_2d_detection_1/gen_check
#   GEN_MASK_CHECKS: /content/output/my_2d_detection/results/my_2d_detection_1/gen_mask_check
#   MEAN_INFO_FILE: /content/output/my_2d_detection/checkpoints/normalization_mean_value.npy
#   PROB_MAP_DIR: /content/output/my_2d_detection/prob_map
#   PROB_MAP_FILENAME: prob_map.npy
#   RESULT_DIR:
#     AS_3D_STACK_POST_PROCESSING: /content/output/my_2d_detection/results/my_2d_detection_1/as_3d_stack_post_processing
#     DET_LOCAL_MAX_COORDS_CHECK: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check
#     FULL_IMAGE: /content/output/my_2d_detection/results/my_2d_detection_1/full_image
#     FULL_IMAGE_BIN: /content/output/my_2d_detection/results/my_2d_detection_1/full_image_binarized
#     PATH: /content/output/my_2d_detection/results/my_2d_detection_1
#     PER_IMAGE: /content/output/my_2d_detection/results/my_2d_detection_1/per_image
#     PER_IMAGE_BIN: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_binarized
#     PER_IMAGE_INSTANCES: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_instances
#     PER_IMAGE_POST_PROCESSING: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_post_processing
#   STD_INFO_FILE: /content/output/my_2d_detection/checkpoints/normalization_std_value.npy
#   TEST_FULL_GT_H5: /content/data/test/y/h5
#   TEST_INSTANCE_CHANNELS_CHECK: /content/output/my_2d_detection/results/my_2d_detection_1/test_BC_instance_channels
#   TRAIN_INSTANCE_CHANNELS_CHECK: /content/output/my_2d_detection/results/my_2d_detection_1/train_BC_instance_channels
#   VAL_INSTANCE_CHANNELS_CHECK: /content/output/my_2d_detection/results/my_2d_detection_1/val_BC_instance_channels
#   WATERSHED_DIR: /content/output/my_2d_detection/results/my_2d_detection_1/watershed
# PROBLEM:
#   DENOISING:
#     N2V_MANIPULATOR: uniform_withCP
#     N2V_NEIGHBORHOOD_RADIUS: 5
#     N2V_PERC_PIX: 0.198
#     N2V_STRUCTMASK: False
#   DETECTION:
#     CENTRAL_POINT_DILATION: 3
#     CHECK_POINTS_CREATED: True
#     DATA_CHECK_MW: True
#   INSTANCE_SEG:
#     DATA_CHANNELS: BC
#     DATA_CHANNEL_WEIGHTS: (1, 1)
#     DATA_CHECK_MW: True
#     DATA_CONTOUR_MODE: thick
#     DATA_MW_OPTIMIZE_THS: False
#     DATA_MW_TH1: 0.5
#     DATA_MW_TH2: 0.1
#     DATA_MW_TH3: 0.3
#     DATA_MW_TH4: 1.5
#     DATA_MW_TH5: 1.2
#     DATA_MW_TH_POINTS: 0.5
#     DATA_REMOVE_AFTER_MW: False
#     DATA_REMOVE_BEFORE_MW: True
#     DATA_REMOVE_SMALL_OBJ_AFTER: 100
#     DATA_REMOVE_SMALL_OBJ_BEFORE: 10
#     ERODE_AND_DILATE_FOREGROUND: False
#     FORE_DILATION_RADIUS: 5
#     FORE_EROSION_RADIUS: 5
#     SEED_MORPH_RADIUS: []
#     SEED_MORPH_SEQUENCE: []
#   NDIM: 2D
#   SELF_SUPERVISED:
#     NOISE: 0.2
#     RESIZING_FACTOR: 4
#   SUPER_RESOLUTION:
#     UPSCALING: 1
#   TYPE: DETECTION
# SYSTEM:
#   NUM_CPUS: -1
#   SEED: 0
# TEST:
#   ANALIZE_2D_IMGS_AS_3D_STACK: False
#   AUGMENTATION: False
#   DET_LOCAL_MAX_COORDS: True
#   DET_MIN_TH_TO_BE_PEAK: [0.5]
#   DET_TOLERANCE: [10]
#   ENABLE: True
#   EVALUATE: True
#   MATCHING_SEGCOMPARE: False
#   MATCHING_STATS: True
#   MATCHING_STATS_THS: [0.3, 0.5, 0.75]
#   POST_PROCESSING:
#     APPLY_MASK: False
#     DET_WATERSHED: False
#     DET_WATERSHED_DONUTS_CLASSES: [-1]
#     DET_WATERSHED_DONUTS_NUCLEUS_DIAMETER: 30
#     DET_WATERSHED_DONUTS_PATCH: [13, 120, 120]
#     DET_WATERSHED_FIRST_DILATION: [[-1, -1]]
#     REMOVE_CLOSE_POINTS: True
#     REMOVE_CLOSE_POINTS_RADIUS: [3]
#     REPARE_LARGE_BLOBS_SIZE: -1
#     VORONOI_ON_MASK: False
#     WATERSHED_CIRCULARITY: -1.0
#     YZ_FILTERING: False
#     YZ_FILTERING_SIZE: 5
#     Z_FILTERING: False
#     Z_FILTERING_SIZE: 5
#   REDUCE_MEMORY: False
#   STATS:
#     FULL_IMG: True
#     MERGE_PATCHES: True
#     PER_PATCH: True
#   VERBOSE: True
# TRAIN:
#   BATCH_SIZE: 8
#   CHECKPOINT_MONITOR: val_loss
#   EARLYSTOPPING_MONITOR: val_loss
#   ENABLE: True
#   EPOCHS: 100
#   LR: 0.0001
#   LR_SCHEDULER:
#     ENABLE: False
#     NAME:
#   OPTIMIZER: ADAM
#   PATIENCE: 20
# ####################
# #  PRE-PROCESSING  #
# ####################
#
# ############################
# #  PREPARE DETECTION DATA  #
# ############################
#
# You select to create detection masks from given .csv files but no file is detected in /content/data/train/y_detection_masks. So let's prepare the data. Notice that, if you do not modify 'DATA.TRAIN.DETECTION_MASK_DIR' path, this process will be done just once!
# Creating train detection masks . . .
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image1.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image14.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image14.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image17.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image17.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image21.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image21.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image29.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image29.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image34.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image34.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image37.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image37.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image44.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image44.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image48.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image48.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image51.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image51.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image55.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image55.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image59.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image59.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image64.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image64.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image67.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image67.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image68.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image68.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image7.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image7.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image75.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image75.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image79.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image79.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image82.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image82.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image86.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 0_XY1562686096_Z0_T00_C1-1-image86.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage12.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage12.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage47.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage47.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage63.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage63.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage74.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1-SubBackimage74.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1_SubBackimage86.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 1_XY1562686097_Z0_T00_C1_SubBackimage86.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 23_XY1562686119_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 23_XY1562686119_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 26_XY1562686122_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 26_XY1562686122_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image16.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image16.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image56.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image56.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image66.csv
# Its respective image seems to be: /content/data/train/x/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image66.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 27_XY1562944037_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 27_XY1562944037_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 34_XY1562944044_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 34_XY1562944044_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 36_XY1562944046_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 36_XY1562944046_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 47_XY1562944057_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 47_XY1562944057_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 52_XY1562944062_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 52_XY1562944062_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 53_XY1562944063_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 53_XY1562944063_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration - Position 72_XY1562944082_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration - Position 72_XY1562944082_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 14_XY1562769071_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 14_XY1562769071_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 25_XY1562769082_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 25_XY1562769082_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 40_XY1562769097_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 40_XY1562769097_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 42_XY1562769099_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 42_XY1562769099_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 43_XY1562769100_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 43_XY1562769100_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 47_XY1562769104_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 47_XY1562769104_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 53_XY1562769110_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 53_XY1562769110_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# Attempting to create mask from CSV file: /content/data/train/y/migration r2 - Position 61_XY1562769118_Z0_T00_C1-1.csv
# Its respective image seems to be: /content/data/train/x/migration r2 - Position 61_XY1562769118_Z0_T00_C1-1.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/train/y_detection_masks
# You select to create detection masks from given .csv files but no file is detected in /content/data/test/y_detection_masks. So let's prepare the data. Notice that, if you do not modify 'DATA.TEST.DETECTION_MASK_DIR' path, this process will be done just once!
# Creating test detection masks . . .
# Attempting to create mask from CSV file: /content/data/test/y/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image76.csv
# Its respective image seems to be: /content/data/test/x/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image76.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/test/y_detection_masks
# Attempting to create mask from CSV file: /content/data/test/y/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image86.csv
# Its respective image seems to be: /content/data/test/x/cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image86.tif
# Creating all points . . .
# Check points created to see if some of them are very close that create a large label
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/data/test/y_detection_masks
# DATA.TRAIN.MASK_PATH changed from /content/data/train/y to /content/data/train/y_detection_masks
# DATA.TEST.MASK_PATH changed from /content/data/test/y to /content/data/test/y_detection_masks
# #################
# #   LOAD DATA   #
# #################
#
# ### LOAD ###
# 0) Loading train images . . .
# Loading data from /content/data/train/x
# 100% 45/45 [00:00<00:00, 322.63it/s]
# *** Loaded data shape is (720, 256, 256, 1)
# 1) Loading train masks . . .
# Loading data from /content/data/train/y_detection_masks
# 100% 45/45 [00:00<00:00, 394.63it/s]
# *** Loaded data shape is (720, 256, 256, 1)
# *** Loaded train data shape is: (648, 256, 256, 1)
# *** Loaded train mask shape is: (648, 256, 256, 1)
# *** Loaded validation data shape is: (72, 256, 256, 1)
# *** Loaded validation mask shape is: (72, 256, 256, 1)
# ### END LOAD ###
# ########################
# #  PREPARE GENERATORS  #
# ########################
#
# Initializing train data generator . . .
# Training data X normalization - min: 0.0 , max: 1.0 , mean: 0.009449048899114132 , dtype: float32
# Training data Y normalization - min: 0 , max: 1 , mean: 0.01284406214584539 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Initializing val data generator . . .
# Validation data X normalization - min: 0.0 , max: 1.0 , mean: 0.011763510294258595 , dtype: float32
# Validation data Y normalization - min: 0 , max: 1 , mean: 0.014463212754991319 , dtype: uint8
# Normalization config used for X: {'type': 'div', 'reduced_uint16': 1}
# Normalization config used for Y: as_mask
# Creating generator samples . . .
# 0) Creating samples of data augmentation . . .
#   0% 0/10 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#  70% 7/10 [00:00<00:00, 60.52it/s]
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 10/10 [00:00<00:00, 62.64it/s]
# 2023-02-05 11:41:07.347278: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# #################
# #  BUILD MODEL  #
# #################
#
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                     Param #           Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                            [(None, None, None, 1)]          0                 []
#
#  conv2d_1 (Conv2D)                               (None, None, None, 36)           360               ['input_1[0][0]']
#
#  elu (ELU)                                       (None, None, None, 36)           0                 ['conv2d_1[0][0]']
#
#  conv2d (Conv2D)                                 (None, None, None, 36)           72                ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)                               (None, None, None, 36)           11700             ['elu[0][0]']
#
#  add (Add)                                       (None, None, None, 36)           0                 ['conv2d[0][0]',
#                                                                                                      'conv2d_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)                    (None, None, None, 36)           0                 ['add[0][0]']
#
#  elu_1 (ELU)                                     (None, None, None, 36)           0                 ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)                               (None, None, None, 48)           15600             ['elu_1[0][0]']
#
#  elu_2 (ELU)                                     (None, None, None, 48)           0                 ['conv2d_4[0][0]']
#
#  conv2d_3 (Conv2D)                               (None, None, None, 48)           1776              ['max_pooling2d[0][0]']
#
#  conv2d_5 (Conv2D)                               (None, None, None, 48)           20784             ['elu_2[0][0]']
#
#  add_1 (Add)                                     (None, None, None, 48)           0                 ['conv2d_3[0][0]',
#                                                                                                      'conv2d_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)                  (None, None, None, 48)           0                 ['add_1[0][0]']
#
#  elu_3 (ELU)                                     (None, None, None, 48)           0                 ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)                               (None, None, None, 64)           27712             ['elu_3[0][0]']
#
#  elu_4 (ELU)                                     (None, None, None, 64)           0                 ['conv2d_7[0][0]']
#
#  conv2d_6 (Conv2D)                               (None, None, None, 64)           3136              ['max_pooling2d_1[0][0]']
#
#  conv2d_8 (Conv2D)                               (None, None, None, 64)           36928             ['elu_4[0][0]']
#
#  add_2 (Add)                                     (None, None, None, 64)           0                 ['conv2d_6[0][0]',
#                                                                                                      'conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTranspose)              (None, None, None, 48)           12336             ['add_2[0][0]']
#
#  concatenate (Concatenate)                       (None, None, None, 96)           0                 ['add_1[0][0]',
#                                                                                                      'conv2d_transpose[0][0]']
#
#  elu_5 (ELU)                                     (None, None, None, 96)           0                 ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)                              (None, None, None, 48)           41520             ['elu_5[0][0]']
#
#  elu_6 (ELU)                                     (None, None, None, 48)           0                 ['conv2d_10[0][0]']
#
#  conv2d_9 (Conv2D)                               (None, None, None, 48)           4656              ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)                              (None, None, None, 48)           20784             ['elu_6[0][0]']
#
#  add_3 (Add)                                     (None, None, None, 48)           0                 ['conv2d_9[0][0]',
#                                                                                                      'conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTranspose)            (None, None, None, 36)           6948              ['add_3[0][0]']
#
#  concatenate_1 (Concatenate)                     (None, None, None, 72)           0                 ['add[0][0]',
#                                                                                                      'conv2d_transpose_1[0][0]']
#
#  elu_7 (ELU)                                     (None, None, None, 72)           0                 ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)                              (None, None, None, 36)           23364             ['elu_7[0][0]']
#
#  elu_8 (ELU)                                     (None, None, None, 36)           0                 ['conv2d_13[0][0]']
#
#  conv2d_12 (Conv2D)                              (None, None, None, 36)           2628              ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)                              (None, None, None, 36)           11700             ['elu_8[0][0]']
#
#  add_4 (Add)                                     (None, None, None, 36)           0                 ['conv2d_12[0][0]',
#                                                                                                      'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)                              (None, None, None, 1)            37                ['add_4[0][0]']
#
# ======================================================================================================================================================
# Total params: 242,041
# Trainable params: 242,041
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# #####################
# #  TRAIN THE MODEL  #
# #####################
#
# Epoch 1/100
# 81/81 [==============================] - ETA: 0s - loss: 0.1857 - jaccard_index: 0.0021
#
# ...
# Epoch 77/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0194 - jaccard_index: 0.5362
#
# Epoch 00077: val_loss improved from 0.02107 to 0.02105, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 184ms/step - loss: 0.0194 - jaccard_index: 0.5362 - val_loss: 0.0210 - val_jaccard_index: 0.5440
# Epoch 78/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0192 - jaccard_index: 0.5389
#
# Epoch 00078: val_loss did not improve from 0.02105
#
#
# 81/81 [==============================] - 15s 180ms/step - loss: 0.0192 - jaccard_index: 0.5389 - val_loss: 0.0213 - val_jaccard_index: 0.5407
# Epoch 79/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0193 - jaccard_index: 0.5387
#
# Epoch 00079: val_loss did not improve from 0.02105
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0193 - jaccard_index: 0.5387 - val_loss: 0.0212 - val_jaccard_index: 0.5426
# Epoch 80/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0192 - jaccard_index: 0.5404
#
# Epoch 00080: val_loss improved from 0.02105 to 0.02075, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 184ms/step - loss: 0.0192 - jaccard_index: 0.5404 - val_loss: 0.0208 - val_jaccard_index: 0.5518
# Epoch 81/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0191 - jaccard_index: 0.5437
#
# Epoch 00081: val_loss did not improve from 0.02075
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0191 - jaccard_index: 0.5437 - val_loss: 0.0208 - val_jaccard_index: 0.5508
# Epoch 82/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0191 - jaccard_index: 0.5431
#
# Epoch 00082: val_loss improved from 0.02075 to 0.02069, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0191 - jaccard_index: 0.5431 - val_loss: 0.0207 - val_jaccard_index: 0.5495
# Epoch 83/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0189 - jaccard_index: 0.5477
#
# Epoch 00083: val_loss did not improve from 0.02069
#
#
# 81/81 [==============================] - 15s 180ms/step - loss: 0.0189 - jaccard_index: 0.5477 - val_loss: 0.0208 - val_jaccard_index: 0.5477
# Epoch 84/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0189 - jaccard_index: 0.5466
#
# Epoch 00084: val_loss improved from 0.02069 to 0.02048, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 183ms/step - loss: 0.0189 - jaccard_index: 0.5466 - val_loss: 0.0205 - val_jaccard_index: 0.5530
# Epoch 85/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0188 - jaccard_index: 0.5495
#
# Epoch 00085: val_loss improved from 0.02048 to 0.02034, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 184ms/step - loss: 0.0188 - jaccard_index: 0.5495 - val_loss: 0.0203 - val_jaccard_index: 0.5566
# Epoch 86/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0188 - jaccard_index: 0.5480
#
# Epoch 00086: val_loss improved from 0.02034 to 0.02028, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0188 - jaccard_index: 0.5480 - val_loss: 0.0203 - val_jaccard_index: 0.5536
# Epoch 87/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0187 - jaccard_index: 0.5510
#
# Epoch 00087: val_loss improved from 0.02028 to 0.02028, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0187 - jaccard_index: 0.5510 - val_loss: 0.0203 - val_jaccard_index: 0.5564
# Epoch 88/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0187 - jaccard_index: 0.5508
#
# Epoch 00088: val_loss improved from 0.02028 to 0.02018, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 183ms/step - loss: 0.0187 - jaccard_index: 0.5508 - val_loss: 0.0202 - val_jaccard_index: 0.5589
# Epoch 89/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0187 - jaccard_index: 0.5499
#
# Epoch 00089: val_loss did not improve from 0.02018
#
#
# 81/81 [==============================] - 15s 180ms/step - loss: 0.0187 - jaccard_index: 0.5499 - val_loss: 0.0202 - val_jaccard_index: 0.5572
# Epoch 90/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0185 - jaccard_index: 0.5550
#
# Epoch 00090: val_loss did not improve from 0.02018
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0185 - jaccard_index: 0.5550 - val_loss: 0.0202 - val_jaccard_index: 0.5565
# Epoch 91/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0184 - jaccard_index: 0.5563
#
# Epoch 00091: val_loss did not improve from 0.02018
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0184 - jaccard_index: 0.5563 - val_loss: 0.0203 - val_jaccard_index: 0.5570
# Epoch 92/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0185 - jaccard_index: 0.5553
#
# Epoch 00092: val_loss did not improve from 0.02018
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0185 - jaccard_index: 0.5553 - val_loss: 0.0204 - val_jaccard_index: 0.5522
# Epoch 93/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0184 - jaccard_index: 0.5566
#
# Epoch 00093: val_loss improved from 0.02018 to 0.02002, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0184 - jaccard_index: 0.5566 - val_loss: 0.0200 - val_jaccard_index: 0.5595
# Epoch 94/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0183 - jaccard_index: 0.5595
#
# Epoch 00094: val_loss did not improve from 0.02002
#
#
# 81/81 [==============================] - 15s 180ms/step - loss: 0.0183 - jaccard_index: 0.5595 - val_loss: 0.0200 - val_jaccard_index: 0.5599
# Epoch 95/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0183 - jaccard_index: 0.5591
#
# Epoch 00095: val_loss did not improve from 0.02002
#
#
# 81/81 [==============================] - 15s 183ms/step - loss: 0.0183 - jaccard_index: 0.5591 - val_loss: 0.0201 - val_jaccard_index: 0.5609
# Epoch 96/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0183 - jaccard_index: 0.5585
#
# Epoch 00096: val_loss improved from 0.02002 to 0.01997, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0183 - jaccard_index: 0.5585 - val_loss: 0.0200 - val_jaccard_index: 0.5620
# Epoch 97/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0182 - jaccard_index: 0.5613
#
# Epoch 00097: val_loss improved from 0.01997 to 0.01971, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0182 - jaccard_index: 0.5613 - val_loss: 0.0197 - val_jaccard_index: 0.5654
# Epoch 98/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0181 - jaccard_index: 0.5626
#
# Epoch 00098: val_loss improved from 0.01971 to 0.01963, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0181 - jaccard_index: 0.5626 - val_loss: 0.0196 - val_jaccard_index: 0.5675
# Epoch 99/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0181 - jaccard_index: 0.5642
#
# Epoch 00099: val_loss improved from 0.01963 to 0.01951, saving model to /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
#
#
# 81/81 [==============================] - 15s 182ms/step - loss: 0.0181 - jaccard_index: 0.5642 - val_loss: 0.0195 - val_jaccard_index: 0.5668
# Epoch 100/100
# 81/81 [==============================] - ETA: 0s - loss: 0.0180 - jaccard_index: 0.5646
#
# Epoch 00100: val_loss did not improve from 0.01951
#
#
# 81/81 [==============================] - 15s 181ms/step - loss: 0.0180 - jaccard_index: 0.5646 - val_loss: 0.0195 - val_jaccard_index: 0.5700
# Creating training plots . . .
# Loading model weights from h5_file: /content/output/my_2d_detection/checkpoints/model_weights_my_2d_detection_1.h5
# ###############
# #  INFERENCE  #
# ###############
#
# Making predictions on test data . . .
#   0% 0/2 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image76.tif']
# ### OV-CROP ###
# Cropping (1, 1024, 1024, 1) images into (256, 256, 1) with overlapping. . .
# Minimum overlap selected: (0, 0)
# Padding: (32, 32)
# Real overlapping (%): 0.13020833333333334
# Real overlapping (pixels): 25.0
# 6 patches per (x,y) axis
# **** New data shape is: (36, 256, 256, 1)
# ### END OV-CROP ###
#
#
#   0% 0/5 [00:00<?, ?it/s]
#
#  20% 1/5 [00:00<00:01,  3.06it/s]
#
#  60% 3/5 [00:00<00:00,  6.86it/s]
#
# 100% 5/5 [00:01<00:00,  3.17it/s]
#
#
#
#   0% 0/5 [00:00<?, ?it/s]
#
#  20% 1/5 [00:00<00:00,  4.13it/s]
#
#  60% 3/5 [00:00<00:00,  8.36it/s]
#
# 100% 5/5 [00:00<00:00, 11.01it/s]
#
#                                  ### MERGE-OV-CROP ###
# Merging (36, 256, 256, 1) images into (1, 1024, 1024, 1) with overlapping . . .
# Minimum overlap selected: (0, 0)
# Padding: (32, 32)
# Real overlapping (%): (0.13020833333333334, 0.13020833333333334)
# Real overlapping (pixels): (25.0, 25.0)
# (6, 6) patches per (x,y) axis
# **** New data shape is: (1, 1024, 1024, 1)
# ### END MERGE-OV-CROP ###
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  6.32it/s]
#
#                                  Capturing the local maxima
# Class 1
# Removing close points . . .
# Initial number of points: 226
# Final number of points: 213
# Creating the image with detected points . . .
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Detection (class 1)
# Points in ground truth: 209, Points in prediction: 213
# True positives: 188, False positives: 25, False negatives: 21
# Detection metrics: ['Precision', 0.8826291079812206, 'Recall', 0.8995215311004785, 'F1', 0.8909952606635071]
# All classes 1
# Detection metrics: ['Precision', 0.8826291079812206, 'Recall', 0.8995215311004785, 'F1', 0.8909952606635071]
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/full_image
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  4.56it/s]
#
#                                  Capturing the local maxima
# Class 1
# Removing close points . . .
# Initial number of points: 227
# Final number of points: 210
# Creating the image with detected points . . .
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Detection (class 1)
# Points in ground truth: 209, Points in prediction: 210
# True positives: 185, False positives: 25, False negatives: 24
# Detection metrics: ['Precision', 0.8809523809523809, 'Recall', 0.8851674641148325, 'F1', 0.883054892601432]
# All classes 1
# Detection metrics: ['Precision', 0.8809523809523809, 'Recall', 0.8851674641148325, 'F1', 0.883054892601432]
#
# 100% 1/1 [00:05<00:00,  5.70s/it]
#  50% 1/2 [00:05<00:05,  5.71s/it]
#   0% 0/1 [00:00<?, ?it/s]Processing image(s): ['cell migration R1 - Position 58_XY1562686154_Z0_T00_C1-image86.tif']
# ### OV-CROP ###
# Cropping (1, 1024, 1024, 1) images into (256, 256, 1) with overlapping. . .
# Minimum overlap selected: (0, 0)
# Padding: (32, 32)
# Real overlapping (%): 0.13020833333333334
# Real overlapping (pixels): 25.0
# 6 patches per (x,y) axis
# **** New data shape is: (36, 256, 256, 1)
# ### END OV-CROP ###
#
#
#   0% 0/5 [00:00<?, ?it/s]
#
#  20% 1/5 [00:00<00:00,  7.69it/s]
#
#  40% 2/5 [00:00<00:00,  8.79it/s]
#
#  60% 3/5 [00:00<00:00,  8.74it/s]
#
#  80% 4/5 [00:00<00:00,  5.07it/s]
#
#
#
#   0% 0/5 [00:00<?, ?it/s]
#
#  40% 2/5 [00:00<00:00, 10.40it/s]
#
#  80% 4/5 [00:00<00:00, 10.91it/s]
#
#                                  ### MERGE-OV-CROP ###
# Merging (36, 256, 256, 1) images into (1, 1024, 1024, 1) with overlapping . . .
# Minimum overlap selected: (0, 0)
# Padding: (32, 32)
# Real overlapping (%): (0.13020833333333334, 0.13020833333333334)
# Real overlapping (pixels): (25.0, 25.0)
# (6, 6) patches per (x,y) axis
# **** New data shape is: (1, 1024, 1024, 1)
# ### END MERGE-OV-CROP ###
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  6.54it/s]
#
#                                  Capturing the local maxima
# Class 1
# Removing close points . . .
# Initial number of points: 243
# Final number of points: 231
# Creating the image with detected points . . .
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Detection (class 1)
# Points in ground truth: 226, Points in prediction: 231
# True positives: 203, False positives: 28, False negatives: 23
# Detection metrics: ['Precision', 0.8787878787878788, 'Recall', 0.8982300884955752, 'F1', 0.8884026258205688]
# All classes 1
# Detection metrics: ['Precision', 0.8787878787878788, 'Recall', 0.8982300884955752, 'F1', 0.8884026258205688]
# Saving (1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/full_image
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
# 100% 1/1 [00:00<00:00,  6.13it/s]
#
#                                  Capturing the local maxima
# Class 1
# Removing close points . . .
# Initial number of points: 243
# Final number of points: 226
# Creating the image with detected points . . .
# Saving (1, 1, 1024, 1024, 1) data as .tif in folder: /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check
#
#
#   0% 0/1 [00:00<?, ?it/s]
#
#                          Detection (class 1)
# Points in ground truth: 226, Points in prediction: 226
# True positives: 195, False positives: 31, False negatives: 31
# Detection metrics: ['Precision', 0.8628318584070797, 'Recall', 0.8628318584070797, 'F1', 0.8628318584070797]
# All classes 1
# Detection metrics: ['Precision', 0.8628318584070797, 'Recall', 0.8628318584070797, 'F1', 0.8628318584070797]
#
# 100% 1/1 [00:02<00:00,  2.17s/it]
# 100% 2/2 [00:07<00:00,  3.95s/it]
# #############
# #  RESULTS  #
# #############
#
# Epoch average time: 14.854623548984527
# Epoch number: 100
# Train time (s): 1485.4623548984528
# Train loss: 0.0180060975253582
# Train jaccard_index: 0.5646222233772278
# Validation loss: 0.01950586587190628
# Validation jaccard_index: 0.5700159668922424
# Loss (per patch): 0.0015910106327889177
# Test Foreground IoU (per patch): 0.07342255115509033
#
# Test Foreground IoU (merge patches): 0.6326174785174546
# Test Overall IoU (merge patches): 0.814427926239979
#
# Loss (per image): 0.010125973261892796
# Test Foreground IoU (per image): 0.646589731397585
# Test Overall IoU (per image): 0.82149664404244
#
# Detection specific metrics:
# Detection - Test Precision (merge patches): 0.8807084933845497
# Detection - Test Recall (merge patches): 0.8988758097980268
# Detection - Test F1 (merge patches): 0.8896989432420379
# Detection - Test Precision (per image): 0.8718921196797302
# Detection - Test Recall (per image): 0.8739996612609561
# Detection - Test F1 (per image): 0.8729433755042558
# FINISHED JOB my_2d_detection_1 !!

# %% [markdown]
# ## Inspection of the loss function and the Intersection over Union (IoU)
# ---
#
# First, it is good practice to evaluate the training progress by comparing the training loss with the validation loss. The latter is a metric which shows how well the network performs on a subset of unseen data which is set aside from the training dataset. For more information on this, see for example [this review](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6381354/) by Nichols *et al.*
#
# **Training loss** describes an error value after each epoch for the difference between the model's prediction and its ground-truth target.
#
# **Validation loss** describes the same error value between the model's prediction on a validation image and compared to it's target.
#
# During training both values should decrease before reaching a minimal value which does not decrease further even after more training. Comparing the development of the validation loss with the training loss can give insights into the model's performance.
#
# Decreasing **Training loss** and **Validation loss** indicates that training is still necessary and increasing the `number_of_epochs` is recommended. Note that the curves can look flat towards the right side, just because of the y-axis scaling. The network has reached convergence once the curves flatten out. After this point no further training is required. If the **Validation loss** suddenly increases again an the **Training loss** simultaneously goes towards zero, it means that the network is overfitting to the training data. In other words the network is remembering the exact patterns from the training data and no longer generalizes well to unseen data. In this case the training dataset has to be increased.
#
# The **Jaccard index or Intersection over Union** (IoU) metric is a method that can be used to quantify the overlap between the target mask and your prediction output. **Therefore, the closer to 1, the better the performance.** This metric can be used to assess the quality of your model to accurately predict cells.

# %%
#@markdown ##Play the cell to show a plot of training error vs. epoch number and IoU vs epoch number
import matplotlib.pyplot as plt

loss_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_loss.png' )

iou_plot = imread( output_path + '/'+job_name+'/results/'+job_name+'_1/charts/'+job_name+'_1_jaccard_index.png' )

fig = plt.figure( figsize = (20,10))
ax1 = plt.subplot( 1, 2, 1 )
_ = plt.imshow( loss_plot )
_ = plt.axis('off')
ax1.set_title( 'Training error vs epoch number', fontdict = {'fontsize':22})

ax2 = plt.subplot( 1, 2, 2 )
_ = plt.imshow( iou_plot )
_ = plt.axis('off')
_= ax2.set_title( 'Intersection over Union (IoU) vs epoch number', fontdict = {'fontsize':22})

# %% [markdown]
# ## **Visualize detection results**

# %%
#@markdown ###Play to visualize results in 2D

# %matplotlib inline
import matplotlib
import numpy as np
from numpy.random import randint, seed
from matplotlib import pyplot as plt
from ipywidgets import interact
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")
detection_results = os.path.join(final_results, "per_image_local_max_check")
test_data_mask_path = "/content/data/train/y_detection_masks"

# Show a few examples to check that they have been stored correctly 
ids_pred = sorted(next(os.walk(detection_results))[2])
ids_pred = [x for x in ids_pred if not x.endswith('.csv') ]
ids_input = sorted(next(os.walk(test_data_path))[2])
ids_gt = sorted(next(os.walk(test_data_mask_path))[2])

# create random color map
vals = np.linspace(0,1,256)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gist_rainbow(vals))
cmap.colors[0] = [0., 0., 0., 1.] # set background to black

samples_to_show = min(len(ids_input), 3)
chosen_images = np.random.choice(len(ids_input), samples_to_show, replace=False) 
seed(1)

test_samples = []
test_sample_preds = []
test_sample_gt = []

# read 3D images again
for i in range(len(chosen_images)):
    aux = imread(os.path.join(test_data_path, ids_input[chosen_images[i]]))
    test_samples.append(np.squeeze(aux))
    
    aux = imread(os.path.join(detection_results, ids_pred[chosen_images[i]])).astype(np.uint16)
    test_sample_preds.append(np.squeeze(aux))
    
    aux = imread(os.path.join(test_data_mask_path, ids_gt[chosen_images[i]])).astype(np.uint16)
    test_sample_gt.append(np.squeeze(aux))

# Show predicted images
plt.figure(figsize=(20,15))
index = 1
for j in range(samples_to_show):
    plt.subplot(samples_to_show, 3, index)
    plt.title("Input image")
    plt.imshow(test_samples[j], cmap='magma', vmin=np.percentile(test_samples[j],0.1),vmax=np.percentile(test_samples[j],99.9))          
    
    index = index + 1
    plt.subplot(samples_to_show, 3, index)
    plt.title("Prediction")
    plt.imshow(test_sample_preds[j], cmap=cmap, interpolation='nearest')
    
    index = index + 1
    plt.subplot(samples_to_show, 3, index)
    plt.title("Ground truth")
    plt.imshow(test_sample_gt[j],  cmap=cmap, interpolation='nearest')
    index = index + 1
plt.show()

# %%
#@markdown ###Play to display the path to the output files (one 2D TIFF label image for each input image).

final_results = os.path.join(output_path, job_name, 'results', job_name+"_1")

detection_results = os.path.join(final_results, "per_image_local_max_check")

print("Output paths:")
print("    Detection files are in {}".format(detection_results))
# Out:
# Output paths:
#     Detection files are in /content/output/my_2d_detection/results/my_2d_detection_1/per_image_local_max_check

# %% [markdown]
# ## **Download detection results**

# %%
#@markdown ###Play to download a zip file with all detection results in test.

from google.colab import files

# !zip -q -j /content/detection.zip $detection_results/*.tif

files.download("/content/detection.zip")

# %% [markdown]
# ## **Download train model (weights and configuration file)**
# If you want to **reuse the train model in the future**, you can download both the model weights and its configuration file (.YAML) by running the following cells.

# %%
#@markdown ###Play to download the model weights

checkpoints_path = os.path.join(output_path, job_name, 'checkpoints')

weights_filename = 'model_weights_' + str( job_name ) + '_1.h5'

files.download( os.path.join( checkpoints_path, weights_filename))

# %%
#@markdown ###Play to download the model configuration file (.YAML)

config_path = os.path.join(output_path, job_name, 'config_files')

files.download( os.path.join( config_path, yaml_file))

# %% [markdown]
# ## **Acknowledgments**
# We would like to acknowledge the inspiration provided by the excellent [ZeroCostDL4Mic notebooks](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki). In particular, we have reused some of their descriptions of metrics and parameters.
